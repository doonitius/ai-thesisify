# %%
import pandas as pd
from glob import glob, glob1

# %%
path = './txtFile/'

data = pd.DataFrame(columns=['doc_id', 'document'])
for i in glob1(path, '*'):
    with open(path + i, 'r', encoding='utf8') as f:
        doc_line = []
        doc_id = i.split('.')[-2]

        for j in f:
            line = j.strip()
            doc_line.append(line)
        doc_details = ' '.join(doc_line)

        data = data.append(
            {"doc_id": doc_id, "document": doc_details}, ignore_index=True)
    f.close()

display(data)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
# C:\Users\USER\AppData\Local\Temp\ipykernel_22420\1399302844.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(
#    doc_id                                           document
# 0      01  Solving Vehicle Routing Problem with Hard Time...
# 1      02  Automatic Hyper-Parameter Tuning for Gradient ...
# 2      03  Computing Resource Estimation by Using Machine...
# 3      04  Thai Character-Word LSTM Language Models with ...
# 4      05  Text Summarization on Covid 19 News Since the ...
# 5      06  Acoustic-to-Articulatory Inversion Using Deep ...
# 6      07  A Computational Study on The Effects of Featur...
# 7      08  An Analysis on Network and Topology of Legal D...
# 8      09  Coreference Resolution and Entity's Action in ...
# 9      10  Thai Tokenization with Attention Mechanism Wor...
# 10     11  Log Data Traffic Characterization for Packet L...
# 11     12  Effects of Facial Movements to Expressive Spee...
# 12     13  Risk-Sensitive Portfolio Management by using D...
# 13     14  Quantum Random Walk on A Number Line Implement...
# 14     15  Automated Hyperparameters Tuning Using the Art...
# 15     16  Machine Learning Classifier to Differentiate t...
# 16     17  Deep Anomaly Detection System Using System Log...
# 17     18  A Synthetic Minority Based on Probabilistic Di...
# 18     19  Stock Market Movement Prediction Using Enhance...
# 19     20  Sentiment analysis of messages on Twitter rela...
# 20     21  A robust system for core thai natural language...
# 21     22  Global optimization of recurrent neural networ...
# 22     23  Artificial Intelligence and Copyright Law In S...
# 23     24  REDUCING SMART CONTRACT RUNTIME ERRORS ON THE ...
# 24     25  Marketing Strategy Development for Professiona...
# 25     26  Big Data Analytics for Improving Customer Win-...
# 26     27  A DEVELOPMENT OF THE DEADLOCK DETECTION ALGORI...
# 27     28  The Application of Machine Learning in Cluster...
# 28     29  DATA AUGMENTATION FOR THAI NATURAL LANGUAGE PR...
# 29     30  Designing Answer Sets For Thai Advisory Chatbo...
# 30     31  Network management policy for overlapping betw...
# 31     32  COMPARATIVE PERFORMANCE EVALUATION OF CENTRALI...
# 32     33  Mitigating sinkhole attack on low-power and lo...
# 33     34  Design and development of central node and mob...
# 34     35  Resilient heat exchanger network design of hyd...
# 35     36  Connectivity analysis and its application to r...
# 36     37  Asset pricing and network topology This disser...
# 37     38  MULTI-DOMAIN NETWORK DESIGN STRATEGY FOR SURVI...
# 38     39  Analogous View Between Residual Networks and P...
# 39     40  Identifying non-binding constrints in linear p...
# 40     41  Use of multilayer feedforward networks for sys...
# 41     42  Increasing of service performance for hypertex...
# 42     43  Water demand forecasting using the artificial ...
# 43     44  Identifying non-binding constrints in linear p...
# 44     45  Hybrid GNS3 and Mininet-WiFi emulator for surv...
# 45     46  Use of multilayer feedforward networks for sys...
# 46     47  NON-GEOGRAPHICAL KNOWLEDGE DATA DISSEMINATION ...
# 47     48  Incomplete time-series data forecasting based ...
# 48     49  Generalization of an elliptic radial basis fun...
# 49     50  An intelligent system to recommend appropriate...

# %%
data.head()
# Out:
#   doc_id                                           document
# 0     01  Solving Vehicle Routing Problem with Hard Time...
# 1     02  Automatic Hyper-Parameter Tuning for Gradient ...
# 2     03  Computing Resource Estimation by Using Machine...
# 3     04  Thai Character-Word LSTM Language Models with ...
# 4     05  Text Summarization on Covid 19 News Since the ...

# %%
len(data)
# Out:
# 50

# %%
data['document'][17]
# Out:
# 'A Synthetic Minority Based on Probabilistic Distribution (SyMProD) Oversampling for Imbalanced Datasets Handling an imbalanced class problem is a challenging task in real-world applications. This problem affects various prediction models that predict only the majority classes and fail to identify the minority classes because of the skewed data. The oversampling technique is one of the exciting solutions that handles the imbalanced class problem. However, several existing oversampling methods do not consider the distribution of the target variable and cause an overlapping class problem. Therefore, this study introduces a new oversampling technique, namely Synthetic Minority Based on Probabilistic Distribution (SyMProD), to handle skewed datasets. Our method normalizes data using a Z-score and removes noisy data. Then, the proposed method selects minority samples based on the probability distribution of both classes. The synthetic instances are generated from the selected points and several minority nearest neighbors. Our technique aims to create synthetic instances that cover the minority class distribution, avoid the noise generation, and reduce the possibilities of overlapping classes and overgeneralization problems. Our proposed technique is validated using 17 benchmark datasets and three classifiers. Moreover, this study compares the performance of the method with other eight conventional oversampling algorithms. The empirical results show that our method achieves better performance than other oversampling techniques.'

# %%
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re
import string
# s = set(string.punctuation)          # !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def tok(text):
    # s = set(string.punctuation)          # !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
    tokens =  word_tokenize(text)
    tokens = list(filter(lambda token: token not in string.punctuation, tokens))
    return tokens

# %%
porter_stemmer = PorterStemmer()

def text_preprocessor(text):

    text = text.lower()
    text = re.sub("\\W", " ", text)  # remove special chars
    text = re.sub("\\s+(in|the|all|for|and|on)\\s+", " _connector_ ", text)  # normalize certain words

    # stem words
    words = re.split("\\s+", text)
    stemmed_words = [porter_stemmer.stem(word=word) for word in words]
    return ' '.join(stemmed_words)

# %%
cv = CountVectorizer(max_df = 0.9, min_df = 2, stop_words = 'english', tokenizer = tok, preprocessor = text_preprocessor)

# %%
dtm = cv.fit_transform(data['document'])
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'formerli', 'forti', 'ha', 'henc', 'hereaft', 'herebi', 'hi', 'howev', 'hundr', 'inde', 'latterli', 'mani', 'meanwhil', 'moreov', 'mostli', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'seriou', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'thi', 'thu', 'togeth', 'twelv', 'twenti', 'veri', 'wa', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   warnings.warn(

# %%
dtm
# Out:
# <50x702 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3141 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
topic_no = 3
LDA = LatentDirichletAllocation(n_components = topic_no, random_state=12)

# %%
LDA.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=12)

# %%
#Grab the vocab of words

# %%
len(cv.get_feature_names())
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 702

# %%
type(cv.get_feature_names())
# Out:
# list

# %%
import random

random_word_id = random.randint(0, len(cv.get_feature_names()))
cv.get_feature_names()[random_word_id]
# Out:
# 'nois'

# %%
#Grab the topics
len(LDA.components_)
# Out:
# 3

# %%
type(LDA.components_)
# Out:
# numpy.ndarray

# %%
LDA.components_.shape
# Out:
# (3, 702)

# %%
LDA.components_
# Out:
# array([[1.41961735, 1.3307952 , 1.33280158, ..., 0.40302209, 0.33337932,
#         0.33655363],
#        [1.43467401, 0.40312195, 3.32628647, ..., 2.26359758, 0.33337355,
#         0.34427122],
#        [2.14570864, 9.26608285, 0.34091196, ..., 0.33338034, 2.33324713,
#         7.31917514]])

# %%
single_topic = LDA.components_[0]

# %%
single_topic.argsort()
# Out:
# array([376, 345,  77, 482, 276, 574, 684, 112, 626, 663, 213, 568, 469,
#        659, 623,  99, 137, 501, 533, 404, 506, 542, 544, 130, 541, 579,
#        405, 645, 651, 694,  97, 621, 677, 312, 493, 121, 588, 176, 304,
#         92, 413, 364, 380, 378, 356, 256, 372, 133,  42, 101, 624, 148,
#        146, 264,  94, 700,  24, 147, 351, 270, 199, 465, 550, 344, 250,
#        191,  72, 217, 360, 149, 608, 119, 664, 370,  55, 303, 577, 238,
#        106, 383, 575, 537, 160, 685,  47, 678,   8, 129,  78, 554, 562,
#        267, 679,  66, 478, 342, 435, 236, 192, 287, 497, 348, 522, 269,
#        272, 358, 110, 220, 291, 399, 218, 566, 439, 459,   9, 255, 300,
#        123, 388, 394, 548, 600, 234, 638, 268, 426, 492, 605, 556, 484,
#         86, 182, 615, 365,  74,  87, 266, 559, 354, 534, 487, 640, 239,
#        251, 500, 429,  91, 555, 447, 519,  16, 214, 691, 494,  56,  28,
#         35, 510, 458, 412, 277, 319, 309, 135, 666, 446, 144, 528, 333,
#        280,  25, 286, 553, 107,  52, 329, 450, 563, 689, 243, 369, 263,
#        583, 134, 681, 629, 586, 244, 375, 352, 419, 527, 299, 202, 418,
#        131, 298, 393,  68,  26, 434, 349, 168, 601, 126, 410, 456, 613,
#        535, 331, 174, 205, 560, 113, 599, 675,  20,   4, 114, 346, 551,
#        631,  51,  11, 297,  67, 477, 136, 649, 172, 536, 336, 698, 367,
#        646,  54, 648, 228, 538, 295, 184, 620, 507, 186, 587, 285, 657,
#        409, 165, 339,  41, 104, 100, 611, 207, 163, 688, 310,  15, 171,
#         64, 701,  65,   5, 274, 167, 511, 464, 194, 187, 479, 350, 247,
#        278, 491, 325, 662, 660, 606, 108, 188, 449, 230, 699, 604, 593,
#        193, 227,  48, 581, 591,  61, 326, 686, 595, 502, 153, 423, 208,
#        442, 580, 508, 564,  96, 115, 155, 116, 512, 539,  89, 384, 687,
#        503, 122, 206, 468, 682,   1, 249, 653, 617, 665, 201, 170, 179,
#        670, 382, 616, 271, 120, 265, 111, 463, 570, 609, 647, 128, 368,
#         95, 198, 515, 474, 549, 200, 212, 693,  32, 377, 183, 124, 347,
#        529, 313, 481,   2, 161, 585, 371, 602, 273, 391, 557,  50, 254,
#        195, 654,  82, 292, 520, 305,  13,  76, 387, 289, 526, 260, 156,
#         83, 612,  36, 259, 513,  34, 283, 275,  39, 603, 341, 669, 355,
#        521, 438,   3,  10, 471,  45, 302, 547, 190, 306, 658, 428, 225,
#        561, 480,  40, 252, 150, 661, 140, 523, 485,  44, 414, 643,  18,
#         12, 132, 246, 683, 204, 226, 248, 416,  19, 159, 257, 576, 692,
#        490,  21, 483, 461, 572, 594, 162, 582, 596, 311, 489, 545,  71,
#        499,   0, 141, 504, 216, 335,  49, 363, 668, 440, 185, 543, 240,
#        164, 219, 598, 417, 334, 143, 181, 695, 697, 655, 386, 565, 222,
#        308, 408, 125, 366, 318, 402, 472,  69, 567, 320, 516,  14, 451,
#         81, 667, 518, 390,  23, 466, 578, 614, 403, 627, 633, 488, 552,
#        374,  31, 432, 362, 158, 281, 430, 152, 389, 316, 470,  37, 233,
#        338, 139, 676, 327, 589, 407, 431,  84,  73, 532, 340, 444,  57,
#        138, 400,  33, 498, 242, 103, 118, 437, 397, 282, 401, 328,  93,
#        337,  22, 592, 145, 441, 315, 524, 531, 453, 457, 324, 232, 296,
#        422, 221, 177, 279,  90,  79, 495,  59, 307, 644, 454, 102, 462,
#        385, 455, 641, 215, 452, 619,  63, 157, 427, 381, 486, 571, 105,
#        142, 650,   7, 622, 209,  38, 460,  85,  88, 396, 625, 514, 223,
#        433, 415,  70,  17,  53, 180, 211,  27, 229, 109, 436, 509,  30,
#         75,  29, 642, 671, 673, 425, 169, 445, 636, 558, 178, 411, 530,
#        235, 652, 314, 590, 607, 117, 680, 525, 290, 323, 373, 321, 293,
#        253, 210, 245, 262, 197, 241, 224, 203, 288, 322, 175, 261, 424,
#        573, 597, 630, 301, 332, 505, 330, 674, 392, 473, 443, 294, 517,
#         43, 569,  58,  60, 475, 166, 258, 634,   6, 632, 317, 398, 696,
#        237, 628, 357, 540,  46, 343, 196, 361, 151, 448,  98, 610, 127,
#        284, 637, 639, 359, 618, 231, 379, 189, 635,  62, 690,  80, 353,
#        476, 584, 395, 656, 496, 173, 546, 467, 421, 672, 154, 406, 420],
#       dtype=int64)

# %%
single_topic.argsort()[-10:]
# Out:
# array([656, 496, 173, 546, 467, 421, 672, 154, 406, 420], dtype=int64)

# %%
top_twenty_words = single_topic.argsort()[-20:]

# %%
for index in top_twenty_words:
    print(cv.get_feature_names()[index])
# Out:
# lstm
# design
# test
# approxim
# wa
# base
# languag
# polici
# set
# mechan
# train
# process
# data
# result
# perform
# neural
# use
# control
# model
# network

# %%
#Grab the highest probability words per topic

# %%
for i, topic in enumerate(LDA.components_):
    print(f"THE TOP 15 WORDS FOR TOPIC # {i}")
    print([cv.get_feature_names()[index] for index in topic.argsort()[-15:]])
    print('\n')
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC # 0
# ['base', 'languag', 'polici', 'set', 'mechan', 'train', 'process', 'data', 'result', 'perform', 'neural', 'use', 'control', 'model', 'network']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 1
# ['connect', 'sensor', 'work', 'propos', 'rout', 'return', 'measur', 'data', 'quantum', 'algorithm', 'traffic', 'node', 'comput', 'use', 'network']
#
#
#
#
# THE TOP 15 WORDS FOR TOPIC # 2
# ['predict', 'studi', 'result', 'method', 'problem', 'propos', 'perform', 'base', 'learn', 'neural', 'algorithm', 'model', 'network', 'use', 'data']

# %%
dtm
# Out:
# <50x702 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3141 stored elements in Compressed Sparse Row format>

# %%
topic_results = LDA.transform(dtm)

# %%
topic_results
# Out:
# array([[0.00341688, 0.00366803, 0.99291509],
#        [0.00381808, 0.00363657, 0.99254535],
#        [0.00275314, 0.00299749, 0.99424937],
#        [0.99254977, 0.00352014, 0.0039301 ],
#        [0.99281015, 0.00334827, 0.00384158],
#        [0.99498752, 0.00244672, 0.00256577],
#        [0.00497242, 0.0048129 , 0.99021467],
#        [0.0038041 , 0.30090357, 0.69529233],
#        [0.00329012, 0.99339655, 0.00331333],
#        [0.00762093, 0.00680597, 0.98557309],
#        [0.00303089, 0.41004172, 0.5869274 ],
#        [0.00504021, 0.99028314, 0.00467665],
#        [0.00284223, 0.00291179, 0.99424598],
#        [0.00259061, 0.99464198, 0.00276741],
#        [0.00378587, 0.00381022, 0.99240391],
#        [0.99233955, 0.00376064, 0.00389981],
#        [0.00334416, 0.00348462, 0.99317122],
#        [0.00338523, 0.00323091, 0.99338386],
#        [0.00352085, 0.00343661, 0.99304254],
#        [0.00439525, 0.00374197, 0.99186278],
#        [0.0030954 , 0.00289663, 0.99400797],
#        [0.00572854, 0.00543239, 0.98883907],
#        [0.00446822, 0.99081531, 0.00471647],
#        [0.99239348, 0.00383697, 0.00376955],
#        [0.00427938, 0.0046392 , 0.99108142],
#        [0.00364121, 0.00356895, 0.99278984],
#        [0.00432114, 0.00460089, 0.99107797],
#        [0.00416931, 0.00391922, 0.99191147],
#        [0.00595353, 0.00527633, 0.98877014],
#        [0.98979276, 0.004893  , 0.00531424],
#        [0.79660608, 0.006054  , 0.19733993],
#        [0.9954806 , 0.00240304, 0.00211637],
#        [0.00224042, 0.99551429, 0.00224529],
#        [0.00410324, 0.99140913, 0.00448762],
#        [0.99089043, 0.00455942, 0.00455015],
#        [0.00299071, 0.99395606, 0.00305324],
#        [0.00195705, 0.99604616, 0.00199679],
#        [0.00356347, 0.99265161, 0.00378492],
#        [0.54655918, 0.44828526, 0.00515556],
#        [0.00346328, 0.00345175, 0.99308497],
#        [0.99582856, 0.00206042, 0.00211102],
#        [0.00699958, 0.17817948, 0.81482094],
#        [0.12641205, 0.25839382, 0.61519413],
#        [0.00346328, 0.00345175, 0.99308497],
#        [0.00191062, 0.99626161, 0.00182776],
#        [0.99582856, 0.00206042, 0.00211102],
#        [0.00353118, 0.55891723, 0.43755159],
#        [0.00214756, 0.00217213, 0.9956803 ],
#        [0.00605893, 0.00507563, 0.98886544],
#        [0.00388795, 0.67283993, 0.32327212]])

# %%
topic_results.shape
# Out:
# (50, 3)

# %%
topic_results[0].round(2)
# Out:
# array([0.  , 0.  , 0.99])

# %%
data['document'][0]
# Out:
# 'Solving Vehicle Routing Problem with Hard Time Windows by Genetic Algorithm In the logistic management, the cost reduction for delivering the goods to customers is crucial to save the budget of the company. Since decades ago, various Vehicle Routing Problems (VRPs) have been emerged enormously to improve the productivity and to reduce the logistic cost of the industry. Among them, Vehicle Routing Problem with Time Windows (VRPTW) is one of the most fundamental VRP variants and one of the most applicable variants in the real-world case studies. In this study, VRPTW with hard time windows is solved by developing a special Genetic Algorithm (GA), composed of a problem-specific crossover operator and seven different mutation operators. The proposed GA has better results with the heuristic mutation among seven operators while exploring the new and better features in large search space. The results of the algorithm are tested on the popular Solomon benchmark 100 customer datasets. The results show that the proposed GA is quite comparable with the best-known solutions on the C set of Solomon benchmark and even better than the best-known solutions on the R and RC sets. The motivation behind this research is to find a new problem specific configurations of GA for VRP TW domain which can have the desirable outputs that can be applied in most of the real-world use cases.'

# %%
topic_results[0].argmax()
# Out:
# 2

# %%
data['Topic'] = topic_results.argmax(axis=1)

# %%
data
# Out:
#    doc_id                                           document  Topic
# 0      01  Solving Vehicle Routing Problem with Hard Time...      2
# 1      02  Automatic Hyper-Parameter Tuning for Gradient ...      2
# 2      03  Computing Resource Estimation by Using Machine...      2
# 3      04  Thai Character-Word LSTM Language Models with ...      0
# 4      05  Text Summarization on Covid 19 News Since the ...      0
# 5      06  Acoustic-to-Articulatory Inversion Using Deep ...      0
# 6      07  A Computational Study on The Effects of Featur...      2
# 7      08  An Analysis on Network and Topology of Legal D...      2
# 8      09  Coreference Resolution and Entity's Action in ...      1
# 9      10  Thai Tokenization with Attention Mechanism Wor...      2
# 10     11  Log Data Traffic Characterization for Packet L...      2
# 11     12  Effects of Facial Movements to Expressive Spee...      1
# 12     13  Risk-Sensitive Portfolio Management by using D...      2
# 13     14  Quantum Random Walk on A Number Line Implement...      1
# 14     15  Automated Hyperparameters Tuning Using the Art...      2
# 15     16  Machine Learning Classifier to Differentiate t...      0
# 16     17  Deep Anomaly Detection System Using System Log...      2
# 17     18  A Synthetic Minority Based on Probabilistic Di...      2
# 18     19  Stock Market Movement Prediction Using Enhance...      2
# 19     20  Sentiment analysis of messages on Twitter rela...      2
# 20     21  A robust system for core thai natural language...      2
# 21     22  Global optimization of recurrent neural networ...      2
# 22     23  Artificial Intelligence and Copyright Law In S...      1
# 23     24  REDUCING SMART CONTRACT RUNTIME ERRORS ON THE ...      0
# 24     25  Marketing Strategy Development for Professiona...      2
# 25     26  Big Data Analytics for Improving Customer Win-...      2
# 26     27  A DEVELOPMENT OF THE DEADLOCK DETECTION ALGORI...      2
# 27     28  The Application of Machine Learning in Cluster...      2
# 28     29  DATA AUGMENTATION FOR THAI NATURAL LANGUAGE PR...      2
# 29     30  Designing Answer Sets For Thai Advisory Chatbo...      0
# 30     31  Network management policy for overlapping betw...      0
# 31     32  COMPARATIVE PERFORMANCE EVALUATION OF CENTRALI...      0
# 32     33  Mitigating sinkhole attack on low-power and lo...      1
# 33     34  Design and development of central node and mob...      1
# 34     35  Resilient heat exchanger network design of hyd...      0
# 35     36  Connectivity analysis and its application to r...      1
# 36     37  Asset pricing and network topology This disser...      1
# 37     38  MULTI-DOMAIN NETWORK DESIGN STRATEGY FOR SURVI...      1
# 38     39  Analogous View Between Residual Networks and P...      0
# 39     40  Identifying non-binding constrints in linear p...      2
# 40     41  Use of multilayer feedforward networks for sys...      0
# 41     42  Increasing of service performance for hypertex...      2
# 42     43  Water demand forecasting using the artificial ...      2
# 43     44  Identifying non-binding constrints in linear p...      2
# 44     45  Hybrid GNS3 and Mininet-WiFi emulator for surv...      1
# 45     46  Use of multilayer feedforward networks for sys...      0
# 46     47  NON-GEOGRAPHICAL KNOWLEDGE DATA DISSEMINATION ...      1
# 47     48  Incomplete time-series data forecasting based ...      2
# 48     49  Generalization of an elliptic radial basis fun...      2
# 49     50  An intelligent system to recommend appropriate...      1

# %%
keywords = ['artificial intelligence',
            'genetic algorithm',
            'deep learning',
            'network resource planning',
            'audio-synchronization',
            'facial expression',
            'deep learning',
            'distributional reinforcement learning',
            'quantum random walk',
            'quantum computer simulator',
            'hyperparameter tuning',
            'random search',
            'convolutional neural network',
            'feature extraction',
            'alice',
            'convolutional neural network',
            'classification',
            'probabilistic distribution',
            'genetic algorithm',
            'gradient boosting',
            'alice',
            'cern',
            'deep learning',
            'long short term memory',
            'abstractive text summarization',
            'covid-19',
            'acoustic-to-articulatory inversion',
            'deep learning',
            'natural language processing',
            'topic modeling',
            'document mining',
            'graph analysis',
            'natural language processing']

# %%
len(keywords)
# Out:
# 33

# %%
from collections import Counter
c = Counter(keywords)
c
# Out:
# Counter({'artificial intelligence': 1,
#          'genetic algorithm': 2,
#          'deep learning': 4,
#          'network resource planning': 1,
#          'audio-synchronization': 1,
#          'facial expression': 1,
#          'distributional reinforcement learning': 1,
#          'quantum random walk': 1,
#          'quantum computer simulator': 1,
#          'hyperparameter tuning': 1,
#          'random search': 1,
#          'convolutional neural network': 2,
#          'feature extraction': 1,
#          'alice': 2,
#          'classification': 1,
#          'probabilistic distribution': 1,
#          'gradient boosting': 1,
#          'cern': 1,
#          'long short term memory': 1,
#          'abstractive text summarization': 1,
#          'covid-19': 1,
#          'acoustic-to-articulatory inversion': 1,
#          'natural language processing': 2,
#          'topic modeling': 1,
#          'document mining': 1,
#          'graph analysis': 1})

# %% [markdown]
# Train LSTM

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
data.describe()
# Out:
#            Topic
# count  50.000000
# mean    1.280000
# std     0.833973
# min     0.000000
# 25%     1.000000
# 50%     2.000000
# 75%     2.000000
# max     2.000000

# %%
x = np.array(data['document'].values)
y = np.array(data['Topic'].values)

# %%
len(y)
# Out:
# 50

# %%
len(x)
# Out:
# 50

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y, random_state=0)
x_train, x_val, y_train, y_val = train_test_split(x , y, test_size =0.3,stratify=y,random_state=0)

# %%
len(x_train)
# Out:
# 35

# %%
from keras.preprocessing import text

# %%
# def token_train_word(train_list):
#     word_list = []
#     for i in train_list:
#         token = tok(i)
#         stemmed = text_preprocessor(token)
#         word_list.append(stemmed)
#     return word_list

# %%
# from nltk import pad_sequence

# %%
# token_train_word(x_train)
# token_train_word(x_test)
# x_indx = pad_sequence(x_train)
# x_indx_test = pad_sequence(x_test)

# %%
t = text.Tokenizer(filters='!"#$%&()*+-./:;<=>?@[\]^_`{|}~', lower=True)
t.fit_on_texts(x_train)
t.fit_on_texts(x_test)
t.fit_on_texts(x_val)
x_indx = t.texts_to_sequences(x_train)
x_indx_test = t.texts_to_sequences(x_test)
x_indx_val = t.texts_to_sequences(x_val)

# %%
x_indx_val
# Out:
# [[57,
#   32,
#   1254,
#   4,
#   1255,
#   1,
#   293,
#   167,
#   2,
#   1256,
#   1257,
#   669,
#   1258,
#   1,
#   1259,
#   8,
#   6,
#   521,
#   1260,
#   13,
#   1261,
#   11,
#   106,
#   1262,
#   62,
#   1263,
#   5,
#   106,
#   204,
#   766,
#   1264,
#   1265,
#   1266,
#   1267,
#   1268,
#   4,
#   1269,
#   68,
#   100,
#   20,
#   597,
#   1270,
#   1,
#   1271,
#   286,
#   2,
#   1272,
#   1273,
#   3,
#   293,
#   5,
#   508,
#   4,
#   1274,
#   20,
#   6,
#   780,
#   1275,
#   72,
#   108,
#   1276,
#   5,
#   1277,
#   254,
#   4,
#   1278,
#   173,
#   14,
#   5,
#   101,
#   4,
#   1279,
#   1,
#   490,
#   774,
#   2,
#   1,
#   1280,
#   12,
#   38,
#   858,
#   1,
#   91,
#   2,
#   6,
#   92,
#   17,
#   9,
#   293,
#   167,
#   5,
#   1281,
#   1282,
#   1283,
#   1284,
#   669,
#   1285,
#   208,
#   44,
#   1286,
#   1,
#   290,
#   922,
#   35,
#   554,
#   4,
#   583,
#   293,
#   842,
#   374,
#   4,
#   221,
#   1287,
#   167,
#   6,
#   69,
#   2,
#   410,
#   1288,
#   136,
#   5,
#   1,
#   173,
#   82,
#   35,
#   1289,
#   114,
#   213,
#   46,
#   1290,
#   1291,
#   1292,
#   670,
#   1293,
#   1294,
#   3,
#   670,
#   1295,
#   103,
#   78,
#   1,
#   523,
#   3,
#   89,
#   32,
#   23,
#   92,
#   40,
#   35,
#   243,
#   114,
#   1,
#   607,
#   1296,
#   1297,
#   671,
#   1298,
#   158,
#   1299,
#   3,
#   426,
#   19,
#   26,
#   1,
#   116,
#   17,
#   31,
#   206,
#   23,
#   10,
#   50,
#   1300,
#   1301,
#   1,
#   672,
#   69,
#   2,
#   236,
#   3,
#   1302,
#   673,
#   97,
#   1,
#   47,
#   632,
#   13,
#   1,
#   58,
#   602,
#   19,
#   7,
#   98,
#   11,
#   1,
#   1303,
#   71,
#   1304,
#   13,
#   417,
#   2,
#   120,
#   252,
#   1305,
#   910,
#   224,
#   9,
#   45,
#   1306,
#   3,
#   6,
#   672,
#   2,
#   1307,
#   1308,
#   236,
#   274,
#   317,
#   1,
#   116,
#   97],
#  [36,
#   294,
#   42,
#   67,
#   51,
#   40,
#   11,
#   531,
#   3,
#   674,
#   1309,
#   248,
#   4,
#   1,
#   675,
#   2,
#   163,
#   213,
#   154,
#   169,
#   361,
#   7,
#   67,
#   43,
#   8,
#   6,
#   763,
#   2,
#   89,
#   361,
#   194,
#   34,
#   8,
#   1310,
#   4,
#   30,
#   639,
#   4,
#   1,
#   1311,
#   2,
#   132,
#   51,
#   82,
#   249,
#   51,
#   284,
#   73,
#   839,
#   53,
#   67,
#   4,
#   17,
#   73,
#   135,
#   312,
#   220,
#   3,
#   509,
#   29,
#   5,
#   154,
#   2,
#   97,
#   83,
#   12,
#   37,
#   52,
#   8,
#   1312,
#   53,
#   4,
#   36,
#   51,
#   1313,
#   1,
#   790,
#   2,
#   36,
#   51,
#   8,
#   561,
#   44,
#   63,
#   64,
#   135,
#   312,
#   1314,
#   295,
#   821,
#   70,
#   1315,
#   23,
#   220,
#   12,
#   85,
#   53,
#   67,
#   5,
#   51,
#   284,
#   4,
#   187,
#   1,
#   1316,
#   42,
#   5,
#   1,
#   1317,
#   520,
#   67,
#   40,
#   72,
#   108,
#   502,
#   3,
#   105,
#   1,
#   47,
#   11,
#   42,
#   125,
#   67,
#   17,
#   1,
#   267,
#   425,
#   13,
#   294,
#   42,
#   67,
#   16,
#   84,
#   1,
#   29,
#   2,
#   132,
#   51,
#   284,
#   1318,
#   10,
#   36,
#   128,
#   249,
#   62,
#   25,
#   294,
#   42,
#   67,
#   11,
#   531,
#   791,
#   2,
#   368,
#   1319,
#   3,
#   674,
#   1320,
#   1,
#   1321,
#   8,
#   625,
#   63,
#   673,
#   42,
#   125,
#   67,
#   246,
#   4,
#   844,
#   367],
#  [676,
#   214,
#   142,
#   25,
#   1,
#   127,
#   437,
#   677,
#   28,
#   438,
#   142,
#   1322,
#   130,
#   214,
#   62,
#   112,
#   6,
#   57,
#   32,
#   17,
#   1323,
#   22,
#   270,
#   77,
#   41,
#   108,
#   1324,
#   1325,
#   1326,
#   678,
#   229,
#   73,
#   184,
#   2,
#   418,
#   13,
#   1327,
#   1,
#   214,
#   9,
#   1,
#   57,
#   32,
#   40,
#   3,
#   1328,
#   115,
#   130,
#   54,
#   1,
#   59,
#   8,
#   308,
#   3,
#   46,
#   1329,
#   20,
#   1330,
#   676,
#   438,
#   142,
#   41,
#   108,
#   679,
#   4,
#   1331,
#   1,
#   59,
#   3,
#   50,
#   135,
#   665,
#   523,
#   369,
#   270,
#   180,
#   18,
#   372,
#   102,
#   3,
#   158,
#   102,
#   83,
#   123,
#   180,
#   18,
#   1332,
#   1333,
#   9,
#   6,
#   156,
#   452,
#   2,
#   1334,
#   456,
#   123,
#   180,
#   227,
#   678,
#   901,
#   337,
#   895,
#   184,
#   2,
#   214,
#   140,
#   1,
#   233,
#   4,
#   1335,
#   471,
#   1,
#   418,
#   1336,
#   22,
#   130,
#   255,
#   5,
#   12,
#   261,
#   1,
#   127,
#   437,
#   677,
#   439,
#   270,
#   28,
#   31,
#   838,
#   4,
#   680,
#   471,
#   214,
#   439,
#   8,
#   6,
#   1337,
#   48,
#   23,
#   10,
#   437,
#   1338,
#   167,
#   1339,
#   345,
#   932,
#   435,
#   933,
#   3,
#   97,
#   1340,
#   435,
#   231,
#   2,
#   25,
#   439,
#   35,
#   366,
#   20,
#   29,
#   533,
#   9,
#   1,
#   431,
#   2,
#   44,
#   438,
#   142,
#   136,
#   9,
#   44,
#   92,
#   104,
#   222,
#   403,
#   21,
#   372,
#   102,
#   3,
#   158,
#   102],
#  [1341,
#   1342,
#   55,
#   111,
#   26,
#   3,
#   440,
#   296,
#   1343,
#   5,
#   12,
#   1344,
#   24,
#   1345,
#   4,
#   847,
#   681,
#   2,
#   252,
#   528,
#   5,
#   111,
#   7,
#   11,
#   161,
#   2,
#   440,
#   296,
#   297,
#   3,
#   95,
#   682,
#   15,
#   229,
#   1,
#   865,
#   2,
#   75,
#   68,
#   113,
#   58,
#   186,
#   2,
#   111,
#   298,
#   20,
#   388,
#   113,
#   6,
#   528,
#   2,
#   46,
#   3,
#   229,
#   45,
#   1346,
#   1347,
#   2,
#   75,
#   20,
#   77,
#   5,
#   1,
#   245,
#   599,
#   24,
#   1348,
#   13,
#   1,
#   111,
#   298,
#   8,
#   683,
#   1349,
#   4,
#   440,
#   296,
#   297,
#   1350,
#   10,
#   46,
#   3,
#   684,
#   12,
#   302,
#   409,
#   4,
#   1351,
#   1352,
#   1353,
#   867,
#   388,
#   2,
#   1,
#   75,
#   5,
#   1,
#   862,
#   1354,
#   4,
#   1,
#   1355,
#   297,
#   24,
#   76,
#   124,
#   13,
#   365,
#   21,
#   1,
#   252,
#   186,
#   2,
#   111,
#   7,
#   16,
#   30,
#   939,
#   20,
#   1356,
#   2,
#   1357,
#   21,
#   193,
#   613,
#   1,
#   75,
#   41,
#   1358,
#   5,
#   1,
#   629,
#   186,
#   643,
#   1359,
#   279,
#   1360,
#   685,
#   2,
#   95,
#   682,
#   1,
#   267,
#   2,
#   19,
#   7,
#   686,
#   21,
#   1361,
#   8,
#   436,
#   3,
#   105,
#   11,
#   111,
#   7,
#   5,
#   1,
#   149,
#   13,
#   111,
#   298,
#   8,
#   1362,
#   246,
#   2,
#   1363,
#   615,
#   113,
#   58,
#   1364,
#   1365,
#   872,
#   2,
#   581,
#   153,
#   2,
#   19,
#   7,
#   686,
#   21,
#   683,
#   578,
#   2,
#   111,
#   298,
#   8,
#   920,
#   1366,
#   20,
#   19,
#   941,
#   296,
#   297],
#  [36,
#   174,
#   11,
#   175,
#   74,
#   42,
#   687,
#   8,
#   22,
#   133,
#   525,
#   82,
#   273,
#   5,
#   132,
#   51,
#   82,
#   1367,
#   295,
#   5,
#   220,
#   11,
#   1368,
#   1369,
#   533,
#   114,
#   100,
#   20,
#   36,
#   1370,
#   23,
#   719,
#   144,
#   800,
#   524,
#   90,
#   229,
#   1,
#   1371,
#   2,
#   1,
#   441,
#   12,
#   442,
#   548,
#   22,
#   175,
#   23,
#   89,
#   32,
#   52,
#   9,
#   36,
#   42,
#   687,
#   11,
#   22,
#   1372,
#   175,
#   498,
#   1,
#   17,
#   16,
#   387,
#   294,
#   316,
#   718,
#   1,
#   1373,
#   441,
#   140,
#   370,
#   1374,
#   70,
#   370,
#   1375,
#   86,
#   3,
#   241,
#   1376,
#   266,
#   192,
#   42,
#   902,
#   1,
#   721,
#   2,
#   12,
#   60,
#   8,
#   4,
#   305,
#   50,
#   44,
#   283,
#   2,
#   175,
#   400,
#   4,
#   824,
#   1,
#   427,
#   2,
#   42,
#   174,
#   1,
#   1377,
#   2,
#   175,
#   9,
#   45,
#   175,
#   74,
#   8,
#   76,
#   621,
#   20,
#   22,
#   1378],
#  [495,
#   688,
#   184,
#   9,
#   36,
#   689,
#   215,
#   11,
#   44,
#   1379,
#   1380,
#   9,
#   197,
#   146,
#   538,
#   12,
#   60,
#   507,
#   10,
#   495,
#   6,
#   54,
#   2,
#   1381,
#   9,
#   36,
#   689,
#   215,
#   25,
#   6,
#   44,
#   1382,
#   52,
#   21,
#   232,
#   215,
#   9,
#   197,
#   146,
#   538,
#   5,
#   101,
#   4,
#   84,
#   1383,
#   215,
#   1384,
#   1,
#   60,
#   254,
#   263,
#   4,
#   1385,
#   1,
#   894,
#   1386,
#   215,
#   51,
#   4,
#   1387,
#   403,
#   1388,
#   3,
#   1389,
#   1390,
#   4,
#   190,
#   1,
#   559,
#   2,
#   688,
#   54,
#   582,
#   1,
#   540,
#   1391,
#   50,
#   92,
#   40,
#   23,
#   10,
#   1392,
#   79,
#   92,
#   17,
#   1393,
#   78,
#   40,
#   1394,
#   1,
#   139,
#   664,
#   1395,
#   419,
#   690,
#   44,
#   410,
#   289,
#   136,
#   1,
#   157,
#   17,
#   1396,
#   1397,
#   10,
#   154,
#   443,
#   395,
#   1398,
#   443,
#   444,
#   445,
#   1399,
#   5,
#   1400,
#   1,
#   573,
#   17,
#   802,
#   78,
#   444,
#   445,
#   3,
#   6,
#   244,
#   42,
#   919,
#   231,
#   9,
#   45,
#   134,
#   691,
#   20,
#   1,
#   1401,
#   110,
#   29,
#   431,
#   2,
#   1,
#   38,
#   322,
#   13,
#   1,
#   17,
#   759,
#   78,
#   110,
#   8,
#   61,
#   478,
#   63,
#   13,
#   460,
#   227,
#   444,
#   445],
#  [1402,
#   121,
#   153,
#   9,
#   1403,
#   185,
#   96,
#   149,
#   38,
#   2,
#   1404,
#   81,
#   96,
#   5,
#   216,
#   12,
#   168,
#   8,
#   1405,
#   4,
#   357,
#   6,
#   121,
#   23,
#   10,
#   1,
#   1406,
#   1407,
#   121,
#   332,
#   9,
#   81,
#   96,
#   5,
#   216,
#   1408,
#   81,
#   96,
#   5,
#   216,
#   18,
#   5,
#   22,
#   1409,
#   684,
#   1410,
#   15,
#   6,
#   1411,
#   2,
#   299,
#   5,
#   181,
#   1412,
#   6,
#   143,
#   125,
#   2,
#   1413,
#   3,
#   6,
#   308,
#   845,
#   930,
#   141,
#   81,
#   96,
#   18,
#   1414,
#   4,
#   1415,
#   9,
#   37,
#   1416,
#   4,
#   917,
#   221,
#   1417,
#   1,
#   442,
#   908,
#   1,
#   109,
#   9,
#   81,
#   185,
#   5,
#   1,
#   1418,
#   21,
#   855,
#   4,
#   1419,
#   114,
#   1420,
#   535,
#   299,
#   535,
#   3,
#   825,
#   2,
#   1,
#   925,
#   2,
#   1,
#   1421,
#   81,
#   96,
#   10,
#   1,
#   109,
#   1,
#   202,
#   761,
#   322,
#   1,
#   927,
#   2,
#   81,
#   185,
#   5,
#   216,
#   3,
#   5,
#   1,
#   201,
#   1,
#   37,
#   121,
#   8,
#   23,
#   10,
#   1,
#   129,
#   2,
#   675,
#   346,
#   5,
#   1,
#   81,
#   1422,
#   100,
#   20,
#   1423,
#   59,
#   1424,
#   57,
#   1425,
#   1426,
#   3,
#   330,
#   1,
#   442,
#   803,
#   458,
#   2,
#   1,
#   129,
#   2,
#   37,
#   346,
#   15,
#   1,
#   537,
#   577,
#   96,
#   799,
#   1,
#   149,
#   2,
#   1427,
#   8,
#   1428,
#   6,
#   915,
#   1429,
#   5,
#   1,
#   1430,
#   2,
#   81,
#   185,
#   1431,
#   12,
#   168,
#   568,
#   4,
#   303,
#   6,
#   37,
#   153,
#   121,
#   9,
#   81,
#   96,
#   5,
#   216],
#  [89,
#   325,
#   118,
#   27,
#   25,
#   27,
#   217,
#   27,
#   217,
#   1432,
#   1,
#   649,
#   68,
#   2,
#   209,
#   1433,
#   43,
#   8,
#   1434,
#   1435,
#   15,
#   692,
#   5,
#   819,
#   828,
#   325,
#   118,
#   10,
#   239,
#   434,
#   8,
#   328,
#   159,
#   462,
#   53,
#   1,
#   57,
#   32,
#   136,
#   4,
#   1,
#   27,
#   217,
#   4,
#   1436,
#   1,
#   693,
#   1437,
#   2,
#   1,
#   27,
#   88,
#   1,
#   139,
#   345,
#   553,
#   463,
#   1438,
#   4,
#   614,
#   6,
#   37,
#   14,
#   472,
#   5,
#   931,
#   4,
#   84,
#   1,
#   29,
#   2,
#   1,
#   27,
#   489,
#   4,
#   1,
#   37,
#   1439,
#   223,
#   1440,
#   4,
#   178,
#   6,
#   290,
#   27,
#   9,
#   1,
#   37,
#   27,
#   83,
#   223,
#   41,
#   108,
#   1441,
#   1,
#   232,
#   290,
#   27,
#   690,
#   575,
#   1,
#   1442,
#   2,
#   1443,
#   5,
#   12,
#   612,
#   6,
#   351,
#   325,
#   118,
#   332,
#   8,
#   33,
#   15,
#   25,
#   426,
#   19,
#   7,
#   694,
#   1444,
#   11,
#   769,
#   43,
#   8,
#   328,
#   5,
#   57,
#   1445,
#   179,
#   1,
#   33,
#   332,
#   680,
#   1446,
#   1,
#   209,
#   515,
#   217,
#   3,
#   1447,
#   1,
#   693,
#   1448,
#   23,
#   10,
#   1,
#   239,
#   434,
#   1,
#   128,
#   39,
#   5,
#   1,
#   168,
#   8,
#   1449,
#   515,
#   217,
#   4,
#   190,
#   1,
#   510,
#   1,
#   234,
#   310,
#   1450,
#   934,
#   935,
#   1451,
#   1452,
#   1453,
#   118,
#   818,
#   3,
#   1454,
#   1455,
#   148,
#   928,
#   24,
#   94,
#   1,
#   321,
#   4,
#   412,
#   1,
#   29,
#   222,
#   1,
#   315,
#   253,
#   43,
#   129,
#   67,
#   163,
#   213,
#   154,
#   169,
#   23,
#   3,
#   694,
#   23,
#   869],
#  [268,
#   71,
#   7,
#   94,
#   121,
#   9,
#   499,
#   156,
#   695,
#   696,
#   26,
#   12,
#   85,
#   767,
#   50,
#   240,
#   720,
#   2,
#   499,
#   268,
#   71,
#   156,
#   695,
#   696,
#   1456,
#   564,
#   71,
#   446,
#   3,
#   1457,
#   5,
#   1458,
#   1,
#   923,
#   7,
#   165,
#   2,
#   45,
#   71,
#   16,
#   30,
#   252,
#   21,
#   64,
#   1459,
#   15,
#   25,
#   22,
#   697,
#   17,
#   4,
#   806,
#   6,
#   7,
#   2,
#   331,
#   1460,
#   1461,
#   1462,
#   71,
#   446,
#   698,
#   398,
#   24,
#   303,
#   22,
#   604,
#   697,
#   17,
#   9,
#   1463,
#   852,
#   258,
#   13,
#   1464,
#   911,
#   258,
#   222,
#   193,
#   532,
#   329,
#   1465,
#   3,
#   8,
#   61,
#   203,
#   63,
#   315,
#   40,
#   4,
#   866,
#   9,
#   1,
#   699,
#   335,
#   1466,
#   1467,
#   137,
#   150,
#   700,
#   1468,
#   18,
#   494,
#   514,
#   24,
#   182,
#   6,
#   37,
#   52,
#   9,
#   268,
#   71,
#   7,
#   94,
#   25,
#   701,
#   1469,
#   258,
#   291,
#   1,
#   1470,
#   335,
#   2,
#   1471,
#   71,
#   3,
#   1472,
#   71,
#   787,
#   16,
#   30,
#   701,
#   61,
#   1473,
#   1,
#   33,
#   52,
#   76,
#   212,
#   6,
#   207,
#   273,
#   850,
#   94,
#   3,
#   576,
#   43,
#   302,
#   56,
#   33,
#   700,
#   685,
#   4,
#   1474,
#   1475,
#   7,
#   86,
#   105,
#   4,
#   532,
#   71,
#   7,
#   94,
#   52,
#   159,
#   1476,
#   7,
#   94,
#   458,
#   18,
#   477,
#   4,
#   1477,
#   1,
#   427,
#   2,
#   56,
#   33,
#   91,
#   11,
#   1478,
#   4,
#   699,
#   335,
#   698,
#   3,
#   7,
#   1479],
#  [14,
#   256,
#   9,
#   36,
#   132,
#   51,
#   82,
#   25,
#   44,
#   174,
#   174,
#   8,
#   58,
#   2,
#   1,
#   115,
#   133,
#   14,
#   525,
#   82,
#   859,
#   5,
#   1,
#   79,
#   92,
#   473,
#   3,
#   76,
#   58,
#   2,
#   1,
#   240,
#   1480,
#   618,
#   5,
#   1,
#   17,
#   29,
#   83,
#   1481,
#   492,
#   702,
#   8,
#   65,
#   1482,
#   62,
#   1,
#   75,
#   8,
#   1483,
#   3,
#   8,
#   249,
#   1484,
#   9,
#   220,
#   140,
#   22,
#   1485,
#   42,
#   1486,
#   100,
#   20,
#   36,
#   141,
#   24,
#   33,
#   22,
#   549,
#   14,
#   256,
#   48,
#   4,
#   84,
#   1,
#   455,
#   2,
#   1487,
#   174,
#   15,
#   25,
#   352,
#   702,
#   24,
#   377,
#   1,
#   29,
#   2,
#   56,
#   104,
#   10,
#   44,
#   36,
#   79,
#   92,
#   205,
#   1,
#   47,
#   679,
#   56,
#   256,
#   1488,
#   636,
#   1,
#   17,
#   61,
#   541,
#   4,
#   174,
#   235,
#   3,
#   16,
#   30,
#   630,
#   135,
#   11,
#   64,
#   14,
#   256,
#   550],
#  [496,
#   2,
#   176,
#   1489,
#   4,
#   447,
#   134,
#   1490,
#   6,
#   250,
#   38,
#   12,
#   85,
#   703,
#   6,
#   250,
#   38,
#   10,
#   1,
#   517,
#   55,
#   1,
#   428,
#   2,
#   218,
#   176,
#   3,
#   292,
#   110,
#   173,
#   218,
#   373,
#   10,
#   447,
#   134,
#   892,
#   31,
#   522,
#   9,
#   1,
#   38,
#   9,
#   1,
#   1491,
#   1,
#   1492,
#   704,
#   1493,
#   2,
#   170,
#   176,
#   765,
#   587,
#   3,
#   170,
#   36,
#   1494,
#   1495,
#   5,
#   705,
#   247,
#   18,
#   835,
#   706,
#   1496,
#   3,
#   173,
#   14,
#   35,
#   1497,
#   21,
#   367,
#   898,
#   36,
#   657,
#   45,
#   899,
#   1498,
#   1,
#   441,
#   2,
#   193,
#   706,
#   5,
#   1,
#   704,
#   5,
#   705,
#   247,
#   35,
#   1499,
#   173,
#   218,
#   1500,
#   9,
#   1,
#   99,
#   176,
#   110,
#   35,
#   903,
#   3,
#   707,
#   15,
#   25,
#   218,
#   1501,
#   337,
#   1,
#   1502,
#   88,
#   1,
#   139,
#   345,
#   292,
#   353,
#   295,
#   1,
#   543,
#   443,
#   1503,
#   31,
#   707,
#   3,
#   1504,
#   11,
#   1,
#   176,
#   14,
#   250,
#   99,
#   10,
#   1,
#   1505,
#   3,
#   681,
#   110,
#   2,
#   78,
#   218,
#   3,
#   173,
#   14,
#   35,
#   781,
#   12,
#   66,
#   212,
#   1,
#   517,
#   2,
#   1,
#   447,
#   176,
#   428,
#   848,
#   11,
#   1,
#   292,
#   1506],
#  [537,
#   14,
#   465,
#   9,
#   860,
#   211,
#   300,
#   198,
#   148,
#   5,
#   1507,
#   691,
#   918,
#   181,
#   1508,
#   109,
#   8,
#   1509,
#   1510,
#   11,
#   519,
#   1511,
#   291,
#   115,
#   692,
#   18,
#   1512,
#   11,
#   600,
#   5,
#   896,
#   1513,
#   1514,
#   295,
#   21,
#   37,
#   199,
#   5,
#   101,
#   4,
#   84,
#   1,
#   299,
#   1515,
#   211,
#   300,
#   198,
#   52,
#   13,
#   507,
#   10,
#   306,
#   199,
#   5,
#   1,
#   448,
#   1516,
#   3,
#   912,
#   1517,
#   266,
#   15,
#   1518,
#   61,
#   1519,
#   1520,
#   1521,
#   8,
#   1522,
#   1523,
#   5,
#   1524,
#   24,
#   723,
#   10,
#   1,
#   153,
#   2,
#   756,
#   465,
#   17,
#   13,
#   1525,
#   1526,
#   211,
#   300,
#   198,
#   148,
#   15,
#   916,
#   1,
#   306,
#   1527,
#   195,
#   831,
#   9,
#   300,
#   198,
#   23,
#   10,
#   1528,
#   29,
#   49,
#   3,
#   468,
#   1,
#   873,
#   1529,
#   1530,
#   159,
#   57,
#   32,
#   104,
#   1,
#   33,
#   48,
#   152,
#   6,
#   708,
#   17,
#   13,
#   1531,
#   199,
#   23,
#   10,
#   1532,
#   4,
#   1533,
#   342,
#   1534,
#   24,
#   305,
#   1,
#   33,
#   48,
#   15,
#   585,
#   22,
#   6,
#   1535,
#   305,
#   9,
#   512,
#   1536,
#   3,
#   241,
#   412,
#   160,
#   107,
#   69,
#   2,
#   709,
#   429,
#   4,
#   448,
#   710,
#   3,
#   120,
#   107,
#   211,
#   711,
#   148,
#   11,
#   1,
#   712,
#   149,
#   24,
#   162,
#   13,
#   1,
#   708,
#   17,
#   1537,
#   1538,
#   309,
#   107,
#   69,
#   2,
#   709,
#   429,
#   4,
#   448,
#   710,
#   15,
#   1539,
#   590,
#   3,
#   309,
#   711,
#   148,
#   15,
#   1540,
#   413,
#   5,
#   407,
#   2,
#   1541,
#   123,
#   380,
#   1542,
#   574,
#   4,
#   6,
#   299,
#   1543,
#   2,
#   1544,
#   1545,
#   449,
#   10,
#   1546,
#   1547,
#   88,
#   1548,
#   1549,
#   413,
#   662],
#  [177,
#   219,
#   196,
#   25,
#   1,
#   127,
#   19,
#   7,
#   12,
#   60,
#   703,
#   1,
#   396,
#   2,
#   127,
#   19,
#   7,
#   9,
#   196,
#   177,
#   219,
#   2,
#   1,
#   199,
#   5,
#   1,
#   1550,
#   378,
#   2,
#   1,
#   1551,
#   1552,
#   1553,
#   1554,
#   1555,
#   940,
#   1556,
#   49,
#   1557,
#   177,
#   1558,
#   3,
#   69,
#   2,
#   199,
#   18,
#   1,
#   75,
#   2,
#   1,
#   7,
#   13,
#   8,
#   905,
#   98,
#   11,
#   202,
#   14,
#   1,
#   66,
#   2,
#   1,
#   196,
#   8,
#   1,
#   177,
#   219,
#   1,
#   7,
#   39,
#   5,
#   12,
#   38,
#   8,
#   6,
#   50,
#   186,
#   381,
#   7,
#   3,
#   1,
#   32,
#   59,
#   8,
#   1,
#   385,
#   12,
#   7,
#   8,
#   98,
#   4,
#   30,
#   1559,
#   4,
#   840,
#   177,
#   219,
#   900,
#   9,
#   177,
#   219,
#   196,
#   2,
#   1,
#   1560,
#   449,
#   1561,
#   1562,
#   1,
#   66,
#   21,
#   127,
#   19,
#   7,
#   212,
#   61,
#   97,
#   15,
#   658,
#   1,
#   713,
#   2,
#   138,
#   88,
#   368,
#   830,
#   144,
#   1,
#   66,
#   21,
#   1563,
#   843,
#   107,
#   91,
#   41,
#   1,
#   713,
#   2,
#   138,
#   88,
#   170,
#   1564,
#   1565,
#   449],
#  [195,
#   65,
#   122,
#   878,
#   5,
#   137,
#   150,
#   86,
#   25,
#   288,
#   32,
#   19,
#   26,
#   12,
#   85,
#   33,
#   22,
#   52,
#   9,
#   195,
#   65,
#   122,
#   422,
#   5,
#   6,
#   137,
#   150,
#   87,
#   423,
#   6,
#   288,
#   32,
#   19,
#   7,
#   879,
#   31,
#   53,
#   5,
#   1,
#   126,
#   48,
#   1,
#   653,
#   2,
#   19,
#   7,
#   35,
#   654,
#   2,
#   1,
#   311,
#   2,
#   1,
#   655,
#   880,
#   1,
#   311,
#   2,
#   1,
#   422,
#   3,
#   1,
#   580,
#   881,
#   882,
#   883,
#   2,
#   137,
#   150,
#   86,
#   9,
#   45,
#   230,
#   2,
#   19,
#   194,
#   34,
#   54,
#   4,
#   160,
#   884,
#   1,
#   183,
#   31,
#   122,
#   3,
#   656,
#   342,
#   1,
#   183,
#   31,
#   65,
#   122,
#   24,
#   358,
#   885,
#   1,
#   423,
#   13,
#   41,
#   6,
#   244,
#   130,
#   255,
#   3,
#   886,
#   1,
#   87,
#   362,
#   4,
#   424,
#   887,
#   172,
#   888,
#   291,
#   172,
#   31,
#   340,
#   21,
#   120,
#   4,
#   170,
#   3,
#   424,
#   31,
#   340,
#   21,
#   172,
#   4,
#   172,
#   120,
#   103,
#   1,
#   198,
#   415,
#   889,
#   28,
#   31,
#   206,
#   9,
#   112,
#   19,
#   26,
#   1,
#   66,
#   2,
#   12,
#   60,
#   425,
#   1,
#   97,
#   2,
#   19,
#   26,
#   13,
#   890,
#   65,
#   122,
#   183],
#  [65,
#   301,
#   161,
#   14,
#   450,
#   10,
#   451,
#   276,
#   277,
#   26,
#   225,
#   155,
#   5,
#   451,
#   276,
#   277,
#   26,
#   8,
#   562,
#   248,
#   4,
#   106,
#   244,
#   641,
#   114,
#   1566,
#   327,
#   3,
#   204,
#   451,
#   1567,
#   226,
#   3,
#   185,
#   5,
#   542,
#   1568,
#   354,
#   482,
#   22,
#   1569,
#   1570,
#   3,
#   225,
#   155,
#   145,
#   24,
#   182,
#   6,
#   65,
#   301,
#   161,
#   225,
#   155,
#   145,
#   13,
#   41,
#   22,
#   203,
#   14,
#   714,
#   289,
#   3,
#   22,
#   203,
#   155,
#   74,
#   1,
#   714,
#   117,
#   289,
#   28,
#   8,
#   6,
#   893,
#   671,
#   28,
#   13,
#   1571,
#   6,
#   117,
#   4,
#   603,
#   13,
#   34,
#   1572,
#   4,
#   6,
#   1573,
#   2,
#   505,
#   1574,
#   54,
#   70,
#   90,
#   1,
#   28,
#   8,
#   6,
#   647,
#   2,
#   739,
#   23,
#   28,
#   3,
#   165,
#   23,
#   419,
#   319,
#   1575,
#   1,
#   28,
#   524,
#   90,
#   1576,
#   467,
#   301,
#   161,
#   141,
#   34,
#   16,
#   474,
#   1577,
#   6,
#   446,
#   1578,
#   103,
#   1,
#   28,
#   16,
#   1579,
#   1580,
#   14,
#   63,
#   245,
#   712,
#   104,
#   13,
#   482,
#   143,
#   1581,
#   715,
#   9,
#   478,
#   14,
#   24,
#   76,
#   182,
#   6,
#   37,
#   155,
#   1582,
#   319,
#   1583,
#   716,
#   417,
#   2,
#   6,
#   155,
#   498,
#   6,
#   1584,
#   1585,
#   74,
#   3,
#   6,
#   715,
#   74,
#   1,
#   33,
#   145,
#   1586,
#   140,
#   467,
#   301,
#   161,
#   3,
#   212,
#   225,
#   3,
#   203,
#   14,
#   450,
#   1,
#   29,
#   8,
#   377,
#   11,
#   6,
#   1587,
#   7,
#   624,
#   1588,
#   512,
#   586,
#   47,
#   124,
#   13,
#   716,
#   11,
#   1589,
#   801,
#   64,
#   315,
#   1590,
#   5,
#   407,
#   2,
#   1591,
#   1592,
#   3,
#   14,
#   450,
#   1593]]

# %%
x_indx
# Out:
# [[6,
#   541,
#   27,
#   9,
#   1594,
#   36,
#   132,
#   51,
#   82,
#   346,
#   20,
#   1,
#   452,
#   2,
#   1595,
#   347,
#   14,
#   1596,
#   34,
#   717,
#   1597,
#   133,
#   4,
#   178,
#   22,
#   542,
#   27,
#   13,
#   16,
#   59,
#   34,
#   132,
#   51,
#   82,
#   453,
#   8,
#   6,
#   1598,
#   13,
#   302,
#   6,
#   260,
#   4,
#   1599,
#   348,
#   220,
#   4,
#   454,
#   179,
#   89,
#   32,
#   40,
#   72,
#   942,
#   1600,
#   47,
#   718,
#   543,
#   179,
#   5,
#   1601,
#   100,
#   20,
#   42,
#   719,
#   943,
#   2,
#   134,
#   1602,
#   3,
#   944,
#   945,
#   1603,
#   83,
#   5,
#   73,
#   1604,
#   123,
#   33,
#   180,
#   544,
#   4,
#   454,
#   135,
#   9,
#   22,
#   453,
#   27,
#   4,
#   30,
#   1605,
#   34,
#   545,
#   946,
#   720,
#   100,
#   20,
#   349,
#   2,
#   1606,
#   3,
#   1607,
#   1608,
#   12,
#   1609,
#   60,
#   721,
#   8,
#   4,
#   303,
#   453,
#   40,
#   13,
#   16,
#   722,
#   546,
#   350,
#   4,
#   84,
#   221,
#   181,
#   201,
#   547,
#   1610,
#   5,
#   12,
#   261,
#   304,
#   182,
#   351,
#   40,
#   3,
#   1611,
#   13,
#   723,
#   10,
#   455,
#   222,
#   546,
#   350,
#   12,
#   262,
#   548,
#   352,
#   351,
#   112,
#   724,
#   3,
#   947,
#   4,
#   84,
#   1,
#   455,
#   222,
#   546,
#   350,
#   12,
#   85,
#   948,
#   75,
#   14,
#   1612,
#   724,
#   13,
#   1613,
#   112,
#   353,
#   100,
#   20,
#   1614,
#   1615,
#   3,
#   725,
#   112,
#   34,
#   948,
#   263,
#   1616,
#   1617,
#   68,
#   16,
#   84,
#   1,
#   455,
#   2,
#   42,
#   1618,
#   456,
#   34,
#   1619,
#   949,
#   183,
#   1620,
#   100,
#   20,
#   1621,
#   1622,
#   43,
#   183,
#   1,
#   949,
#   55,
#   1,
#   457,
#   350,
#   3,
#   1,
#   950,
#   1623,
#   350,
#   304,
#   76,
#   182,
#   549,
#   264,
#   550,
#   13,
#   951,
#   1,
#   952,
#   2,
#   453,
#   354,
#   15,
#   1624,
#   1625,
#   725,
#   458,
#   4,
#   1,
#   305,
#   184,
#   56,
#   725,
#   264,
#   550,
#   124,
#   13,
#   306,
#   89,
#   32,
#   40,
#   18,
#   90,
#   541,
#   222,
#   1626,
#   1627,
#   3,
#   551,
#   76,
#   124,
#   13,
#   56,
#   33,
#   112,
#   724,
#   3,
#   947,
#   16,
#   84,
#   1,
#   29,
#   113,
#   546,
#   350],
#  [265,
#   459,
#   307,
#   15,
#   25,
#   57,
#   32,
#   136,
#   9,
#   223,
#   726,
#   953,
#   27,
#   459,
#   307,
#   8,
#   6,
#   91,
#   13,
#   41,
#   73,
#   460,
#   5,
#   12,
#   461,
#   24,
#   954,
#   263,
#   34,
#   16,
#   30,
#   39,
#   4,
#   355,
#   265,
#   552,
#   2,
#   354,
#   23,
#   10,
#   202,
#   14,
#   5,
#   101,
#   4,
#   356,
#   266,
#   61,
#   203,
#   73,
#   462,
#   72,
#   53,
#   57,
#   32,
#   4,
#   355,
#   265,
#   552,
#   1,
#   955,
#   463,
#   9,
#   956,
#   60,
#   553,
#   8,
#   1628,
#   357,
#   6,
#   37,
#   953,
#   27,
#   9,
#   6,
#   156,
#   1629,
#   1630,
#   267,
#   223,
#   1631,
#   23,
#   10,
#   1,
#   1632,
#   957,
#   3,
#   958,
#   1633,
#   464,
#   1634,
#   1635,
#   6,
#   1636,
#   554,
#   10,
#   1,
#   157,
#   125,
#   1637,
#   959,
#   727,
#   960,
#   1,
#   1638,
#   14,
#   3,
#   555,
#   34,
#   4,
#   957,
#   6,
#   14,
#   1639,
#   1640,
#   728,
#   1641,
#   1,
#   14,
#   3,
#   1642,
#   1,
#   1643,
#   14,
#   4,
#   961,
#   43,
#   8,
#   39,
#   9,
#   102,
#   3,
#   465,
#   1,
#   27,
#   1644,
#   308,
#   86,
#   62,
#   556,
#   11,
#   156,
#   729,
#   43,
#   18,
#   730,
#   4,
#   355,
#   103,
#   5,
#   1,
#   1645,
#   1,
#   69,
#   2,
#   224,
#   3,
#   1,
#   69,
#   2,
#   185,
#   5,
#   1,
#   57,
#   16,
#   309,
#   70,
#   1646,
#   459,
#   307,
#   31,
#   39,
#   4,
#   355,
#   3,
#   1647,
#   1,
#   69,
#   2,
#   552,
#   15,
#   25,
#   1648,
#   4,
#   731,
#   1,
#   202,
#   265,
#   310,
#   2,
#   732,
#   3,
#   15,
#   25,
#   728,
#   4,
#   356,
#   1,
#   27,
#   61,
#   225,
#   3,
#   1649,
#   4,
#   962,
#   24,
#   53,
#   44,
#   57,
#   32,
#   104,
#   114,
#   158,
#   963,
#   964,
#   352,
#   137,
#   964,
#   3,
#   268,
#   186,
#   965,
#   4,
#   466,
#   40,
#   1,
#   1650,
#   2,
#   123,
#   40,
#   8,
#   733,
#   3,
#   105,
#   25,
#   1,
#   311,
#   2,
#   1651,
#   43,
#   18,
#   734,
#   966,
#   138,
#   3,
#   734,
#   1652,
#   138],
#  [557,
#   2,
#   22,
#   1653,
#   735,
#   736,
#   77,
#   19,
#   7,
#   735,
#   736,
#   77,
#   19,
#   7,
#   558,
#   1654,
#   8,
#   58,
#   2,
#   1,
#   115,
#   358,
#   19,
#   26,
#   11,
#   204,
#   14,
#   92,
#   3,
#   77,
#   1655,
#   226,
#   1656,
#   24,
#   737,
#   227,
#   1,
#   14,
#   92,
#   226,
#   1,
#   92,
#   559,
#   2,
#   22,
#   558,
#   7,
#   8,
#   312,
#   15,
#   1,
#   14,
#   3,
#   1,
#   967,
#   2,
#   1,
#   735,
#   736,
#   77,
#   4,
#   968,
#   6,
#   359,
#   2,
#   353,
#   1,
#   14,
#   545,
#   30,
#   1657,
#   15,
#   1,
#   139,
#   1658,
#   20,
#   1659,
#   20,
#   738,
#   140,
#   467,
#   14,
#   21,
#   1,
#   64,
#   360,
#   83,
#   1,
#   969,
#   92,
#   2,
#   1,
#   112,
#   3,
#   468,
#   14,
#   469,
#   90,
#   734,
#   13,
#   1,
#   7,
#   16,
#   970,
#   106,
#   557,
#   4,
#   1660,
#   1661,
#   228,
#   971,
#   48,
#   9,
#   972,
#   1,
#   739,
#   470,
#   2,
#   1,
#   14,
#   545,
#   30,
#   53,
#   4,
#   973,
#   471,
#   1,
#   472,
#   3,
#   967,
#   2,
#   1,
#   558,
#   361,
#   1662,
#   91,
#   8,
#   358,
#   3,
#   53,
#   4,
#   355,
#   1,
#   472,
#   3,
#   362,
#   2,
#   45,
#   558,
#   361,
#   5,
#   12,
#   85,
#   1,
#   560,
#   47,
#   124,
#   13,
#   12,
#   91,
#   561,
#   309,
#   1,
#   557],
#  [6,
#   313,
#   363,
#   23,
#   10,
#   974,
#   470,
#   975,
#   364,
#   9,
#   740,
#   205,
#   1663,
#   22,
#   740,
#   359,
#   87,
#   8,
#   6,
#   562,
#   473,
#   5,
#   181,
#   201,
#   226,
#   12,
#   87,
#   976,
#   204,
#   126,
#   40,
#   13,
#   187,
#   227,
#   1,
#   977,
#   360,
#   3,
#   544,
#   4,
#   741,
#   1,
#   363,
#   360,
#   314,
#   2,
#   1,
#   978,
#   14,
#   1,
#   364,
#   91,
#   8,
#   58,
#   2,
#   1,
#   1664,
#   563,
#   13,
#   1665,
#   1,
#   740,
#   359,
#   87,
#   83,
#   159,
#   315,
#   364,
#   180,
#   979,
#   90,
#   229,
#   1,
#   470,
#   2,
#   1,
#   230,
#   1666,
#   3,
#   742,
#   22,
#   743,
#   359,
#   87,
#   141,
#   12,
#   38,
#   1667,
#   6,
#   37,
#   364,
#   1668,
#   564,
#   313,
#   363,
#   23,
#   10,
#   974,
#   470,
#   975,
#   49,
#   4,
#   722,
#   978,
#   205,
#   56,
#   48,
#   1669,
#   14,
#   25,
#   6,
#   1670,
#   231,
#   3,
#   1671,
#   1672,
#   14,
#   744,
#   1,
#   33,
#   48,
#   1673,
#   363,
#   565,
#   23,
#   10,
#   1,
#   566,
#   470,
#   2,
#   78,
#   360,
#   1,
#   313,
#   980,
#   18,
#   567,
#   21,
#   1,
#   206,
#   1674,
#   3,
#   159,
#   363,
#   1675,
#   1676,
#   56,
#   91,
#   568,
#   4,
#   466,
#   313,
#   980,
#   13,
#   968,
#   1,
#   363,
#   359,
#   981,
#   474,
#   1,
#   569,
#   1677,
#   3,
#   475,
#   1,
#   1678,
#   2,
#   743,
#   360,
#   3,
#   1679,
#   86,
#   56,
#   33,
#   91,
#   8,
#   982,
#   25,
#   983,
#   745,
#   205,
#   3,
#   207,
#   1680,
#   103,
#   12,
#   38,
#   984,
#   1,
#   29,
#   2,
#   1,
#   48,
#   11,
#   64,
#   985,
#   232,
#   364,
#   104,
#   1,
#   746,
#   47,
#   124,
#   13,
#   56,
#   48,
#   1681,
#   188,
#   29,
#   63,
#   64,
#   364,
#   136],
#  [22,
#   542,
#   27,
#   4,
#   1682,
#   476,
#   316,
#   9,
#   986,
#   747,
#   570,
#   127,
#   19,
#   26,
#   35,
#   39,
#   4,
#   741,
#   476,
#   316,
#   23,
#   10,
#   477,
#   748,
#   2,
#   97,
#   2,
#   987,
#   571,
#   1683,
#   20,
#   135,
#   20,
#   1,
#   115,
#   478,
#   988,
#   2,
#   1,
#   987,
#   571,
#   208,
#   477,
#   1684,
#   1685,
#   3,
#   1686,
#   479,
#   19,
#   26,
#   72,
#   233,
#   4,
#   1687,
#   1688,
#   55,
#   75,
#   2,
#   570,
#   479,
#   3,
#   365,
#   2,
#   1689,
#   316,
#   2,
#   986,
#   747,
#   570,
#   15,
#   32,
#   21,
#   181,
#   565,
#   141,
#   19,
#   26,
#   35,
#   98,
#   11,
#   112,
#   3,
#   1690,
#   14,
#   184,
#   749,
#   112,
#   159,
#   19,
#   26,
#   5,
#   159,
#   1691,
#   50,
#   19,
#   26,
#   35,
#   366,
#   4,
#   317,
#   126,
#   2,
#   1692,
#   3,
#   116,
#   747,
#   570,
#   750,
#   5,
#   1,
#   157,
#   989,
#   1,
#   116,
#   19,
#   7,
#   13,
#   16,
#   187,
#   316,
#   13,
#   1693,
#   22,
#   138,
#   55,
#   269,
#   571,
#   234,
#   3,
#   1694,
#   571,
#   751,
#   63,
#   367,
#   31,
#   366,
#   1,
#   366,
#   7,
#   990,
#   983,
#   752,
#   991,
#   55,
#   1,
#   269,
#   753,
#   572,
#   3,
#   754,
#   753,
#   572,
#   1,
#   365,
#   8,
#   753,
#   20,
#   160,
#   9,
#   750,
#   13,
#   41,
#   751,
#   63,
#   367,
#   138,
#   3,
#   368,
#   1695,
#   5,
#   1,
#   573,
#   989,
#   1,
#   116,
#   19,
#   7,
#   13,
#   16,
#   187,
#   1,
#   235,
#   1696,
#   4,
#   1,
#   269,
#   235,
#   31,
#   206,
#   1,
#   366,
#   19,
#   7,
#   990,
#   480,
#   1697,
#   107,
#   966,
#   991,
#   55,
#   269,
#   3,
#   754,
#   235],
#  [755,
#   481,
#   369,
#   142,
#   9,
#   370,
#   992,
#   57,
#   57,
#   32,
#   3,
#   756,
#   993,
#   72,
#   757,
#   758,
#   39,
#   5,
#   73,
#   994,
#   759,
#   28,
#   140,
#   142,
#   481,
#   369,
#   16,
#   574,
#   4,
#   1698,
#   29,
#   2,
#   17,
#   370,
#   992,
#   57,
#   760,
#   8,
#   58,
#   2,
#   1,
#   1699,
#   23,
#   40,
#   5,
#   43,
#   1,
#   29,
#   16,
#   1700,
#   1701,
#   1702,
#   10,
#   106,
#   547,
#   142,
#   481,
#   236,
#   2,
#   1,
#   17,
#   575,
#   761,
#   161,
#   2,
#   1,
#   28,
#   103,
#   78,
#   1,
#   29,
#   3,
#   371,
#   2,
#   1,
#   142,
#   59,
#   482,
#   4,
#   30,
#   1703,
#   5,
#   995,
#   5,
#   12,
#   1704,
#   24,
#   33,
#   22,
#   52,
#   23,
#   10,
#   189,
#   28,
#   318,
#   5,
#   59,
#   2,
#   760,
#   142,
#   1,
#   318,
#   8,
#   1705,
#   39,
#   5,
#   1,
#   270,
#   1706,
#   1707,
#   314,
#   2,
#   1,
#   233,
#   4,
#   722,
#   61,
#   762,
#   86,
#   24,
#   483,
#   1,
#   318,
#   763,
#   319,
#   481,
#   189,
#   4,
#   1708,
#   1,
#   481,
#   369,
#   2,
#   760,
#   3,
#   996,
#   1,
#   116,
#   547,
#   738,
#   2,
#   1,
#   189,
#   236,
#   5,
#   484,
#   24,
#   105,
#   56,
#   116,
#   547,
#   11,
#   1,
#   47,
#   21,
#   372,
#   1709,
#   1710,
#   576,
#   3,
#   158,
#   52,
#   113,
#   577,
#   184,
#   2,
#   14,
#   56,
#   33,
#   28,
#   1711,
#   1712,
#   29,
#   3,
#   997,
#   1,
#   64,
#   104,
#   5,
#   1,
#   128,
#   11,
#   6,
#   143,
#   1713,
#   144,
#   1714,
#   1715,
#   998,
#   1716,
#   46,
#   88,
#   1,
#   1717,
#   320,
#   10,
#   1,
#   977,
#   2,
#   560,
#   205],
#  [237,
#   485,
#   3,
#   999,
#   1000,
#   5,
#   764,
#   373,
#   578,
#   3,
#   1001,
#   2,
#   764,
#   373,
#   41,
#   86,
#   374,
#   4,
#   1002,
#   945,
#   1718,
#   3,
#   237,
#   237,
#   8,
#   6,
#   1719,
#   765,
#   5,
#   1,
#   373,
#   13,
#   1720,
#   4,
#   1,
#   139,
#   1721,
#   3,
#   999,
#   766,
#   1722,
#   1003,
#   271,
#   10,
#   1723,
#   41,
#   108,
#   1724,
#   4,
#   1725,
#   12,
#   60,
#   767,
#   237,
#   485,
#   3,
#   271,
#   375,
#   5,
#   764,
#   1726,
#   25,
#   22,
#   768,
#   28,
#   114,
#   1727,
#   486,
#   1728,
#   375,
#   769,
#   770,
#   9,
#   237,
#   485,
#   3,
#   1729,
#   271,
#   375,
#   272,
#   9,
#   271,
#   375,
#   487,
#   273,
#   1730,
#   18,
#   376,
#   238,
#   79,
#   1731,
#   237,
#   1732,
#   1733,
#   264,
#   9,
#   271,
#   1004,
#   3,
#   771,
#   579,
#   1005,
#   264,
#   488,
#   3,
#   1734,
#   264,
#   1006,
#   1735,
#   1736,
#   35,
#   53,
#   4,
#   190,
#   1737,
#   271,
#   55,
#   1738,
#   3,
#   1739,
#   237,
#   1007,
#   1,
#   272,
#   29,
#   31,
#   377,
#   15,
#   1005,
#   231,
#   11,
#   1008,
#   321,
#   376,
#   10,
#   272,
#   224,
#   772,
#   10,
#   1,
#   580,
#   2,
#   1,
#   773,
#   1740,
#   49,
#   772,
#   10,
#   1,
#   1741,
#   2,
#   1,
#   1742,
#   11,
#   1743,
#   1744,
#   49,
#   3,
#   772,
#   3,
#   145,
#   1745,
#   4,
#   1,
#   774,
#   2,
#   1,
#   1746,
#   1009,
#   35,
#   1,
#   205,
#   12,
#   267,
#   322,
#   1,
#   770,
#   1747,
#   557,
#   9,
#   237,
#   485,
#   5,
#   1,
#   238,
#   378,
#   11,
#   1748,
#   1749,
#   49,
#   775,
#   1750,
#   49,
#   3,
#   1751,
#   146,
#   5,
#   1752,
#   1753,
#   3,
#   1009,
#   1754,
#   1,
#   1755,
#   579,
#   322,
#   1,
#   272,
#   1003,
#   1756,
#   271,
#   1004,
#   3,
#   117,
#   1757,
#   1,
#   272,
#   224,
#   18,
#   1758,
#   489,
#   4,
#   1,
#   771,
#   2,
#   237,
#   62,
#   379,
#   770,
#   11,
#   272,
#   1759,
#   1,
#   238,
#   79,
#   8,
#   1760,
#   3,
#   272,
#   8,
#   6,
#   490,
#   488,
#   4,
#   454,
#   238,
#   79,
#   271,
#   375,
#   1,
#   272,
#   1010,
#   749,
#   771,
#   1761,
#   1762,
#   16,
#   30,
#   53,
#   9,
#   581,
#   238,
#   79,
#   82,
#   179,
#   11,
#   19,
#   7,
#   100,
#   20,
#   238,
#   1763],
#  [239,
#   14,
#   93,
#   1764,
#   9,
#   323,
#   191,
#   307,
#   5,
#   223,
#   726,
#   27,
#   191,
#   307,
#   8,
#   1765,
#   380,
#   9,
#   7,
#   1766,
#   1767,
#   3,
#   1768,
#   6,
#   240,
#   1769,
#   5,
#   1770,
#   1771,
#   776,
#   576,
#   7,
#   582,
#   1772,
#   1011,
#   2,
#   209,
#   1773,
#   49,
#   1774,
#   489,
#   4,
#   1,
#   955,
#   463,
#   9,
#   956,
#   60,
#   553,
#   49,
#   1,
#   223,
#   726,
#   265,
#   27,
#   41,
#   959,
#   319,
#   157,
#   125,
#   1775,
#   324,
#   49,
#   43,
#   583,
#   1776,
#   584,
#   1777,
#   14,
#   21,
#   223,
#   1778,
#   3,
#   1012,
#   349,
#   1013,
#   82,
#   239,
#   14,
#   567,
#   15,
#   179,
#   585,
#   10,
#   324,
#   18,
#   777,
#   113,
#   6,
#   7,
#   4,
#   1,
#   728,
#   1,
#   239,
#   8,
#   241,
#   778,
#   3,
#   777,
#   4,
#   1,
#   961,
#   3,
#   958,
#   9,
#   1779,
#   325,
#   118,
#   156,
#   1780,
#   2,
#   239,
#   14,
#   93,
#   21,
#   324,
#   113,
#   12,
#   7,
#   274,
#   574,
#   4,
#   323,
#   191,
#   5,
#   12,
#   461,
#   24,
#   466,
#   324,
#   5,
#   6,
#   275,
#   1014,
#   4,
#   1781,
#   1,
#   239,
#   14,
#   93,
#   567,
#   15,
#   179,
#   5,
#   324,
#   3,
#   1015,
#   1,
#   14,
#   4,
#   46,
#   326,
#   40,
#   3,
#   566,
#   1782,
#   1783,
#   1784,
#   1785,
#   1786,
#   1,
#   1787,
#   40,
#   18,
#   241,
#   39,
#   4,
#   38,
#   242,
#   4,
#   242,
#   323,
#   191,
#   11,
#   75,
#   93,
#   21,
#   6,
#   156,
#   69,
#   2,
#   324,
#   5,
#   6,
#   7,
#   2,
#   1788,
#   1,
#   586,
#   47,
#   16,
#   779,
#   187,
#   1,
#   69,
#   2,
#   1789,
#   587,
#   3,
#   93,
#   1790,
#   13,
#   1,
#   7,
#   16,
#   1791,
#   9,
#   44,
#   1792,
#   2,
#   179,
#   585,
#   10,
#   324,
#   1016,
#   5,
#   101,
#   4,
#   162,
#   1,
#   116,
#   1793,
#   17,
#   105,
#   4,
#   1,
#   181,
#   1794,
#   780,
#   24,
#   781,
#   17,
#   1795,
#   3,
#   1796,
#   192,
#   1797,
#   1,
#   242,
#   4,
#   242,
#   323,
#   191,
#   3,
#   1798,
#   782,
#   2,
#   45,
#   473],
#  [129,
#   2,
#   491,
#   381,
#   26,
#   9,
#   27,
#   382,
#   77,
#   383,
#   3,
#   384,
#   80,
#   491,
#   381,
#   26,
#   9,
#   27,
#   382,
#   77,
#   383,
#   3,
#   384,
#   80,
#   18,
#   588,
#   5,
#   12,
#   60,
#   138,
#   385,
#   3,
#   1017,
#   1018,
#   104,
#   72,
#   108,
#   783,
#   4,
#   1019,
#   1,
#   19,
#   26,
#   9,
#   27,
#   382,
#   1,
#   19,
#   26,
#   18,
#   98,
#   11,
#   269,
#   386,
#   75,
#   365,
#   14,
#   4,
#   387,
#   1,
#   386,
#   388,
#   2,
#   22,
#   1020,
#   1021,
#   242,
#   1022,
#   1023,
#   27,
#   34,
#   16,
#   30,
#   389,
#   13,
#   1,
#   98,
#   19,
#   26,
#   1024,
#   492,
#   126,
#   47,
#   5,
#   78,
#   112,
#   14,
#   54,
#   3,
#   468,
#   14,
#   54,
#   11,
#   390,
#   107,
#   589,
#   138,
#   2,
#   590,
#   9,
#   77,
#   383,
#   1,
#   19,
#   26,
#   18,
#   98,
#   11,
#   784,
#   14,
#   2,
#   6,
#   1025,
#   1026,
#   1027,
#   391,
#   591,
#   5,
#   101,
#   4,
#   1028,
#   6,
#   77,
#   5,
#   1,
#   1029,
#   17,
#   80,
#   392,
#   28,
#   23,
#   10,
#   1,
#   1030,
#   393,
#   3,
#   1,
#   391,
#   393,
#   34,
#   16,
#   30,
#   389,
#   13,
#   1,
#   1031,
#   2,
#   19,
#   7,
#   1032,
#   5,
#   1,
#   392,
#   16,
#   84,
#   1,
#   392,
#   80,
#   29,
#   208,
#   1,
#   592,
#   593,
#   3,
#   54,
#   320,
#   594,
#   1033,
#   5,
#   6,
#   1034,
#   394,
#   3,
#   1,
#   1035,
#   2,
#   386,
#   17,
#   1036,
#   9,
#   384,
#   1037,
#   1,
#   19,
#   26,
#   18,
#   98,
#   4,
#   387,
#   1,
#   1038,
#   17,
#   3,
#   1,
#   395,
#   17,
#   2,
#   1,
#   591,
#   1,
#   157,
#   58,
#   8,
#   39,
#   4,
#   1039,
#   1,
#   59,
#   17,
#   3,
#   1,
#   64,
#   58,
#   8,
#   39,
#   20,
#   6,
#   210,
#   5,
#   1,
#   1040,
#   1041,
#   17,
#   80,
#   595,
#   28,
#   34,
#   16,
#   30,
#   389,
#   13,
#   1,
#   19,
#   7,
#   210,
#   23,
#   10,
#   1,
#   395,
#   17,
#   16,
#   80,
#   1,
#   391,
#   1042,
#   88,
#   106,
#   54,
#   320,
#   62,
#   1,
#   27,
#   8,
#   243,
#   11,
#   54,
#   320,
#   594,
#   83,
#   34,
#   1043,
#   228,
#   596,
#   62,
#   1,
#   27,
#   8,
#   243,
#   11,
#   592,
#   593,
#   785,
#   1,
#   1044,
#   210,
#   8,
#   786,
#   192,
#   1,
#   595,
#   80,
#   1045,
#   5,
#   101,
#   4,
#   731,
#   1046,
#   2,
#   1,
#   596,
#   20,
#   1,
#   1047,
#   1048,
#   1049,
#   80,
#   1050,
#   18,
#   493],
#  [327,
#   99,
#   3,
#   106,
#   396,
#   4,
#   119,
#   145,
#   5,
#   1051,
#   276,
#   277,
#   7,
#   1799,
#   15,
#   1800,
#   41,
#   757,
#   328,
#   5,
#   1801,
#   1802,
#   1,
#   372,
#   2,
#   597,
#   1803,
#   1804,
#   758,
#   193,
#   113,
#   201,
#   1052,
#   598,
#   329,
#   8,
#   1,
#   244,
#   1805,
#   9,
#   1806,
#   62,
#   551,
#   1807,
#   113,
#   1053,
#   378,
#   1808,
#   2,
#   1054,
#   1809,
#   1810,
#   378,
#   379,
#   276,
#   277,
#   7,
#   4,
#   1811,
#   143,
#   371,
#   3,
#   163,
#   397,
#   1052,
#   787,
#   8,
#   6,
#   278,
#   13,
#   8,
#   1812,
#   73,
#   60,
#   143,
#   1813,
#   1814,
#   599,
#   981,
#   3,
#   163,
#   598,
#   1055,
#   18,
#   600,
#   5,
#   101,
#   9,
#   1051,
#   276,
#   277,
#   7,
#   601,
#   4,
#   757,
#   1056,
#   7,
#   327,
#   3,
#   598,
#   1057,
#   18,
#   788,
#   2,
#   12,
#   262,
#   88,
#   398,
#   327,
#   1815,
#   17,
#   2,
#   6,
#   1816,
#   58,
#   602,
#   276,
#   277,
#   7,
#   31,
#   494,
#   241,
#   34,
#   31,
#   53,
#   4,
#   789,
#   1817,
#   1,
#   1818,
#   2,
#   1819,
#   566,
#   10,
#   27,
#   236,
#   2,
#   601,
#   10,
#   6,
#   597,
#   279,
#   12,
#   17,
#   16,
#   30,
#   39,
#   5,
#   7,
#   582,
#   3,
#   4,
#   190,
#   7,
#   327,
#   5,
#   204,
#   479,
#   34,
#   16,
#   76,
#   30,
#   39,
#   5,
#   7,
#   94,
#   1,
#   1820,
#   2,
#   327,
#   10,
#   7,
#   29,
#   31,
#   399,
#   3,
#   1821,
#   1822,
#   601,
#   790,
#   13,
#   1058,
#   5,
#   1823,
#   16,
#   603,
#   245,
#   3,
#   1824,
#   2,
#   45,
#   1825,
#   351,
#   329,
#   1059,
#   23,
#   119,
#   400,
#   35,
#   33,
#   4,
#   84,
#   7,
#   598,
#   1057,
#   5,
#   38,
#   37,
#   119,
#   1060,
#   24,
#   494,
#   6,
#   37,
#   329,
#   1059,
#   307,
#   17,
#   13,
#   16,
#   30,
#   53,
#   1826,
#   5,
#   1827,
#   140,
#   1828,
#   1061,
#   1062,
#   161,
#   7,
#   29,
#   16,
#   30,
#   604,
#   15,
#   1,
#   1829,
#   791,
#   2,
#   1,
#   1830,
#   1831,
#   4,
#   1832,
#   3,
#   569,
#   605,
#   369,
#   2,
#   12,
#   17,
#   24,
#   493,
#   1,
#   792,
#   119,
#   29,
#   21,
#   1,
#   267,
#   2,
#   601,
#   793,
#   1055,
#   2,
#   1833,
#   1834,
#   55,
#   1,
#   1054,
#   1835,
#   3,
#   1058],
#  [1063,
#   29,
#   264,
#   2,
#   401,
#   5,
#   7,
#   280,
#   606,
#   3,
#   281,
#   282,
#   748,
#   5,
#   68,
#   1064,
#   7,
#   15,
#   25,
#   402,
#   275,
#   29,
#   8,
#   6,
#   794,
#   1836,
#   9,
#   495,
#   68,
#   1064,
#   7,
#   1065,
#   208,
#   1,
#   607,
#   2,
#   464,
#   312,
#   1066,
#   164,
#   103,
#   1,
#   795,
#   2,
#   401,
#   5,
#   7,
#   280,
#   606,
#   3,
#   281,
#   282,
#   748,
#   1837,
#   976,
#   1,
#   29,
#   12,
#   262,
#   1838,
#   4,
#   190,
#   1,
#   29,
#   2,
#   1065,
#   208,
#   164,
#   607,
#   62,
#   207,
#   44,
#   400,
#   2,
#   401,
#   5,
#   7,
#   280,
#   147,
#   11,
#   281,
#   282,
#   125,
#   18,
#   53,
#   15,
#   25,
#   402,
#   275,
#   34,
#   76,
#   568,
#   4,
#   38,
#   1,
#   496,
#   2,
#   7,
#   165,
#   10,
#   1,
#   7,
#   29,
#   403,
#   207,
#   400,
#   1839,
#   2,
#   65,
#   497,
#   5,
#   7,
#   280,
#   147,
#   11,
#   404,
#   281,
#   282,
#   498,
#   279,
#   497,
#   5,
#   7,
#   280,
#   147,
#   11,
#   279,
#   281,
#   282,
#   125,
#   74,
#   3,
#   405,
#   497,
#   5,
#   7,
#   280,
#   147,
#   11,
#   405,
#   281,
#   282,
#   125,
#   74,
#   4,
#   190,
#   1,
#   29,
#   577,
#   29,
#   310,
#   114,
#   796,
#   1067,
#   608,
#   107,
#   1840,
#   1841,
#   1068,
#   148,
#   55,
#   80,
#   3,
#   14,
#   1069,
#   3,
#   1070,
#   329,
#   93,
#   35,
#   797,
#   1,
#   321,
#   35,
#   376,
#   5,
#   50,
#   560,
#   1842,
#   114,
#   1071,
#   23,
#   402,
#   275,
#   3,
#   798,
#   15,
#   406,
#   5,
#   45,
#   1843,
#   50,
#   44,
#   7,
#   1844,
#   35,
#   243,
#   1,
#   47,
#   124,
#   13,
#   45,
#   74,
#   41,
#   106,
#   1845,
#   3,
#   952,
#   799,
#   1,
#   7,
#   29,
#   1846,
#   4,
#   45,
#   74,
#   1847,
#   10,
#   1,
#   283,
#   2,
#   7,
#   165,
#   144,
#   1,
#   7,
#   8,
#   800,
#   1,
#   405,
#   497,
#   5,
#   7,
#   280,
#   147,
#   11,
#   405,
#   281,
#   282,
#   125,
#   74,
#   801,
#   330,
#   1848,
#   62,
#   1,
#   7,
#   717,
#   1849,
#   12,
#   74,
#   322,
#   228,
#   1850,
#   5,
#   407,
#   2,
#   1068,
#   148,
#   55,
#   80,
#   3,
#   14,
#   1069,
#   3,
#   1,
#   1070,
#   329,
#   93,
#   1,
#   65,
#   497,
#   5,
#   7,
#   280,
#   147,
#   11,
#   404,
#   281,
#   282,
#   74,
#   609,
#   1,
#   1851,
#   105,
#   4,
#   330,
#   10,
#   1,
#   64,
#   1852,
#   798,
#   15,
#   406,
#   8,
#   1853,
#   4,
#   129,
#   314,
#   34,
#   802,
#   751,
#   459,
#   3,
#   803,
#   1,
#   139,
#   47,
#   20,
#   403,
#   5,
#   1071,
#   23,
#   402,
#   275,
#   1014],
#  [804,
#   805,
#   3,
#   406,
#   610,
#   1854,
#   9,
#   499,
#   164,
#   500,
#   7,
#   1072,
#   501,
#   611,
#   93,
#   12,
#   85,
#   41,
#   502,
#   3,
#   483,
#   22,
#   503,
#   275,
#   9,
#   1073,
#   1074,
#   397,
#   1855,
#   119,
#   9,
#   501,
#   166,
#   93,
#   15,
#   25,
#   464,
#   312,
#   1066,
#   164,
#   88,
#   1,
#   500,
#   7,
#   5,
#   12,
#   612,
#   1,
#   804,
#   806,
#   2,
#   805,
#   3,
#   406,
#   610,
#   798,
#   7,
#   275,
#   8,
#   33,
#   4,
#   178,
#   22,
#   503,
#   164,
#   23,
#   500,
#   7,
#   5,
#   805,
#   3,
#   22,
#   503,
#   1856,
#   113,
#   504,
#   408,
#   1075,
#   378,
#   7,
#   1076,
#   5,
#   406,
#   610,
#   207,
#   331,
#   732,
#   18,
#   39,
#   4,
#   54,
#   246,
#   1,
#   804,
#   503,
#   164,
#   23,
#   7,
#   275,
#   1,
#   406,
#   610,
#   1077,
#   43,
#   8,
#   39,
#   4,
#   178,
#   1,
#   503,
#   1076,
#   166,
#   7,
#   8,
#   554,
#   5,
#   50,
#   331,
#   732,
#   1857,
#   3,
#   1,
#   1858,
#   331,
#   57,
#   8,
#   1859,
#   1860,
#   5,
#   1,
#   33,
#   164,
#   23,
#   500,
#   194,
#   247,
#   18,
#   207,
#   1078,
#   613,
#   4,
#   1012,
#   1,
#   166,
#   93,
#   21,
#   50,
#   166,
#   26,
#   4,
#   1,
#   796,
#   194,
#   3,
#   1861,
#   331,
#   1862,
#   807,
#   1072,
#   1,
#   402,
#   145,
#   8,
#   39,
#   4,
#   614,
#   22,
#   164,
#   23,
#   500,
#   7,
#   1,
#   1863,
#   23,
#   808,
#   164,
#   332,
#   8,
#   39,
#   20,
#   1,
#   1864,
#   401,
#   164,
#   210,
#   43,
#   1865,
#   985,
#   807,
#   224,
#   1866,
#   5,
#   207,
#   613,
#   5,
#   22,
#   349,
#   2,
#   1867,
#   615,
#   5,
#   12,
#   261,
#   1,
#   119,
#   28,
#   8,
#   23,
#   10,
#   1079,
#   323,
#   191,
#   608,
#   3,
#   1,
#   69,
#   2,
#   1080,
#   236,
#   4,
#   1081,
#   1,
#   130,
#   279,
#   9,
#   1,
#   166,
#   93,
#   70,
#   1,
#   14,
#   1082,
#   93,
#   1,
#   119,
#   28,
#   8,
#   809,
#   3,
#   1083,
#   5,
#   1,
#   401,
#   808,
#   210,
#   247,
#   18,
#   50,
#   240,
#   179,
#   9,
#   1,
#   1084,
#   1085,
#   117,
#   505,
#   4,
#   1,
#   50,
#   166,
#   26,
#   304,
#   4,
#   810,
#   1,
#   1079,
#   323,
#   191,
#   608,
#   3,
#   1,
#   69,
#   2,
#   1080,
#   1868,
#   4,
#   1086,
#   1,
#   234,
#   66,
#   4,
#   1,
#   401,
#   808,
#   210,
#   1,
#   68,
#   43,
#   8,
#   777,
#   15,
#   1,
#   1084,
#   1085,
#   117,
#   8,
#   133,
#   9,
#   1,
#   164,
#   210,
#   4,
#   1081,
#   1,
#   130,
#   279,
#   3,
#   241,
#   1869,
#   1,
#   811,
#   402,
#   1870,
#   4,
#   1,
#   807,
#   117,
#   4,
#   614,
#   1,
#   14,
#   1082,
#   5,
#   12,
#   261,
#   1,
#   234,
#   66,
#   2,
#   397,
#   812,
#   119,
#   28,
#   8,
#   1871,
#   813,
#   995,
#   8,
#   13,
#   1,
#   483,
#   119,
#   28,
#   8,
#   1073,
#   1074,
#   11,
#   1,
#   234,
#   66,
#   2,
#   1872,
#   46,
#   62,
#   1,
#   206,
#   130,
#   279,
#   8,
#   506,
#   1,
#   1873,
#   2,
#   164,
#   248,
#   4,
#   1,
#   1874,
#   2,
#   80,
#   3,
#   14,
#   1875,
#   8,
#   1,
#   794,
#   1087,
#   9,
#   409,
#   20,
#   1,
#   119,
#   167,
#   8,
#   814,
#   1876,
#   249,
#   9,
#   611,
#   166,
#   26,
#   5,
#   12,
#   168],
#  [129,
#   2,
#   491,
#   381,
#   26,
#   9,
#   27,
#   382,
#   77,
#   383,
#   3,
#   384,
#   80,
#   491,
#   381,
#   26,
#   9,
#   27,
#   382,
#   77,
#   383,
#   3,
#   384,
#   80,
#   18,
#   588,
#   5,
#   12,
#   60,
#   138,
#   385,
#   3,
#   1017,
#   1018,
#   104,
#   72,
#   108,
#   783,
#   4,
#   1019,
#   1,
#   19,
#   26,
#   9,
#   27,
#   382,
#   1,
#   19,
#   26,
#   18,
#   98,
#   11,
#   269,
#   386,
#   75,
#   365,
#   14,
#   4,
#   387,
#   1,
#   386,
#   388,
#   2,
#   22,
#   1020,
#   1021,
#   242,
#   1022,
#   1023,
#   27,
#   34,
#   16,
#   30,
#   389,
#   13,
#   1,
#   98,
#   19,
#   26,
#   1024,
#   492,
#   126,
#   47,
#   5,
#   78,
#   112,
#   14,
#   54,
#   3,
#   468,
#   14,
#   54,
#   11,
#   390,
#   107,
#   589,
#   138,
#   2,
#   590,
#   9,
#   77,
#   383,
#   1,
#   19,
#   26,
#   18,
#   98,
#   11,
#   784,
#   14,
#   2,
#   6,
#   1025,
#   1026,
#   1027,
#   391,
#   591,
#   5,
#   101,
#   4,
#   1028,
#   6,
#   77,
#   5,
#   1,
#   1029,
#   17,
#   80,
#   392,
#   28,
#   23,
#   10,
#   1,
#   1030,
#   393,
#   3,
#   1,
#   391,
#   393,
#   34,
#   16,
#   30,
#   389,
#   13,
#   1,
#   1031,
#   2,
#   19,
#   7,
#   1032,
#   5,
#   1,
#   392,
#   16,
#   84,
#   1,
#   392,
#   80,
#   29,
#   208,
#   1,
#   592,
#   593,
#   3,
#   54,
#   320,
#   594,
#   1033,
#   5,
#   6,
#   1034,
#   394,
#   3,
#   1,
#   1035,
#   2,
#   386,
#   17,
#   1036,
#   9,
#   384,
#   1037,
#   1,
#   19,
#   26,
#   18,
#   98,
#   4,
#   387,
#   1,
#   1038,
#   17,
#   3,
#   1,
#   395,
#   17,
#   2,
#   1,
#   591,
#   1,
#   157,
#   58,
#   8,
#   39,
#   4,
#   1039,
#   1,
#   59,
#   17,
#   3,
#   1,
#   64,
#   58,
#   8,
#   39,
#   20,
#   6,
#   210,
#   5,
#   1,
#   1040,
#   1041,
#   17,
#   80,
#   595,
#   28,
#   34,
#   16,
#   30,
#   389,
#   13,
#   1,
#   19,
#   7,
#   210,
#   23,
#   10,
#   1,
#   395,
#   17,
#   16,
#   80,
#   1,
#   391,
#   1042,
#   88,
#   106,
#   54,
#   320,
#   62,
#   1,
#   27,
#   8,
#   243,
#   11,
#   54,
#   320,
#   594,
#   83,
#   34,
#   1043,
#   228,
#   596,
#   62,
#   1,
#   27,
#   8,
#   243,
#   11,
#   592,
#   593,
#   785,
#   1,
#   1044,
#   210,
#   8,
#   786,
#   192,
#   1,
#   595,
#   80,
#   1045,
#   5,
#   101,
#   4,
#   731,
#   1046,
#   2,
#   1,
#   596,
#   20,
#   1,
#   1047,
#   1048,
#   1049,
#   80,
#   1050,
#   18,
#   493],
#  [616,
#   2,
#   209,
#   29,
#   9,
#   815,
#   555,
#   145,
#   6,
#   149,
#   38,
#   10,
#   816,
#   260,
#   7,
#   2,
#   1088,
#   1089,
#   12,
#   38,
#   507,
#   10,
#   616,
#   2,
#   209,
#   29,
#   9,
#   815,
#   555,
#   145,
#   1,
#   1088,
#   1089,
#   816,
#   7,
#   8,
#   206,
#   20,
#   6,
#   149,
#   38,
#   1,
#   815,
#   555,
#   145,
#   323,
#   8,
#   39,
#   15,
#   201,
#   617,
#   1090,
#   209,
#   13,
#   8,
#   1,
#   115,
#   328,
#   10,
#   817,
#   7,
#   207,
#   618,
#   35,
#   588,
#   1091,
#   1877,
#   1092,
#   1067,
#   818,
#   3,
#   508,
#   46,
#   207,
#   549,
#   7,
#   40,
#   3,
#   321,
#   35,
#   502,
#   9,
#   123,
#   26,
#   4,
#   162,
#   1,
#   476,
#   1878,
#   796,
#   1879,
#   9,
#   1,
#   116,
#   616,
#   209,
#   29,
#   2,
#   201,
#   617,
#   1090,
#   1880,
#   7,
#   782,
#   14,
#   10,
#   816,
#   7,
#   35,
#   1881,
#   243,
#   3,
#   399,
#   11,
#   971,
#   1882],
#  [6,
#   250,
#   38,
#   10,
#   1,
#   496,
#   2,
#   410,
#   1883,
#   5,
#   278,
#   284,
#   5,
#   819,
#   1884,
#   73,
#   453,
#   179,
#   274,
#   509,
#   188,
#   29,
#   15,
#   379,
#   1,
#   42,
#   411,
#   20,
#   1,
#   375,
#   2,
#   1885,
#   5,
#   12,
#   461,
#   24,
#   182,
#   89,
#   42,
#   278,
#   1886,
#   1887,
#   776,
#   820,
#   333,
#   49,
#   6,
#   1888,
#   1889,
#   59,
#   9,
#   112,
#   333,
#   11,
#   42,
#   411,
#   820,
#   333,
#   1890,
#   1,
#   1093,
#   59,
#   2,
#   22,
#   457,
#   333,
#   15,
#   1094,
#   42,
#   411,
#   91,
#   4,
#   1891,
#   1,
#   17,
#   4,
#   1892,
#   1893,
#   23,
#   411,
#   6,
#   19,
#   7,
#   8,
#   53,
#   4,
#   1,
#   1894,
#   1895,
#   1093,
#   59,
#   20,
#   813,
#   1896,
#   9,
#   42,
#   278,
#   1897,
#   6,
#   128,
#   1898,
#   21,
#   1899,
#   998,
#   3,
#   1900,
#   211,
#   1901,
#   4,
#   1902,
#   190,
#   56,
#   510,
#   1,
#   278,
#   1903,
#   1904,
#   278,
#   1905,
#   3,
#   278,
#   1011,
#   35,
#   39,
#   4,
#   412,
#   55,
#   56,
#   52,
#   3,
#   333,
#   1,
#   560,
#   66,
#   10,
#   78,
#   36,
#   3,
#   821,
#   128,
#   1906,
#   13,
#   820,
#   333,
#   609,
#   188,
#   63,
#   333,
#   10,
#   78,
#   205],
#  [1,
#   396,
#   2,
#   57,
#   32,
#   5,
#   619,
#   1095,
#   511,
#   334,
#   251,
#   620,
#   1096,
#   36,
#   1097,
#   1098,
#   11,
#   822,
#   73,
#   1097,
#   1098,
#   11,
#   822,
#   823,
#   72,
#   334,
#   251,
#   1099,
#   2,
#   334,
#   251,
#   1907,
#   18,
#   1908,
#   1100,
#   57,
#   32,
#   1101,
#   16,
#   951,
#   252,
#   1909,
#   793,
#   1910,
#   14,
#   1,
#   38,
#   1911,
#   4,
#   824,
#   729,
#   2,
#   1096,
#   36,
#   823,
#   11,
#   1095,
#   334,
#   251,
#   25,
#   1100,
#   1101,
#   822,
#   1912,
#   1913,
#   38,
#   1914,
#   36,
#   823,
#   1915,
#   1916,
#   1917,
#   334,
#   29,
#   31,
#   377,
#   15,
#   1,
#   36,
#   982,
#   1918,
#   334,
#   825,
#   1919,
#   12,
#   38,
#   621,
#   1102,
#   826,
#   1103,
#   55,
#   752,
#   3,
#   1104,
#   1,
#   231,
#   2,
#   45,
#   334,
#   71,
#   1920,
#   20,
#   285,
#   1921,
#   9,
#   1,
#   1105,
#   827,
#   28,
#   620,
#   1922,
#   1923,
#   1924,
#   1106,
#   160,
#   1103,
#   55,
#   752,
#   3,
#   1104,
#   1107,
#   1925,
#   31,
#   1926,
#   1108,
#   1927,
#   1928,
#   828,
#   1929,
#   1930,
#   480,
#   35,
#   1931,
#   1107,
#   1932,
#   31,
#   1933,
#   1108,
#   1934,
#   1935,
#   1936,
#   1937,
#   3,
#   1938,
#   1939,
#   160,
#   35,
#   1940,
#   1941,
#   1105,
#   827,
#   285,
#   1942,
#   487,
#   729,
#   2,
#   193,
#   1102,
#   1943,
#   368,
#   285,
#   160,
#   829,
#   169,
#   11,
#   511,
#   51,
#   251,
#   49,
#   1109,
#   170,
#   285,
#   120,
#   511,
#   1110,
#   1111,
#   1944,
#   169,
#   251,
#   49,
#   146,
#   120,
#   285,
#   512,
#   1945,
#   1112,
#   11,
#   511,
#   1110,
#   1111,
#   77,
#   51,
#   169,
#   251,
#   49,
#   830,
#   1113,
#   285,
#   170,
#   829,
#   51,
#   11,
#   511,
#   169,
#   251,
#   49,
#   1946,
#   480,
#   285,
#   413,
#   829,
#   51,
#   1112,
#   251,
#   6,
#   1947,
#   38,
#   8,
#   1948,
#   4,
#   741,
#   1949,
#   5,
#   1950,
#   831,
#   3,
#   1951,
#   55,
#   45,
#   285],
#  [95,
#   158,
#   622,
#   10,
#   6,
#   69,
#   1952,
#   795,
#   10,
#   44,
#   1114,
#   11,
#   832,
#   46,
#   1953,
#   513,
#   6,
#   1115,
#   260,
#   41,
#   6,
#   1116,
#   4,
#   1117,
#   6,
#   156,
#   362,
#   2,
#   14,
#   3,
#   762,
#   1954,
#   462,
#   72,
#   30,
#   1955,
#   1956,
#   4,
#   162,
#   37,
#   563,
#   95,
#   265,
#   8,
#   58,
#   2,
#   266,
#   6,
#   69,
#   2,
#   95,
#   104,
#   72,
#   108,
#   1957,
#   228,
#   2,
#   266,
#   35,
#   1958,
#   1118,
#   13,
#   551,
#   274,
#   1117,
#   86,
#   1119,
#   63,
#   221,
#   1115,
#   1120,
#   489,
#   4,
#   1,
#   1959,
#   1960,
#   6,
#   95,
#   158,
#   622,
#   41,
#   204,
#   1961,
#   103,
#   34,
#   16,
#   30,
#   6,
#   488,
#   4,
#   1962,
#   64,
#   95,
#   104,
#   5,
#   12,
#   261,
#   1,
#   58,
#   602,
#   95,
#   158,
#   622,
#   8,
#   588,
#   744,
#   1,
#   95,
#   158,
#   622,
#   286,
#   8,
#   483,
#   963,
#   21,
#   1121,
#   3,
#   1963,
#   21,
#   1964,
#   43,
#   18,
#   95,
#   150,
#   1965,
#   18,
#   996,
#   50,
#   321,
#   18,
#   376,
#   398,
#   1,
#   1122,
#   18,
#   1966,
#   10,
#   95,
#   260,
#   1114,
#   21,
#   1123,
#   3,
#   1121,
#   1,
#   623,
#   2,
#   1,
#   1122,
#   18,
#   1967,
#   1968,
#   1969,
#   3,
#   480,
#   1970,
#   245,
#   1124,
#   9,
#   45,
#   1092,
#   1,
#   286,
#   8,
#   1125,
#   11,
#   413,
#   44,
#   283,
#   2,
#   1126,
#   833,
#   1,
#   47,
#   124,
#   13,
#   265,
#   832,
#   46,
#   21,
#   1971,
#   95,
#   260,
#   624,
#   8,
#   561,
#   625,
#   63,
#   1972,
#   95,
#   260,
#   624,
#   9,
#   1,
#   139,
#   362,
#   3,
#   286,
#   834,
#   103,
#   10,
#   1,
#   139,
#   286,
#   1127,
#   6,
#   1128,
#   137,
#   1129,
#   55,
#   1,
#   265,
#   832,
#   46,
#   3,
#   1,
#   286,
#   1973,
#   8,
#   626,
#   514,
#   1,
#   139,
#   286,
#   623,
#   3,
#   283,
#   21,
#   1,
#   157,
#   267,
#   35,
#   1974,
#   10,
#   22,
#   269,
#   1123,
#   95,
#   1975,
#   944,
#   1976,
#   835,
#   1977,
#   83,
#   1,
#   1130,
#   66,
#   8,
#   227,
#   9,
#   1,
#   170,
#   1978,
#   245,
#   1979,
#   1,
#   64,
#   623,
#   2,
#   245,
#   1124,
#   627,
#   138,
#   248,
#   4,
#   1,
#   335,
#   2,
#   1,
#   95,
#   260,
#   456,
#   1,
#   1130,
#   234,
#   47,
#   18,
#   1980,
#   15,
#   1,
#   569,
#   21,
#   1,
#   515,
#   2,
#   1,
#   269,
#   95,
#   260],
#  [287,
#   836,
#   1131,
#   628,
#   15,
#   25,
#   1981,
#   336,
#   32,
#   1,
#   837,
#   87,
#   8,
#   6,
#   562,
#   473,
#   9,
#   73,
#   1132,
#   3,
#   462,
#   5,
#   1,
#   1982,
#   1983,
#   73,
#   1984,
#   2,
#   60,
#   838,
#   89,
#   32,
#   4,
#   178,
#   22,
#   1985,
#   516,
#   27,
#   115,
#   839,
#   53,
#   1,
#   1133,
#   2,
#   288,
#   32,
#   136,
#   4,
#   840,
#   1,
#   151,
#   1134,
#   3,
#   4,
#   178,
#   1,
#   516,
#   354,
#   23,
#   10,
#   1,
#   754,
#   47,
#   813,
#   758,
#   39,
#   1986,
#   8,
#   336,
#   32,
#   248,
#   4,
#   106,
#   233,
#   4,
#   1987,
#   1988,
#   1,
#   517,
#   55,
#   1,
#   109,
#   841,
#   11,
#   1,
#   130,
#   516,
#   842,
#   83,
#   34,
#   8,
#   1135,
#   1002,
#   263,
#   4,
#   178,
#   287,
#   1136,
#   336,
#   32,
#   4,
#   1137,
#   5,
#   1,
#   837,
#   109,
#   73,
#   2,
#   629,
#   253,
#   630,
#   1,
#   843,
#   107,
#   2,
#   1,
#   1133,
#   2,
#   1,
#   152,
#   4,
#   1,
#   1138,
#   77,
#   4,
#   356,
#   1,
#   336,
#   32,
#   4,
#   30,
#   287,
#   836,
#   1989,
#   12,
#   60,
#   33,
#   6,
#   351,
#   1139,
#   4,
#   178,
#   1,
#   287,
#   836,
#   336,
#   32,
#   15,
#   411,
#   1,
#   287,
#   1990,
#   192,
#   1,
#   147,
#   1991,
#   63,
#   1992,
#   1,
#   287,
#   4,
#   1,
#   1138,
#   77,
#   4,
#   12,
#   1993,
#   12,
#   168,
#   797,
#   1,
#   1140,
#   336,
#   32,
#   1994,
#   28,
#   11,
#   22,
#   1000,
#   289,
#   48,
#   23,
#   10,
#   1,
#   631,
#   605,
#   4,
#   178,
#   1,
#   287,
#   1136,
#   516,
#   27,
#   1,
#   52,
#   1141,
#   31,
#   1995,
#   1996,
#   314,
#   34,
#   39,
#   844,
#   1997,
#   1140,
#   336,
#   32,
#   11,
#   1,
#   631,
#   605,
#   147,
#   1,
#   746,
#   47,
#   5,
#   12,
#   168,
#   632,
#   13,
#   25,
#   1,
#   631,
#   605,
#   147,
#   274,
#   509,
#   61,
#   1998,
#   63,
#   25,
#   1,
#   1999,
#   147,
#   15,
#   107,
#   12,
#   168,
#   76,
#   626,
#   1,
#   1063,
#   38,
#   4,
#   954,
#   1,
#   496,
#   2,
#   1,
#   2000,
#   121,
#   180,
#   3,
#   1,
#   2001,
#   19,
#   7,
#   136,
#   10,
#   1,
#   29,
#   2,
#   56,
#   33,
#   48],
#  [414,
#   633,
#   3,
#   7,
#   165,
#   12,
#   262,
#   212,
#   37,
#   746,
#   2002,
#   9,
#   1,
#   1129,
#   55,
#   7,
#   634,
#   3,
#   414,
#   152,
#   5,
#   2003,
#   1142,
#   1143,
#   3,
#   1144,
#   629,
#   254,
#   162,
#   13,
#   6,
#   7,
#   2,
#   627,
#   316,
#   212,
#   1,
#   2004,
#   845,
#   2005,
#   2,
#   1,
#   2006,
#   109,
#   12,
#   635,
#   636,
#   1,
#   7,
#   634,
#   6,
#   2007,
#   2008,
#   337,
#   43,
#   22,
#   338,
#   518,
#   2009,
#   12,
#   7,
#   410,
#   16,
#   2010,
#   70,
#   2011,
#   1,
#   338,
#   518,
#   10,
#   1,
#   27,
#   617,
#   125,
#   141,
#   1,
#   2012,
#   2013,
#   2,
#   1,
#   1145,
#   414,
#   633,
#   40,
#   8,
#   90,
#   2014,
#   1056,
#   20,
#   1,
#   338,
#   518,
#   717,
#   61,
#   380,
#   62,
#   2015,
#   11,
#   1,
#   7,
#   637,
#   23,
#   10,
#   12,
#   338,
#   518,
#   415,
#   2016,
#   12,
#   262,
#   2017,
#   1,
#   637,
#   2,
#   2018,
#   3,
#   638,
#   192,
#   1,
#   414,
#   633,
#   40,
#   5,
#   12,
#   2019,
#   6,
#   151,
#   7,
#   8,
#   1125,
#   21,
#   1,
#   2020,
#   750,
#   2021,
#   2,
#   151,
#   152,
#   13,
#   8,
#   778,
#   15,
#   6,
#   7,
#   28,
#   2022,
#   1,
#   2023,
#   2024,
#   1,
#   778,
#   58,
#   2025,
#   227,
#   1,
#   639,
#   68,
#   640,
#   1,
#   2026,
#   61,
#   2027,
#   34,
#   2028,
#   409,
#   4,
#   466,
#   6,
#   2029,
#   7,
#   2,
#   43,
#   73,
#   7,
#   641,
#   16,
#   30,
#   2030,
#   1,
#   133,
#   7,
#   641,
#   39,
#   5,
#   12,
#   262,
#   18,
#   7,
#   165,
#   3,
#   151,
#   638,
#   1,
#   7,
#   165,
#   1146,
#   1,
#   642,
#   2,
#   2031,
#   43,
#   469,
#   30,
#   768,
#   192,
#   6,
#   2032,
#   643,
#   7,
#   70,
#   846,
#   2033,
#   192,
#   6,
#   2034,
#   643,
#   7,
#   45,
#   642,
#   41,
#   44,
#   233,
#   4,
#   2035,
#   1,
#   338,
#   518,
#   415,
#   1,
#   151,
#   638,
#   1146,
#   1,
#   589,
#   1147,
#   2,
#   1,
#   151,
#   5,
#   50,
#   2036,
#   1,
#   157,
#   1148,
#   8,
#   1,
#   2037,
#   233,
#   4,
#   1147,
#   1,
#   64,
#   1149,
#   5,
#   1,
#   7,
#   144,
#   1,
#   64,
#   1148,
#   8,
#   106,
#   2038,
#   4,
#   2039,
#   2040,
#   1,
#   794,
#   635,
#   2,
#   12,
#   262,
#   8,
#   13,
#   1,
#   637,
#   2,
#   7,
#   634,
#   18,
#   2041,
#   380,
#   4,
#   847,
#   70,
#   187,
#   414,
#   152,
#   5,
#   1,
#   409,
#   2042,
#   304,
#   38,
#   1,
#   1149,
#   2043,
#   5,
#   587,
#   2044,
#   3,
#   162,
#   13,
#   1,
#   7,
#   2045,
#   733,
#   15,
#   2046,
#   253,
#   848,
#   11,
#   1,
#   338,
#   1150,
#   733,
#   15,
#   107,
#   151,
#   2047,
#   4,
#   187,
#   152,
#   10,
#   1,
#   109,
#   1131,
#   456,
#   10,
#   1,
#   1142,
#   837,
#   1143,
#   1,
#   7,
#   637,
#   72,
#   408,
#   4,
#   187,
#   1,
#   566,
#   2,
#   2048,
#   519,
#   152,
#   62,
#   556,
#   11,
#   1,
#   338,
#   287,
#   810,
#   43,
#   8,
#   107,
#   2049,
#   2,
#   151,
#   109,
#   152,
#   1016,
#   5,
#   151,
#   1151,
#   2,
#   2050,
#   304,
#   162,
#   13,
#   1,
#   2051,
#   2052,
#   15,
#   1,
#   7,
#   2053,
#   2054,
#   2055,
#   152,
#   13,
#   849,
#   30,
#   2056,
#   15,
#   1,
#   1145,
#   414,
#   633,
#   17,
#   1,
#   143,
#   850,
#   133,
#   96,
#   72,
#   625,
#   152,
#   63,
#   1,
#   504,
#   2057,
#   1,
#   96,
#   11,
#   143,
#   2058,
#   125,
#   72,
#   1152,
#   152,
#   63,
#   1,
#   330,
#   103,
#   1,
#   7,
#   638,
#   469,
#   30,
#   2059,
#   5,
#   2060,
#   1,
#   851,
#   2061,
#   792,
#   152,
#   5,
#   1144],
#  [6,
#   153,
#   2,
#   1,
#   171,
#   118,
#   28,
#   9,
#   195,
#   490,
#   2062,
#   1153,
#   357,
#   6,
#   1154,
#   396,
#   150,
#   2063,
#   1155,
#   9,
#   1156,
#   129,
#   8,
#   1157,
#   171,
#   5,
#   1,
#   1154,
#   1155,
#   8,
#   1,
#   115,
#   2064,
#   87,
#   314,
#   24,
#   849,
#   162,
#   1,
#   171,
#   5,
#   1,
#   396,
#   3,
#   2065,
#   9,
#   2066,
#   2067,
#   2068,
#   10,
#   1,
#   153,
#   1158,
#   8,
#   846,
#   1152,
#   3,
#   61,
#   762,
#   1159,
#   171,
#   5,
#   2069,
#   1158,
#   2,
#   1,
#   464,
#   153,
#   2070,
#   852,
#   70,
#   25,
#   1160,
#   99,
#   8,
#   1,
#   644,
#   61,
#   853,
#   513,
#   24,
#   1135,
#   979,
#   90,
#   603,
#   263,
#   2071,
#   460,
#   1,
#   2072,
#   1159,
#   171,
#   5,
#   1,
#   2073,
#   854,
#   25,
#   1160,
#   99,
#   8,
#   56,
#   289,
#   9,
#   12,
#   60,
#   24,
#   72,
#   1161,
#   809,
#   1,
#   171,
#   118,
#   28,
#   13,
#   2074,
#   1,
#   2075,
#   2,
#   487,
#   171,
#   479,
#   15,
#   2076,
#   2077,
#   1162,
#   5,
#   855,
#   3,
#   50,
#   854,
#   2078,
#   15,
#   2079,
#   2080,
#   1162,
#   5,
#   2081,
#   24,
#   789,
#   520,
#   171,
#   479,
#   13,
#   18,
#   1,
#   2082,
#   645,
#   1,
#   2083,
#   101,
#   2084,
#   394,
#   70,
#   1,
#   2085,
#   856,
#   2086,
#   645,
#   1,
#   2087,
#   645,
#   1,
#   950,
#   645,
#   1,
#   65,
#   2088,
#   856,
#   394,
#   3,
#   1,
#   2089,
#   856,
#   394,
#   5,
#   484,
#   24,
#   303,
#   1,
#   2090,
#   2,
#   1,
#   171,
#   118,
#   488,
#   4,
#   2091,
#   1,
#   129,
#   2,
#   1,
#   171,
#   118,
#   28,
#   1,
#   66,
#   2,
#   1,
#   795,
#   2,
#   1,
#   171,
#   118,
#   28,
#   3,
#   1,
#   171,
#   118,
#   488,
#   18,
#   2092,
#   3,
#   317,
#   969,
#   66,
#   20,
#   792],
#  [416,
#   46,
#   326,
#   14,
#   196,
#   23,
#   10,
#   619,
#   857,
#   5,
#   91,
#   3,
#   2093,
#   19,
#   7,
#   17,
#   12,
#   262,
#   858,
#   1,
#   87,
#   2,
#   416,
#   46,
#   326,
#   126,
#   15,
#   284,
#   1,
#   196,
#   2,
#   159,
#   132,
#   3,
#   521,
#   2094,
#   1,
#   993,
#   417,
#   2,
#   50,
#   240,
#   859,
#   1,
#   157,
#   273,
#   8,
#   4,
#   355,
#   1,
#   522,
#   416,
#   353,
#   43,
#   18,
#   358,
#   20,
#   339,
#   14,
#   70,
#   339,
#   418,
#   1,
#   573,
#   273,
#   8,
#   4,
#   187,
#   37,
#   14,
#   23,
#   10,
#   1,
#   1163,
#   2,
#   1,
#   14,
#   493,
#   21,
#   1,
#   157,
#   273,
#   56,
#   255,
#   8,
#   4,
#   303,
#   6,
#   37,
#   19,
#   7,
#   17,
#   9,
#   196,
#   416,
#   46,
#   326,
#   14,
#   3,
#   860,
#   1,
#   97,
#   2,
#   126,
#   50,
#   19,
#   7,
#   40,
#   18,
#   33,
#   398,
#   204,
#   1120,
#   2,
#   2095,
#   23,
#   28,
#   3,
#   2096,
#   1164,
#   2097,
#   18,
#   39,
#   4,
#   2098,
#   1,
#   416,
#   14,
#   184,
#   1,
#   404,
#   26,
#   18,
#   98,
#   15,
#   288,
#   491,
#   965,
#   2099,
#   11,
#   2100,
#   2101,
#   2102,
#   1,
#   646,
#   2103,
#   8,
#   39,
#   9,
#   1,
#   647,
#   2,
#   1,
#   404,
#   26,
#   24,
#   1141,
#   12,
#   834,
#   2,
#   7,
#   857,
#   5,
#   2104,
#   646,
#   48,
#   2105,
#   2106,
#   26,
#   514,
#   45,
#   404,
#   7,
#   460,
#   6,
#   1165,
#   1166,
#   508,
#   17,
#   4,
#   454,
#   1,
#   126,
#   1,
#   572,
#   2,
#   193,
#   404,
#   19,
#   26,
#   18,
#   630,
#   15,
#   1,
#   189,
#   28,
#   23,
#   1167,
#   19,
#   7,
#   646,
#   48,
#   2107,
#   24,
#   2108,
#   12,
#   7,
#   20,
#   6,
#   2109,
#   339,
#   14,
#   1165,
#   1166,
#   508,
#   1167,
#   646,
#   2110,
#   2111,
#   7,
#   103,
#   24,
#   33,
#   6,
#   37,
#   857,
#   5,
#   91,
#   13,
#   8,
#   604,
#   9,
#   972,
#   339,
#   418,
#   23,
#   10,
#   619,
#   91,
#   9,
#   2112,
#   1,
#   642,
#   2,
#   416,
#   46,
#   326,
#   14,
#   1,
#   240,
#   2113,
#   8,
#   1,
#   46,
#   326,
#   14,
#   18,
#   2114,
#   192,
#   2115,
#   2116,
#   2,
#   44,
#   623,
#   2117,
#   141,
#   45,
#   648,
#   16,
#   30,
#   2118,
#   20,
#   6,
#   1168,
#   1,
#   861,
#   2,
#   339,
#   565,
#   8,
#   1169,
#   15,
#   635,
#   6,
#   649,
#   648,
#   862,
#   4,
#   1,
#   339,
#   2119,
#   648,
#   3,
#   2120,
#   1,
#   339,
#   565,
#   21,
#   12,
#   649,
#   648,
#   1,
#   861,
#   97,
#   2,
#   1,
#   33,
#   419,
#   564,
#   340,
#   1168,
#   619,
#   2121,
#   28,
#   8,
#   1170,
#   70,
#   188,
#   63,
#   1,
#   330,
#   523,
#   180,
#   100,
#   20,
#   1,
#   1164,
#   2122,
#   1,
#   352,
#   861,
#   2123,
#   49,
#   3,
#   1,
#   130,
#   2124,
#   121,
#   2125,
#   1171,
#   827,
#   28,
#   2126,
#   5,
#   149,
#   2,
#   1,
#   65,
#   2127,
#   46,
#   326,
#   14],
#  [94,
#   3,
#   153,
#   2,
#   1172,
#   117,
#   3,
#   1173,
#   117,
#   9,
#   1174,
#   234,
#   166,
#   7,
#   1,
#   232,
#   1175,
#   7,
#   524,
#   90,
#   317,
#   1,
#   1176,
#   233,
#   3,
#   8,
#   90,
#   1177,
#   9,
#   1,
#   65,
#   2128,
#   650,
#   1178,
#   24,
#   182,
#   6,
#   1075,
#   166,
#   7,
#   9,
#   1175,
#   290,
#   3,
#   1053,
#   1179,
#   27,
#   9,
#   2129,
#   463,
#   3,
#   2130,
#   650,
#   11,
#   106,
#   163,
#   154,
#   14,
#   2131,
#   1180,
#   1,
#   1174,
#   234,
#   166,
#   7,
#   16,
#   30,
#   768,
#   5,
#   73,
#   60,
#   2132,
#   249,
#   5,
#   2133,
#   2134,
#   4,
#   583,
#   1,
#   14,
#   11,
#   6,
#   651,
#   2135,
#   485,
#   2136,
#   4,
#   1,
#   232,
#   48,
#   348,
#   863,
#   11,
#   106,
#   1176,
#   1180,
#   1,
#   7,
#   302,
#   1,
#   242,
#   650,
#   9,
#   188,
#   290,
#   3,
#   2137,
#   221,
#   27,
#   61,
#   814,
#   3,
#   2138,
#   12,
#   7,
#   8,
#   864,
#   4,
#   178,
#   3,
#   302,
#   1,
#   242,
#   650,
#   4,
#   865,
#   1,
#   1181,
#   3,
#   864,
#   4,
#   2139,
#   1,
#   27,
#   15,
#   25,
#   1,
#   2140,
#   91,
#   3,
#   233,
#   4,
#   54,
#   246,
#   37,
#   1181,
#   21,
#   1,
#   472,
#   34,
#   16,
#   30,
#   39,
#   20,
#   2141,
#   70,
#   2142,
#   7,
#   15,
#   2143,
#   476,
#   2144,
#   346,
#   3,
#   419,
#   24,
#   16,
#   866,
#   1,
#   408,
#   2145,
#   2,
#   1,
#   27,
#   5,
#   12,
#   261,
#   24,
#   867,
#   5,
#   2146,
#   640,
#   2147,
#   3,
#   464,
#   1182,
#   9,
#   357,
#   12,
#   7,
#   1172,
#   3,
#   1173,
#   224],
#  [79,
#   420,
#   10,
#   197,
#   146,
#   421,
#   513,
#   1,
#   2148,
#   2,
#   1183,
#   2149,
#   70,
#   197,
#   146,
#   88,
#   1,
#   242,
#   2,
#   2150,
#   247,
#   41,
#   108,
#   22,
#   1157,
#   452,
#   2,
#   421,
#   640,
#   197,
#   2151,
#   3,
#   34,
#   1184,
#   6,
#   163,
#   46,
#   9,
#   2152,
#   4,
#   1185,
#   1,
#   2153,
#   59,
#   34,
#   3,
#   2154,
#   133,
#   68,
#   21,
#   34,
#   141,
#   755,
#   79,
#   420,
#   8,
#   811,
#   5,
#   12,
#   868,
#   20,
#   34,
#   16,
#   779,
#   409,
#   59,
#   68,
#   1119,
#   3,
#   129,
#   34,
#   4,
#   356,
#   188,
#   2155,
#   1153,
#   247,
#   18,
#   50,
#   240,
#   869,
#   4,
#   755,
#   79,
#   420,
#   1186,
#   3,
#   870,
#   1186,
#   79,
#   420,
#   8,
#   376,
#   15,
#   195,
#   133,
#   2156,
#   2,
#   1,
#   79,
#   3,
#   2157,
#   6,
#   2158,
#   2,
#   1007,
#   21,
#   1,
#   457,
#   79,
#   870,
#   79,
#   420,
#   8,
#   2159,
#   4,
#   1,
#   348,
#   48,
#   20,
#   34,
#   8,
#   1,
#   2160,
#   70,
#   2161,
#   23,
#   10,
#   1001,
#   3,
#   578,
#   2,
#   1,
#   79,
#   25,
#   132,
#   51,
#   82,
#   136,
#   5,
#   12,
#   461,
#   24,
#   53,
#   22,
#   870,
#   420,
#   48,
#   10,
#   6,
#   871,
#   2162,
#   1091,
#   2163,
#   155,
#   2164,
#   2165,
#   421,
#   128,
#   640,
#   197,
#   146,
#   421,
#   14,
#   256,
#   31,
#   76,
#   2166,
#   5,
#   1,
#   525,
#   82,
#   943,
#   4,
#   30,
#   22,
#   872,
#   149,
#   2,
#   556,
#   11,
#   14,
#   13,
#   18,
#   90,
#   1187,
#   70,
#   2167,
#   1188,
#   50,
#   163,
#   213,
#   154,
#   169,
#   67,
#   1189,
#   11,
#   3,
#   140,
#   14,
#   1190,
#   35,
#   39,
#   4,
#   2168,
#   1191,
#   1,
#   873,
#   1191,
#   35,
#   399,
#   3,
#   105,
#   11,
#   374,
#   168,
#   25,
#   1192,
#   2169,
#   1006,
#   9,
#   2170,
#   264,
#   2171,
#   310],
#  [341,
#   526,
#   652,
#   7,
#   94,
#   2,
#   1193,
#   59,
#   527,
#   874,
#   15,
#   526,
#   652,
#   7,
#   8,
#   1,
#   133,
#   2172,
#   5,
#   2173,
#   59,
#   1,
#   527,
#   2174,
#   2175,
#   4,
#   1,
#   1194,
#   3,
#   469,
#   742,
#   1,
#   59,
#   61,
#   308,
#   4,
#   1195,
#   1,
#   230,
#   393,
#   141,
#   5,
#   101,
#   4,
#   970,
#   390,
#   527,
#   874,
#   3,
#   2176,
#   230,
#   2177,
#   88,
#   221,
#   1196,
#   2178,
#   1,
#   341,
#   526,
#   652,
#   7,
#   13,
#   16,
#   2179,
#   875,
#   18,
#   133,
#   12,
#   461,
#   1,
#   341,
#   526,
#   652,
#   7,
#   94,
#   2180,
#   1197,
#   15,
#   2181,
#   2182,
#   8,
#   129,
#   4,
#   94,
#   341,
#   7,
#   9,
#   1,
#   1193,
#   59,
#   1198,
#   59,
#   5,
#   359,
#   304,
#   87,
#   1,
#   2183,
#   642,
#   2184,
#   1126,
#   52,
#   3,
#   1,
#   526,
#   876,
#   415,
#   91,
#   18,
#   639,
#   52,
#   1199,
#   2185,
#   9,
#   1,
#   1198,
#   59,
#   18,
#   2186,
#   4,
#   30,
#   1,
#   877,
#   26,
#   9,
#   1195,
#   230,
#   393,
#   3,
#   76,
#   2187,
#   390,
#   527,
#   874,
#   2188,
#   1,
#   877,
#   236,
#   2,
#   341,
#   26,
#   18,
#   2189,
#   4,
#   412,
#   3,
#   206,
#   1,
#   116,
#   341,
#   7,
#   5,
#   101,
#   4,
#   960,
#   341,
#   194,
#   6,
#   1137,
#   1200,
#   55,
#   371,
#   3,
#   877,
#   469,
#   30,
#   1182,
#   1,
#   2190,
#   528,
#   1201,
#   30,
#   786,
#   5,
#   1,
#   7,
#   9,
#   2191,
#   2192,
#   11,
#   1,
#   875,
#   3,
#   864,
#   4,
#   94,
#   80,
#   634,
#   4,
#   1,
#   7],
#  [195,
#   65,
#   122,
#   878,
#   5,
#   137,
#   150,
#   86,
#   25,
#   288,
#   32,
#   19,
#   26,
#   12,
#   85,
#   33,
#   22,
#   52,
#   9,
#   195,
#   65,
#   122,
#   422,
#   5,
#   6,
#   137,
#   150,
#   87,
#   423,
#   6,
#   288,
#   32,
#   19,
#   7,
#   879,
#   31,
#   53,
#   5,
#   1,
#   126,
#   48,
#   1,
#   653,
#   2,
#   19,
#   7,
#   35,
#   654,
#   2,
#   1,
#   311,
#   2,
#   1,
#   655,
#   880,
#   1,
#   311,
#   2,
#   1,
#   422,
#   3,
#   1,
#   580,
#   881,
#   882,
#   883,
#   2,
#   137,
#   150,
#   86,
#   9,
#   45,
#   230,
#   2,
#   19,
#   194,
#   34,
#   54,
#   4,
#   160,
#   884,
#   1,
#   183,
#   31,
#   122,
#   3,
#   656,
#   342,
#   1,
#   183,
#   31,
#   65,
#   122,
#   24,
#   358,
#   885,
#   1,
#   423,
#   13,
#   41,
#   6,
#   244,
#   130,
#   255,
#   3,
#   886,
#   1,
#   87,
#   362,
#   4,
#   424,
#   887,
#   172,
#   888,
#   291,
#   172,
#   31,
#   340,
#   21,
#   120,
#   4,
#   170,
#   3,
#   424,
#   31,
#   340,
#   21,
#   172,
#   4,
#   172,
#   120,
#   103,
#   1,
#   198,
#   415,
#   889,
#   28,
#   31,
#   206,
#   9,
#   112,
#   19,
#   26,
#   1,
#   66,
#   2,
#   12,
#   60,
#   425,
#   1,
#   97,
#   2,
#   19,
#   26,
#   13,
#   890,
#   65,
#   122,
#   183],
#  [292,
#   4,
#   343,
#   891,
#   25,
#   89,
#   32,
#   52,
#   12,
#   85,
#   33,
#   6,
#   134,
#   892,
#   1202,
#   17,
#   25,
#   6,
#   893,
#   32,
#   121,
#   1,
#   17,
#   626,
#   1,
#   894,
#   343,
#   230,
#   2,
#   2193,
#   2194,
#   2195,
#   25,
#   6,
#   89,
#   32,
#   17,
#   1,
#   17,
#   31,
#   98,
#   11,
#   6,
#   313,
#   128,
#   2196,
#   21,
#   1,
#   895,
#   657,
#   3,
#   529,
#   1203,
#   1197,
#   5,
#   6,
#   2197,
#   6,
#   2198,
#   343,
#   2199,
#   33,
#   14,
#   896,
#   180,
#   2200,
#   343,
#   788,
#   3,
#   784,
#   2201,
#   2202,
#   2203,
#   40,
#   12,
#   48,
#   31,
#   502,
#   4,
#   2204,
#   738,
#   134,
#   875,
#   2205,
#   82,
#   14,
#   1190,
#   584,
#   1204,
#   49,
#   569,
#   2206,
#   3,
#   2207,
#   2208,
#   31,
#   53,
#   4,
#   1,
#   313,
#   128,
#   1,
#   38,
#   105,
#   44,
#   17,
#   2209,
#   584,
#   1204,
#   49,
#   1205,
#   505,
#   510,
#   426,
#   510,
#   3,
#   530,
#   17,
#   1,
#   486,
#   163,
#   213,
#   154,
#   169,
#   530,
#   19,
#   7,
#   997,
#   64,
#   1189,
#   658,
#   487,
#   486,
#   2210,
#   11,
#   2211,
#   2212,
#   3,
#   897,
#   531,
#   5,
#   45,
#   186,
#   659,
#   134,
#   21,
#   1008,
#   898,
#   36,
#   657,
#   31,
#   39,
#   4,
#   2213,
#   190,
#   1,
#   2214,
#   427,
#   3,
#   2215,
#   45,
#   659,
#   2216,
#   2217,
#   36,
#   2218,
#   529,
#   2219,
#   43,
#   31,
#   6,
#   647,
#   2,
#   6,
#   49,
#   304,
#   49,
#   2220,
#   49,
#   584,
#   49,
#   2221,
#   49,
#   2222,
#   49,
#   2223,
#   49,
#   656,
#   49,
#   3,
#   2224,
#   2225,
#   247,
#   35,
#   2226,
#   1206,
#   2227,
#   899,
#   1,
#   33,
#   17,
#   900,
#   1207,
#   343,
#   788,
#   21,
#   1,
#   659,
#   36,
#   529,
#   1206,
#   1,
#   38,
#   581,
#   399,
#   1,
#   2228,
#   2229,
#   25,
#   6,
#   529,
#   2230,
#   17,
#   144,
#   12,
#   17,
#   31,
#   2231,
#   195,
#   1,
#   529,
#   21,
#   6,
#   477,
#   2232,
#   1,
#   307,
#   66,
#   21,
#   1,
#   292,
#   4,
#   343,
#   891,
#   1208,
#   17,
#   31,
#   90,
#   1187,
#   1,
#   66,
#   425,
#   13,
#   1,
#   891,
#   134,
#   21,
#   1,
#   1207,
#   230,
#   343,
#   31,
#   2233,
#   658,
#   1209,
#   1113,
#   2234,
#   55,
#   1,
#   457,
#   659,
#   134,
#   3,
#   1,
#   313,
#   134,
#   21,
#   1,
#   1208,
#   17],
#  [151,
#   109,
#   428,
#   126,
#   25,
#   2235,
#   89,
#   32,
#   17,
#   11,
#   1210,
#   3,
#   347,
#   68,
#   151,
#   109,
#   126,
#   8,
#   308,
#   314,
#   2236,
#   18,
#   2237,
#   3,
#   2238,
#   15,
#   73,
#   618,
#   2239,
#   73,
#   254,
#   1211,
#   4,
#   187,
#   151,
#   109,
#   2240,
#   25,
#   89,
#   32,
#   52,
#   123,
#   126,
#   40,
#   783,
#   50,
#   283,
#   2,
#   75,
#   20,
#   160,
#   1210,
#   68,
#   2,
#   202,
#   1134,
#   3,
#   1212,
#   2241,
#   3,
#   120,
#   347,
#   68,
#   114,
#   421,
#   2242,
#   70,
#   2243,
#   83,
#   115,
#   2,
#   1,
#   254,
#   2244,
#   10,
#   126,
#   17,
#   153,
#   23,
#   10,
#   6,
#   532,
#   75,
#   1127,
#   144,
#   1132,
#   399,
#   109,
#   167,
#   23,
#   10,
#   6,
#   1213,
#   2,
#   68,
#   5,
#   12,
#   612,
#   24,
#   33,
#   6,
#   89,
#   19,
#   7,
#   9,
#   151,
#   109,
#   2245,
#   43,
#   16,
#   901,
#   78,
#   283,
#   2,
#   653,
#   1,
#   33,
#   17,
#   417,
#   2,
#   426,
#   19,
#   7,
#   3,
#   163,
#   213,
#   154,
#   169,
#   3,
#   1184,
#   2246,
#   411,
#   902,
#   903,
#   21,
#   421,
#   2247,
#   202,
#   2248,
#   353,
#   3,
#   6,
#   54,
#   2,
#   1212,
#   533,
#   20,
#   75,
#   103,
#   24,
#   76,
#   2249,
#   6,
#   37,
#   655,
#   77,
#   13,
#   16,
#   84,
#   2250,
#   627,
#   23,
#   10,
#   516,
#   2251,
#   15,
#   25,
#   631,
#   608,
#   43,
#   8,
#   6,
#   810,
#   2,
#   627,
#   589,
#   4,
#   1150,
#   3,
#   851,
#   2252],
#  [7,
#   628,
#   147,
#   9,
#   743,
#   55,
#   2253,
#   3,
#   501,
#   26,
#   5,
#   904,
#   27,
#   62,
#   1,
#   7,
#   782,
#   2254,
#   1214,
#   3,
#   397,
#   86,
#   2255,
#   744,
#   1,
#   7,
#   849,
#   905,
#   2256,
#   1215,
#   2,
#   906,
#   513,
#   1,
#   904,
#   27,
#   41,
#   380,
#   226,
#   1216,
#   793,
#   1,
#   2257,
#   123,
#   86,
#   16,
#   30,
#   2258,
#   1217,
#   5,
#   228,
#   2259,
#   429,
#   785,
#   1218,
#   7,
#   11,
#   606,
#   17,
#   31,
#   33,
#   5,
#   12,
#   85,
#   1,
#   47,
#   72,
#   942,
#   13,
#   11,
#   1,
#   476,
#   628,
#   2,
#   1216,
#   226,
#   337,
#   6,
#   7,
#   147,
#   20,
#   135,
#   20,
#   2260,
#   2,
#   459,
#   776,
#   15,
#   2261,
#   6,
#   501,
#   7,
#   113,
#   1,
#   457,
#   2262,
#   7,
#   16,
#   2263,
#   2264,
#   29,
#   15,
#   2265,
#   1,
#   1214,
#   3,
#   397,
#   86,
#   141,
#   12,
#   60,
#   41,
#   1161,
#   1118,
#   13,
#   1218,
#   7,
#   11,
#   606,
#   8,
#   1,
#   203,
#   255,
#   11,
#   371,
#   427,
#   10,
#   1,
#   7,
#   628,
#   147,
#   9,
#   1,
#   904,
#   27],
#  [1219,
#   430,
#   660,
#   907,
#   235,
#   10,
#   1,
#   661,
#   2266,
#   11,
#   430,
#   2267,
#   6,
#   617,
#   1062,
#   2,
#   226,
#   16,
#   30,
#   483,
#   10,
#   2268,
#   661,
#   2269,
#   430,
#   660,
#   2270,
#   854,
#   11,
#   1,
#   430,
#   660,
#   946,
#   1178,
#   1,
#   661,
#   331,
#   57,
#   1220,
#   16,
#   1185,
#   3,
#   2271,
#   131,
#   973,
#   193,
#   1083,
#   131,
#   78,
#   1221,
#   3,
#   506,
#   131,
#   18,
#   2272,
#   10,
#   1,
#   1077,
#   2273,
#   506,
#   131,
#   18,
#   2274,
#   15,
#   1,
#   1220,
#   248,
#   4,
#   907,
#   235,
#   3,
#   66,
#   5,
#   2275,
#   1222,
#   1,
#   1222,
#   21,
#   123,
#   131,
#   2276,
#   246,
#   4,
#   2277,
#   120,
#   662,
#   2278,
#   70,
#   2279,
#   120,
#   662,
#   5,
#   12,
#   261,
#   24,
#   182,
#   2280,
#   6,
#   2281,
#   28,
#   9,
#   1219,
#   661,
#   430,
#   660,
#   907,
#   2282,
#   43,
#   41,
#   50,
#   400,
#   398,
#   344,
#   548,
#   13,
#   906,
#   1086,
#   131,
#   11,
#   1,
#   390,
#   534,
#   2283,
#   4,
#   474,
#   349,
#   2,
#   534,
#   235,
#   83,
#   12,
#   47,
#   5,
#   22,
#   2284,
#   143,
#   2285,
#   2286,
#   62,
#   131,
#   544,
#   514,
#   344,
#   908,
#   131,
#   319,
#   4,
#   45,
#   48,
#   5,
#   430,
#   2287,
#   3,
#   2288,
#   6,
#   48,
#   20,
#   6,
#   48,
#   11,
#   6,
#   143,
#   2289,
#   148,
#   342,
#   1,
#   69,
#   2,
#   506,
#   131,
#   2290,
#   2291,
#   2292,
#   12,
#   74,
#   2293,
#   906,
#   21,
#   663,
#   3,
#   2294,
#   9,
#   131,
#   13,
#   18,
#   2295,
#   4,
#   544,
#   24,
#   2296,
#   321,
#   4,
#   190,
#   1,
#   29,
#   2,
#   344,
#   15,
#   2297,
#   131,
#   5,
#   6,
#   2298,
#   7,
#   1,
#   47,
#   124,
#   13,
#   344,
#   16,
#   475,
#   506,
#   131,
#   246,
#   4,
#   1223,
#   1106,
#   105,
#   4,
#   663,
#   208,
#   909,
#   1224,
#   5,
#   1151,
#   9,
#   6,
#   579,
#   5,
#   1221,
#   131,
#   15,
#   160,
#   775,
#   1,
#   452,
#   2,
#   534,
#   39,
#   15,
#   344,
#   8,
#   227,
#   58,
#   2299,
#   105,
#   4,
#   663,
#   208,
#   909,
#   1224,
#   663,
#   131,
#   11,
#   1,
#   390,
#   534,
#   5,
#   344,
#   2300,
#   349,
#   2,
#   534,
#   235,
#   15,
#   1223,
#   1109,
#   5,
#   484,
#   344,
#   16,
#   1225,
#   246,
#   4,
#   2301,
#   2302,
#   1226,
#   1209,
#   910,
#   2,
#   2303,
#   5,
#   1,
#   2304,
#   909,
#   117,
#   3,
#   897,
#   1227,
#   1226,
#   897,
#   1227,
#   5,
#   1,
#   2305,
#   911,
#   2306,
#   117],
#  [405,
#   270,
#   2,
#   530,
#   19,
#   26,
#   6,
#   431,
#   2,
#   1,
#   189,
#   28,
#   3,
#   432,
#   102,
#   4,
#   789,
#   1,
#   1139,
#   2,
#   379,
#   189,
#   28,
#   3,
#   432,
#   102,
#   5,
#   635,
#   1,
#   405,
#   1228,
#   5,
#   530,
#   19,
#   7,
#   241,
#   1,
#   66,
#   8,
#   105,
#   11,
#   2307,
#   1,
#   2308,
#   48,
#   1,
#   66,
#   2309,
#   13,
#   189,
#   28,
#   3,
#   432,
#   102,
#   16,
#   779,
#   530,
#   19,
#   7,
#   609,
#   188,
#   63,
#   385,
#   12,
#   8,
#   314,
#   1,
#   189,
#   28,
#   41,
#   6,
#   851,
#   113,
#   863,
#   4,
#   2310,
#   1200,
#   2,
#   1013,
#   1228,
#   2311,
#   432,
#   102,
#   2312,
#   432,
#   2313,
#   4,
#   2314,
#   912,
#   2315,
#   102,
#   20,
#   135,
#   20,
#   25,
#   163,
#   154,
#   169,
#   4,
#   356,
#   1,
#   2316,
#   2317,
#   83,
#   189,
#   28,
#   3,
#   432,
#   102,
#   2318,
#   61,
#   46,
#   4,
#   162,
#   349,
#   1,
#   255,
#   5,
#   6,
#   213,
#   46,
#   2319,
#   385,
#   16,
#   162,
#   6,
#   255,
#   5,
#   228,
#   128,
#   188,
#   63,
#   330],
#  [2320,
#   913,
#   119,
#   87,
#   11,
#   730,
#   46,
#   914,
#   15,
#   189,
#   28,
#   5,
#   1,
#   664,
#   2321,
#   1,
#   371,
#   579,
#   9,
#   2322,
#   1,
#   2323,
#   4,
#   199,
#   8,
#   2324,
#   4,
#   1225,
#   1,
#   2325,
#   2,
#   1,
#   915,
#   513,
#   2326,
#   2327,
#   204,
#   913,
#   119,
#   86,
#   2328,
#   72,
#   108,
#   2329,
#   2330,
#   4,
#   84,
#   1,
#   2331,
#   3,
#   4,
#   475,
#   1,
#   664,
#   371,
#   2,
#   1,
#   2332,
#   620,
#   2333,
#   913,
#   119,
#   87,
#   11,
#   46,
#   914,
#   1229,
#   8,
#   58,
#   2,
#   1,
#   115,
#   543,
#   1230,
#   1231,
#   3,
#   58,
#   2,
#   1,
#   115,
#   2334,
#   1231,
#   5,
#   1,
#   181,
#   201,
#   149,
#   254,
#   5,
#   12,
#   2335,
#   1229,
#   11,
#   730,
#   46,
#   914,
#   8,
#   2336,
#   15,
#   357,
#   6,
#   1156,
#   189,
#   28,
#   318,
#   49,
#   654,
#   2,
#   6,
#   87,
#   871,
#   2337,
#   863,
#   3,
#   520,
#   44,
#   1232,
#   833,
#   1,
#   33,
#   318,
#   41,
#   188,
#   47,
#   11,
#   1,
#   2338,
#   1232,
#   620,
#   520,
#   833,
#   144,
#   916,
#   1,
#   37,
#   3,
#   188,
#   110,
#   5,
#   156,
#   102,
#   599,
#   1,
#   47,
#   2,
#   1,
#   28,
#   18,
#   243,
#   10,
#   1,
#   328,
#   1233,
#   745,
#   2339,
#   211,
#   205,
#   1,
#   47,
#   124,
#   13,
#   1,
#   33,
#   318,
#   8,
#   2340,
#   1170,
#   11,
#   1,
#   116,
#   665,
#   563,
#   10,
#   1,
#   1171,
#   54,
#   2,
#   1233,
#   745,
#   3,
#   846,
#   188,
#   63,
#   1,
#   116,
#   665,
#   563,
#   10,
#   1,
#   2341,
#   3,
#   2342,
#   184,
#   1,
#   2343,
#   2344,
#   12,
#   60,
#   8,
#   4,
#   162,
#   6,
#   37,
#   87,
#   871,
#   1203,
#   2,
#   318,
#   9,
#   1230,
#   2345,
#   71,
#   43,
#   16,
#   72,
#   1,
#   1196,
#   572,
#   13,
#   16,
#   30,
#   53,
#   5,
#   115,
#   2,
#   1,
#   181,
#   201,
#   129,
#   429],
#  [22,
#   99,
#   10,
#   7,
#   3,
#   165,
#   2,
#   238,
#   433,
#   25,
#   79,
#   1234,
#   3,
#   1235,
#   52,
#   1,
#   69,
#   2,
#   433,
#   5,
#   6,
#   128,
#   1078,
#   10,
#   1,
#   817,
#   8,
#   616,
#   83,
#   1,
#   1116,
#   2,
#   25,
#   347,
#   68,
#   494,
#   21,
#   433,
#   5,
#   14,
#   99,
#   575,
#   61,
#   988,
#   46,
#   3,
#   552,
#   20,
#   1,
#   14,
#   917,
#   22,
#   99,
#   2,
#   1,
#   433,
#   5,
#   6,
#   128,
#   16,
#   30,
#   376,
#   25,
#   64,
#   283,
#   2,
#   110,
#   12,
#   85,
#   626,
#   6,
#   250,
#   38,
#   10,
#   433,
#   11,
#   2346,
#   1,
#   99,
#   2347,
#   36,
#   238,
#   433,
#   20,
#   6,
#   128,
#   1,
#   14,
#   35,
#   522,
#   21,
#   22,
#   68,
#   209,
#   27,
#   2,
#   1,
#   2348,
#   2349,
#   2,
#   918,
#   2350,
#   1,
#   38,
#   797,
#   79,
#   1234,
#   3,
#   7,
#   99,
#   4,
#   509,
#   2351,
#   21,
#   1,
#   373,
#   1,
#   99,
#   48,
#   621,
#   505,
#   919,
#   535,
#   1235,
#   2352,
#   3,
#   2353,
#   1010,
#   1,
#   38,
#   76,
#   2354,
#   22,
#   68,
#   1236,
#   27,
#   21,
#   1,
#   7,
#   110,
#   493,
#   21,
#   1,
#   7,
#   99,
#   1,
#   264,
#   632,
#   22,
#   309,
#   5,
#   1,
#   29,
#   749,
#   1094,
#   1,
#   7,
#   110,
#   11,
#   347,
#   110,
#   12,
#   920,
#   1,
#   490,
#   1087,
#   2,
#   25,
#   7,
#   110,
#   5,
#   6,
#   181,
#   201,
#   68,
#   1236,
#   27],
#  [2355,
#   257,
#   200,
#   10,
#   504,
#   408,
#   3,
#   666,
#   26,
#   11,
#   93,
#   812,
#   1237,
#   28,
#   25,
#   667,
#   668,
#   74,
#   504,
#   408,
#   3,
#   666,
#   26,
#   921,
#   18,
#   26,
#   291,
#   193,
#   1,
#   2356,
#   3,
#   611,
#   922,
#   18,
#   556,
#   10,
#   6,
#   1238,
#   2357,
#   2358,
#   3,
#   250,
#   527,
#   248,
#   4,
#   1,
#   2359,
#   2360,
#   2,
#   921,
#   26,
#   100,
#   20,
#   1238,
#   2361,
#   666,
#   615,
#   3,
#   2362,
#   2,
#   923,
#   2363,
#   1179,
#   1239,
#   16,
#   2364,
#   62,
#   119,
#   5,
#   22,
#   921,
#   7,
#   1,
#   119,
#   145,
#   9,
#   504,
#   408,
#   3,
#   666,
#   26,
#   536,
#   31,
#   809,
#   4,
#   2365,
#   1,
#   1215,
#   2,
#   352,
#   226,
#   5,
#   1,
#   994,
#   2,
#   501,
#   166,
#   26,
#   2366,
#   3,
#   817,
#   2,
#   2367,
#   611,
#   228,
#   166,
#   224,
#   5,
#   6,
#   536,
#   7,
#   18,
#   90,
#   2368,
#   1188,
#   4,
#   2369,
#   6,
#   1213,
#   2,
#   2370,
#   100,
#   20,
#   6,
#   257,
#   200,
#   12,
#   834,
#   2,
#   200,
#   16,
#   924,
#   1,
#   7,
#   15,
#   2371,
#   70,
#   5,
#   2372,
#   11,
#   64,
#   1239,
#   1,
#   2373,
#   16,
#   814,
#   466,
#   1240,
#   167,
#   3,
#   16,
#   742,
#   1217,
#   1241,
#   21,
#   1,
#   7,
#   3,
#   191,
#   2,
#   2374,
#   1242,
#   2,
#   1,
#   7,
#   93,
#   20,
#   1,
#   924,
#   2,
#   257,
#   200,
#   5,
#   1,
#   536,
#   7,
#   8,
#   651,
#   537,
#   3,
#   34,
#   636,
#   6,
#   143,
#   925,
#   4,
#   1,
#   194,
#   245,
#   2,
#   1,
#   200,
#   117,
#   8,
#   651,
#   133,
#   5,
#   1,
#   194,
#   3,
#   34,
#   16,
#   356,
#   6,
#   2375,
#   7,
#   1241,
#   3,
#   191,
#   1,
#   143,
#   2376,
#   2,
#   93,
#   191,
#   12,
#   85,
#   254,
#   1,
#   924,
#   2,
#   257,
#   200,
#   5,
#   536,
#   26,
#   3,
#   33,
#   1,
#   2377,
#   3,
#   651,
#   853,
#   644,
#   2,
#   926,
#   74,
#   4,
#   1243,
#   13,
#   257,
#   200,
#   56,
#   33,
#   2378,
#   2379,
#   6,
#   667,
#   668,
#   927,
#   9,
#   45,
#   773,
#   117,
#   5,
#   1,
#   7,
#   62,
#   1,
#   165,
#   8,
#   54,
#   2380,
#   8,
#   1,
#   853,
#   644,
#   4,
#   926,
#   1,
#   257,
#   200,
#   12,
#   85,
#   76,
#   2381,
#   1,
#   93,
#   876,
#   2382,
#   2,
#   1,
#   7,
#   15,
#   379,
#   93,
#   812,
#   1237,
#   28,
#   1244,
#   379,
#   1,
#   1244,
#   5,
#   1,
#   536,
#   7,
#   165,
#   8,
#   6,
#   492,
#   644,
#   4,
#   737,
#   1,
#   1245,
#   93,
#   876,
#   2,
#   56,
#   14,
#   1202,
#   194,
#   474,
#   1,
#   2383,
#   55,
#   773,
#   224,
#   3,
#   668,
#   117,
#   1061,
#   3,
#   475,
#   1,
#   46,
#   3,
#   397,
#   2,
#   1,
#   7,
#   47,
#   124,
#   13,
#   24,
#   16,
#   1243,
#   1,
#   257,
#   200,
#   3,
#   1205,
#   2384,
#   1,
#   1245,
#   2385,
#   2,
#   1,
#   7,
#   3,
#   12,
#   85,
#   984,
#   1,
#   69,
#   2,
#   46,
#   1246,
#   3,
#   1242,
#   191,
#   5,
#   78,
#   1060,
#   11,
#   3,
#   140,
#   667,
#   2386,
#   208,
#   257,
#   200,
#   3,
#   1099,
#   2,
#   46,
#   1246,
#   431,
#   2,
#   58,
#   1240,
#   167,
#   4,
#   2387,
#   1,
#   559,
#   2,
#   56,
#   33,
#   48,
#   3,
#   586,
#   928,
#   24,
#   16,
#   2388,
#   13,
#   56,
#   667,
#   668,
#   257,
#   200,
#   926,
#   74,
#   8,
#   2389,
#   135,
#   15,
#   2390,
#   1,
#   2391,
#   47],
#  [929,
#   99,
#   2,
#   434,
#   10,
#   1247,
#   374,
#   4,
#   197,
#   146,
#   25,
#   89,
#   32,
#   52,
#   1,
#   2392,
#   930,
#   2,
#   1,
#   1183,
#   146,
#   197,
#   146,
#   538,
#   8,
#   6,
#   2393,
#   3,
#   2394,
#   737,
#   73,
#   962,
#   5,
#   407,
#   2,
#   2395,
#   18,
#   811,
#   4,
#   475,
#   1,
#   2396,
#   2,
#   2397,
#   144,
#   2398,
#   72,
#   2399,
#   337,
#   44,
#   2400,
#   551,
#   2401,
#   221,
#   2402,
#   3,
#   1194,
#   10,
#   521,
#   2403,
#   249,
#   10,
#   1247,
#   197,
#   146,
#   374,
#   434,
#   16,
#   2404,
#   521,
#   2405,
#   12,
#   38,
#   609,
#   929,
#   99,
#   10,
#   1248,
#   3,
#   2406,
#   266,
#   192,
#   1199,
#   360,
#   2,
#   1128,
#   3,
#   519,
#   2407,
#   1249,
#   2,
#   2408,
#   2409,
#   2410,
#   2411,
#   2412,
#   3,
#   2413,
#   24,
#   399,
#   78,
#   347,
#   68,
#   3,
#   202,
#   14,
#   24,
#   522,
#   2414,
#   244,
#   1248,
#   205,
#   55,
#   160,
#   2415,
#   931,
#   3,
#   2416,
#   2417,
#   2418,
#   24,
#   105,
#   1,
#   29,
#   2,
#   487,
#   19,
#   7,
#   40,
#   43,
#   18,
#   268,
#   186,
#   2419,
#   2420,
#   1250,
#   486,
#   1250,
#   3,
#   2421,
#   11,
#   159,
#   310,
#   1249,
#   2,
#   932,
#   435,
#   933,
#   934,
#   3,
#   1192,
#   1,
#   47,
#   124,
#   13,
#   67,
#   454,
#   1,
#   116,
#   10,
#   2422,
#   11,
#   2423,
#   480,
#   144,
#   486,
#   67,
#   17,
#   1169,
#   1,
#   2424,
#   231,
#   10,
#   310,
#   11,
#   1251,
#   10,
#   935,
#   775,
#   10,
#   435,
#   231,
#   3,
#   1251,
#   10,
#   97,
#   123,
#   40,
#   274,
#   30,
#   39,
#   4,
#   2425,
#   1,
#   428,
#   2,
#   519,
#   2426,
#   5,
#   484,
#   24,
#   317,
#   1177,
#   2427,
#   21,
#   929,
#   99,
#   11,
#   2428,
#   14,
#   3,
#   202,
#   2429,
#   2,
#   2430,
#   2431,
#   3,
#   2432,
#   14],
#  [127,
#   936,
#   3,
#   539,
#   937,
#   5,
#   2433,
#   6,
#   38,
#   10,
#   1,
#   258,
#   2,
#   2434,
#   3,
#   2435,
#   2436,
#   15,
#   259,
#   354,
#   144,
#   1,
#   2437,
#   2,
#   127,
#   936,
#   2438,
#   2439,
#   2440,
#   2441,
#   5,
#   2442,
#   2443,
#   2444,
#   2445,
#   1,
#   2446,
#   2447,
#   1,
#   2448,
#   2,
#   123,
#   37,
#   2449,
#   88,
#   1,
#   2450,
#   18,
#   2451,
#   2452,
#   3,
#   2453,
#   600,
#   4,
#   1,
#   841,
#   1,
#   87,
#   2,
#   263,
#   24,
#   1015,
#   1,
#   232,
#   938,
#   2,
#   1252,
#   3,
#   1,
#   394,
#   2,
#   2454,
#   9,
#   259,
#   567,
#   253,
#   2455,
#   6,
#   2456,
#   278,
#   228,
#   2457,
#   2458,
#   13,
#   1253,
#   868,
#   436,
#   15,
#   259,
#   1201,
#   90,
#   30,
#   2459,
#   539,
#   258,
#   10,
#   1,
#   2460,
#   13,
#   259,
#   8,
#   90,
#   6,
#   348,
#   826,
#   274,
#   2461,
#   20,
#   2462,
#   2,
#   253,
#   88,
#   1,
#   139,
#   345,
#   64,
#   2463,
#   2464,
#   13,
#   1,
#   157,
#   259,
#   104,
#   35,
#   436,
#   3,
#   2465,
#   15,
#   6,
#   132,
#   2466,
#   2467,
#   826,
#   939,
#   2468,
#   3,
#   2469,
#   259,
#   4,
#   2470,
#   10,
#   2471,
#   179,
#   2472,
#   34,
#   2473,
#   13,
#   1,
#   2474,
#   168,
#   940,
#   545,
#   30,
#   2475,
#   2476,
#   4,
#   941,
#   539,
#   1253,
#   868,
#   11,
#   1,
#   2477,
#   20,
#   22,
#   2478,
#   348,
#   540,
#   12,
#   85,
#   727,
#   2479,
#   4,
#   2480,
#   1,
#   232,
#   938,
#   2,
#   1,
#   306,
#   539,
#   841,
#   5,
#   2481,
#   258,
#   4,
#   253,
#   436,
#   15,
#   6,
#   348,
#   540,
#   3,
#   2482,
#   1,
#   2483,
#   2,
#   937,
#   5,
#   2484,
#   4,
#   2485,
#   1,
#   37,
#   1163,
#   2,
#   2486,
#   2487,
#   15,
#   127,
#   936,
#   259,
#   5,
#   484,
#   12,
#   38,
#   727,
#   1211,
#   4,
#   317,
#   238,
#   2488,
#   10,
#   263,
#   306,
#   539,
#   937,
#   16,
#   30,
#   53,
#   4,
#   253,
#   436,
#   15,
#   259,
#   342,
#   1,
#   938,
#   2,
#   1252,
#   2489,
#   2490,
#   4,
#   2491,
#   259,
#   20,
#   22,
#   540,
#   2,
#   253]]

# %%
x_indx_test
# Out:
# [[57,
#   32,
#   1254,
#   4,
#   1255,
#   1,
#   293,
#   167,
#   2,
#   1256,
#   1257,
#   669,
#   1258,
#   1,
#   1259,
#   8,
#   6,
#   521,
#   1260,
#   13,
#   1261,
#   11,
#   106,
#   1262,
#   62,
#   1263,
#   5,
#   106,
#   204,
#   766,
#   1264,
#   1265,
#   1266,
#   1267,
#   1268,
#   4,
#   1269,
#   68,
#   100,
#   20,
#   597,
#   1270,
#   1,
#   1271,
#   286,
#   2,
#   1272,
#   1273,
#   3,
#   293,
#   5,
#   508,
#   4,
#   1274,
#   20,
#   6,
#   780,
#   1275,
#   72,
#   108,
#   1276,
#   5,
#   1277,
#   254,
#   4,
#   1278,
#   173,
#   14,
#   5,
#   101,
#   4,
#   1279,
#   1,
#   490,
#   774,
#   2,
#   1,
#   1280,
#   12,
#   38,
#   858,
#   1,
#   91,
#   2,
#   6,
#   92,
#   17,
#   9,
#   293,
#   167,
#   5,
#   1281,
#   1282,
#   1283,
#   1284,
#   669,
#   1285,
#   208,
#   44,
#   1286,
#   1,
#   290,
#   922,
#   35,
#   554,
#   4,
#   583,
#   293,
#   842,
#   374,
#   4,
#   221,
#   1287,
#   167,
#   6,
#   69,
#   2,
#   410,
#   1288,
#   136,
#   5,
#   1,
#   173,
#   82,
#   35,
#   1289,
#   114,
#   213,
#   46,
#   1290,
#   1291,
#   1292,
#   670,
#   1293,
#   1294,
#   3,
#   670,
#   1295,
#   103,
#   78,
#   1,
#   523,
#   3,
#   89,
#   32,
#   23,
#   92,
#   40,
#   35,
#   243,
#   114,
#   1,
#   607,
#   1296,
#   1297,
#   671,
#   1298,
#   158,
#   1299,
#   3,
#   426,
#   19,
#   26,
#   1,
#   116,
#   17,
#   31,
#   206,
#   23,
#   10,
#   50,
#   1300,
#   1301,
#   1,
#   672,
#   69,
#   2,
#   236,
#   3,
#   1302,
#   673,
#   97,
#   1,
#   47,
#   632,
#   13,
#   1,
#   58,
#   602,
#   19,
#   7,
#   98,
#   11,
#   1,
#   1303,
#   71,
#   1304,
#   13,
#   417,
#   2,
#   120,
#   252,
#   1305,
#   910,
#   224,
#   9,
#   45,
#   1306,
#   3,
#   6,
#   672,
#   2,
#   1307,
#   1308,
#   236,
#   274,
#   317,
#   1,
#   116,
#   97],
#  [36,
#   294,
#   42,
#   67,
#   51,
#   40,
#   11,
#   531,
#   3,
#   674,
#   1309,
#   248,
#   4,
#   1,
#   675,
#   2,
#   163,
#   213,
#   154,
#   169,
#   361,
#   7,
#   67,
#   43,
#   8,
#   6,
#   763,
#   2,
#   89,
#   361,
#   194,
#   34,
#   8,
#   1310,
#   4,
#   30,
#   639,
#   4,
#   1,
#   1311,
#   2,
#   132,
#   51,
#   82,
#   249,
#   51,
#   284,
#   73,
#   839,
#   53,
#   67,
#   4,
#   17,
#   73,
#   135,
#   312,
#   220,
#   3,
#   509,
#   29,
#   5,
#   154,
#   2,
#   97,
#   83,
#   12,
#   37,
#   52,
#   8,
#   1312,
#   53,
#   4,
#   36,
#   51,
#   1313,
#   1,
#   790,
#   2,
#   36,
#   51,
#   8,
#   561,
#   44,
#   63,
#   64,
#   135,
#   312,
#   1314,
#   295,
#   821,
#   70,
#   1315,
#   23,
#   220,
#   12,
#   85,
#   53,
#   67,
#   5,
#   51,
#   284,
#   4,
#   187,
#   1,
#   1316,
#   42,
#   5,
#   1,
#   1317,
#   520,
#   67,
#   40,
#   72,
#   108,
#   502,
#   3,
#   105,
#   1,
#   47,
#   11,
#   42,
#   125,
#   67,
#   17,
#   1,
#   267,
#   425,
#   13,
#   294,
#   42,
#   67,
#   16,
#   84,
#   1,
#   29,
#   2,
#   132,
#   51,
#   284,
#   1318,
#   10,
#   36,
#   128,
#   249,
#   62,
#   25,
#   294,
#   42,
#   67,
#   11,
#   531,
#   791,
#   2,
#   368,
#   1319,
#   3,
#   674,
#   1320,
#   1,
#   1321,
#   8,
#   625,
#   63,
#   673,
#   42,
#   125,
#   67,
#   246,
#   4,
#   844,
#   367],
#  [676,
#   214,
#   142,
#   25,
#   1,
#   127,
#   437,
#   677,
#   28,
#   438,
#   142,
#   1322,
#   130,
#   214,
#   62,
#   112,
#   6,
#   57,
#   32,
#   17,
#   1323,
#   22,
#   270,
#   77,
#   41,
#   108,
#   1324,
#   1325,
#   1326,
#   678,
#   229,
#   73,
#   184,
#   2,
#   418,
#   13,
#   1327,
#   1,
#   214,
#   9,
#   1,
#   57,
#   32,
#   40,
#   3,
#   1328,
#   115,
#   130,
#   54,
#   1,
#   59,
#   8,
#   308,
#   3,
#   46,
#   1329,
#   20,
#   1330,
#   676,
#   438,
#   142,
#   41,
#   108,
#   679,
#   4,
#   1331,
#   1,
#   59,
#   3,
#   50,
#   135,
#   665,
#   523,
#   369,
#   270,
#   180,
#   18,
#   372,
#   102,
#   3,
#   158,
#   102,
#   83,
#   123,
#   180,
#   18,
#   1332,
#   1333,
#   9,
#   6,
#   156,
#   452,
#   2,
#   1334,
#   456,
#   123,
#   180,
#   227,
#   678,
#   901,
#   337,
#   895,
#   184,
#   2,
#   214,
#   140,
#   1,
#   233,
#   4,
#   1335,
#   471,
#   1,
#   418,
#   1336,
#   22,
#   130,
#   255,
#   5,
#   12,
#   261,
#   1,
#   127,
#   437,
#   677,
#   439,
#   270,
#   28,
#   31,
#   838,
#   4,
#   680,
#   471,
#   214,
#   439,
#   8,
#   6,
#   1337,
#   48,
#   23,
#   10,
#   437,
#   1338,
#   167,
#   1339,
#   345,
#   932,
#   435,
#   933,
#   3,
#   97,
#   1340,
#   435,
#   231,
#   2,
#   25,
#   439,
#   35,
#   366,
#   20,
#   29,
#   533,
#   9,
#   1,
#   431,
#   2,
#   44,
#   438,
#   142,
#   136,
#   9,
#   44,
#   92,
#   104,
#   222,
#   403,
#   21,
#   372,
#   102,
#   3,
#   158,
#   102],
#  [1341,
#   1342,
#   55,
#   111,
#   26,
#   3,
#   440,
#   296,
#   1343,
#   5,
#   12,
#   1344,
#   24,
#   1345,
#   4,
#   847,
#   681,
#   2,
#   252,
#   528,
#   5,
#   111,
#   7,
#   11,
#   161,
#   2,
#   440,
#   296,
#   297,
#   3,
#   95,
#   682,
#   15,
#   229,
#   1,
#   865,
#   2,
#   75,
#   68,
#   113,
#   58,
#   186,
#   2,
#   111,
#   298,
#   20,
#   388,
#   113,
#   6,
#   528,
#   2,
#   46,
#   3,
#   229,
#   45,
#   1346,
#   1347,
#   2,
#   75,
#   20,
#   77,
#   5,
#   1,
#   245,
#   599,
#   24,
#   1348,
#   13,
#   1,
#   111,
#   298,
#   8,
#   683,
#   1349,
#   4,
#   440,
#   296,
#   297,
#   1350,
#   10,
#   46,
#   3,
#   684,
#   12,
#   302,
#   409,
#   4,
#   1351,
#   1352,
#   1353,
#   867,
#   388,
#   2,
#   1,
#   75,
#   5,
#   1,
#   862,
#   1354,
#   4,
#   1,
#   1355,
#   297,
#   24,
#   76,
#   124,
#   13,
#   365,
#   21,
#   1,
#   252,
#   186,
#   2,
#   111,
#   7,
#   16,
#   30,
#   939,
#   20,
#   1356,
#   2,
#   1357,
#   21,
#   193,
#   613,
#   1,
#   75,
#   41,
#   1358,
#   5,
#   1,
#   629,
#   186,
#   643,
#   1359,
#   279,
#   1360,
#   685,
#   2,
#   95,
#   682,
#   1,
#   267,
#   2,
#   19,
#   7,
#   686,
#   21,
#   1361,
#   8,
#   436,
#   3,
#   105,
#   11,
#   111,
#   7,
#   5,
#   1,
#   149,
#   13,
#   111,
#   298,
#   8,
#   1362,
#   246,
#   2,
#   1363,
#   615,
#   113,
#   58,
#   1364,
#   1365,
#   872,
#   2,
#   581,
#   153,
#   2,
#   19,
#   7,
#   686,
#   21,
#   683,
#   578,
#   2,
#   111,
#   298,
#   8,
#   920,
#   1366,
#   20,
#   19,
#   941,
#   296,
#   297],
#  [36,
#   174,
#   11,
#   175,
#   74,
#   42,
#   687,
#   8,
#   22,
#   133,
#   525,
#   82,
#   273,
#   5,
#   132,
#   51,
#   82,
#   1367,
#   295,
#   5,
#   220,
#   11,
#   1368,
#   1369,
#   533,
#   114,
#   100,
#   20,
#   36,
#   1370,
#   23,
#   719,
#   144,
#   800,
#   524,
#   90,
#   229,
#   1,
#   1371,
#   2,
#   1,
#   441,
#   12,
#   442,
#   548,
#   22,
#   175,
#   23,
#   89,
#   32,
#   52,
#   9,
#   36,
#   42,
#   687,
#   11,
#   22,
#   1372,
#   175,
#   498,
#   1,
#   17,
#   16,
#   387,
#   294,
#   316,
#   718,
#   1,
#   1373,
#   441,
#   140,
#   370,
#   1374,
#   70,
#   370,
#   1375,
#   86,
#   3,
#   241,
#   1376,
#   266,
#   192,
#   42,
#   902,
#   1,
#   721,
#   2,
#   12,
#   60,
#   8,
#   4,
#   305,
#   50,
#   44,
#   283,
#   2,
#   175,
#   400,
#   4,
#   824,
#   1,
#   427,
#   2,
#   42,
#   174,
#   1,
#   1377,
#   2,
#   175,
#   9,
#   45,
#   175,
#   74,
#   8,
#   76,
#   621,
#   20,
#   22,
#   1378],
#  [495,
#   688,
#   184,
#   9,
#   36,
#   689,
#   215,
#   11,
#   44,
#   1379,
#   1380,
#   9,
#   197,
#   146,
#   538,
#   12,
#   60,
#   507,
#   10,
#   495,
#   6,
#   54,
#   2,
#   1381,
#   9,
#   36,
#   689,
#   215,
#   25,
#   6,
#   44,
#   1382,
#   52,
#   21,
#   232,
#   215,
#   9,
#   197,
#   146,
#   538,
#   5,
#   101,
#   4,
#   84,
#   1383,
#   215,
#   1384,
#   1,
#   60,
#   254,
#   263,
#   4,
#   1385,
#   1,
#   894,
#   1386,
#   215,
#   51,
#   4,
#   1387,
#   403,
#   1388,
#   3,
#   1389,
#   1390,
#   4,
#   190,
#   1,
#   559,
#   2,
#   688,
#   54,
#   582,
#   1,
#   540,
#   1391,
#   50,
#   92,
#   40,
#   23,
#   10,
#   1392,
#   79,
#   92,
#   17,
#   1393,
#   78,
#   40,
#   1394,
#   1,
#   139,
#   664,
#   1395,
#   419,
#   690,
#   44,
#   410,
#   289,
#   136,
#   1,
#   157,
#   17,
#   1396,
#   1397,
#   10,
#   154,
#   443,
#   395,
#   1398,
#   443,
#   444,
#   445,
#   1399,
#   5,
#   1400,
#   1,
#   573,
#   17,
#   802,
#   78,
#   444,
#   445,
#   3,
#   6,
#   244,
#   42,
#   919,
#   231,
#   9,
#   45,
#   134,
#   691,
#   20,
#   1,
#   1401,
#   110,
#   29,
#   431,
#   2,
#   1,
#   38,
#   322,
#   13,
#   1,
#   17,
#   759,
#   78,
#   110,
#   8,
#   61,
#   478,
#   63,
#   13,
#   460,
#   227,
#   444,
#   445],
#  [1402,
#   121,
#   153,
#   9,
#   1403,
#   185,
#   96,
#   149,
#   38,
#   2,
#   1404,
#   81,
#   96,
#   5,
#   216,
#   12,
#   168,
#   8,
#   1405,
#   4,
#   357,
#   6,
#   121,
#   23,
#   10,
#   1,
#   1406,
#   1407,
#   121,
#   332,
#   9,
#   81,
#   96,
#   5,
#   216,
#   1408,
#   81,
#   96,
#   5,
#   216,
#   18,
#   5,
#   22,
#   1409,
#   684,
#   1410,
#   15,
#   6,
#   1411,
#   2,
#   299,
#   5,
#   181,
#   1412,
#   6,
#   143,
#   125,
#   2,
#   1413,
#   3,
#   6,
#   308,
#   845,
#   930,
#   141,
#   81,
#   96,
#   18,
#   1414,
#   4,
#   1415,
#   9,
#   37,
#   1416,
#   4,
#   917,
#   221,
#   1417,
#   1,
#   442,
#   908,
#   1,
#   109,
#   9,
#   81,
#   185,
#   5,
#   1,
#   1418,
#   21,
#   855,
#   4,
#   1419,
#   114,
#   1420,
#   535,
#   299,
#   535,
#   3,
#   825,
#   2,
#   1,
#   925,
#   2,
#   1,
#   1421,
#   81,
#   96,
#   10,
#   1,
#   109,
#   1,
#   202,
#   761,
#   322,
#   1,
#   927,
#   2,
#   81,
#   185,
#   5,
#   216,
#   3,
#   5,
#   1,
#   201,
#   1,
#   37,
#   121,
#   8,
#   23,
#   10,
#   1,
#   129,
#   2,
#   675,
#   346,
#   5,
#   1,
#   81,
#   1422,
#   100,
#   20,
#   1423,
#   59,
#   1424,
#   57,
#   1425,
#   1426,
#   3,
#   330,
#   1,
#   442,
#   803,
#   458,
#   2,
#   1,
#   129,
#   2,
#   37,
#   346,
#   15,
#   1,
#   537,
#   577,
#   96,
#   799,
#   1,
#   149,
#   2,
#   1427,
#   8,
#   1428,
#   6,
#   915,
#   1429,
#   5,
#   1,
#   1430,
#   2,
#   81,
#   185,
#   1431,
#   12,
#   168,
#   568,
#   4,
#   303,
#   6,
#   37,
#   153,
#   121,
#   9,
#   81,
#   96,
#   5,
#   216],
#  [89,
#   325,
#   118,
#   27,
#   25,
#   27,
#   217,
#   27,
#   217,
#   1432,
#   1,
#   649,
#   68,
#   2,
#   209,
#   1433,
#   43,
#   8,
#   1434,
#   1435,
#   15,
#   692,
#   5,
#   819,
#   828,
#   325,
#   118,
#   10,
#   239,
#   434,
#   8,
#   328,
#   159,
#   462,
#   53,
#   1,
#   57,
#   32,
#   136,
#   4,
#   1,
#   27,
#   217,
#   4,
#   1436,
#   1,
#   693,
#   1437,
#   2,
#   1,
#   27,
#   88,
#   1,
#   139,
#   345,
#   553,
#   463,
#   1438,
#   4,
#   614,
#   6,
#   37,
#   14,
#   472,
#   5,
#   931,
#   4,
#   84,
#   1,
#   29,
#   2,
#   1,
#   27,
#   489,
#   4,
#   1,
#   37,
#   1439,
#   223,
#   1440,
#   4,
#   178,
#   6,
#   290,
#   27,
#   9,
#   1,
#   37,
#   27,
#   83,
#   223,
#   41,
#   108,
#   1441,
#   1,
#   232,
#   290,
#   27,
#   690,
#   575,
#   1,
#   1442,
#   2,
#   1443,
#   5,
#   12,
#   612,
#   6,
#   351,
#   325,
#   118,
#   332,
#   8,
#   33,
#   15,
#   25,
#   426,
#   19,
#   7,
#   694,
#   1444,
#   11,
#   769,
#   43,
#   8,
#   328,
#   5,
#   57,
#   1445,
#   179,
#   1,
#   33,
#   332,
#   680,
#   1446,
#   1,
#   209,
#   515,
#   217,
#   3,
#   1447,
#   1,
#   693,
#   1448,
#   23,
#   10,
#   1,
#   239,
#   434,
#   1,
#   128,
#   39,
#   5,
#   1,
#   168,
#   8,
#   1449,
#   515,
#   217,
#   4,
#   190,
#   1,
#   510,
#   1,
#   234,
#   310,
#   1450,
#   934,
#   935,
#   1451,
#   1452,
#   1453,
#   118,
#   818,
#   3,
#   1454,
#   1455,
#   148,
#   928,
#   24,
#   94,
#   1,
#   321,
#   4,
#   412,
#   1,
#   29,
#   222,
#   1,
#   315,
#   253,
#   43,
#   129,
#   67,
#   163,
#   213,
#   154,
#   169,
#   23,
#   3,
#   694,
#   23,
#   869],
#  [268,
#   71,
#   7,
#   94,
#   121,
#   9,
#   499,
#   156,
#   695,
#   696,
#   26,
#   12,
#   85,
#   767,
#   50,
#   240,
#   720,
#   2,
#   499,
#   268,
#   71,
#   156,
#   695,
#   696,
#   1456,
#   564,
#   71,
#   446,
#   3,
#   1457,
#   5,
#   1458,
#   1,
#   923,
#   7,
#   165,
#   2,
#   45,
#   71,
#   16,
#   30,
#   252,
#   21,
#   64,
#   1459,
#   15,
#   25,
#   22,
#   697,
#   17,
#   4,
#   806,
#   6,
#   7,
#   2,
#   331,
#   1460,
#   1461,
#   1462,
#   71,
#   446,
#   698,
#   398,
#   24,
#   303,
#   22,
#   604,
#   697,
#   17,
#   9,
#   1463,
#   852,
#   258,
#   13,
#   1464,
#   911,
#   258,
#   222,
#   193,
#   532,
#   329,
#   1465,
#   3,
#   8,
#   61,
#   203,
#   63,
#   315,
#   40,
#   4,
#   866,
#   9,
#   1,
#   699,
#   335,
#   1466,
#   1467,
#   137,
#   150,
#   700,
#   1468,
#   18,
#   494,
#   514,
#   24,
#   182,
#   6,
#   37,
#   52,
#   9,
#   268,
#   71,
#   7,
#   94,
#   25,
#   701,
#   1469,
#   258,
#   291,
#   1,
#   1470,
#   335,
#   2,
#   1471,
#   71,
#   3,
#   1472,
#   71,
#   787,
#   16,
#   30,
#   701,
#   61,
#   1473,
#   1,
#   33,
#   52,
#   76,
#   212,
#   6,
#   207,
#   273,
#   850,
#   94,
#   3,
#   576,
#   43,
#   302,
#   56,
#   33,
#   700,
#   685,
#   4,
#   1474,
#   1475,
#   7,
#   86,
#   105,
#   4,
#   532,
#   71,
#   7,
#   94,
#   52,
#   159,
#   1476,
#   7,
#   94,
#   458,
#   18,
#   477,
#   4,
#   1477,
#   1,
#   427,
#   2,
#   56,
#   33,
#   91,
#   11,
#   1478,
#   4,
#   699,
#   335,
#   698,
#   3,
#   7,
#   1479],
#  [14,
#   256,
#   9,
#   36,
#   132,
#   51,
#   82,
#   25,
#   44,
#   174,
#   174,
#   8,
#   58,
#   2,
#   1,
#   115,
#   133,
#   14,
#   525,
#   82,
#   859,
#   5,
#   1,
#   79,
#   92,
#   473,
#   3,
#   76,
#   58,
#   2,
#   1,
#   240,
#   1480,
#   618,
#   5,
#   1,
#   17,
#   29,
#   83,
#   1481,
#   492,
#   702,
#   8,
#   65,
#   1482,
#   62,
#   1,
#   75,
#   8,
#   1483,
#   3,
#   8,
#   249,
#   1484,
#   9,
#   220,
#   140,
#   22,
#   1485,
#   42,
#   1486,
#   100,
#   20,
#   36,
#   141,
#   24,
#   33,
#   22,
#   549,
#   14,
#   256,
#   48,
#   4,
#   84,
#   1,
#   455,
#   2,
#   1487,
#   174,
#   15,
#   25,
#   352,
#   702,
#   24,
#   377,
#   1,
#   29,
#   2,
#   56,
#   104,
#   10,
#   44,
#   36,
#   79,
#   92,
#   205,
#   1,
#   47,
#   679,
#   56,
#   256,
#   1488,
#   636,
#   1,
#   17,
#   61,
#   541,
#   4,
#   174,
#   235,
#   3,
#   16,
#   30,
#   630,
#   135,
#   11,
#   64,
#   14,
#   256,
#   550],
#  [496,
#   2,
#   176,
#   1489,
#   4,
#   447,
#   134,
#   1490,
#   6,
#   250,
#   38,
#   12,
#   85,
#   703,
#   6,
#   250,
#   38,
#   10,
#   1,
#   517,
#   55,
#   1,
#   428,
#   2,
#   218,
#   176,
#   3,
#   292,
#   110,
#   173,
#   218,
#   373,
#   10,
#   447,
#   134,
#   892,
#   31,
#   522,
#   9,
#   1,
#   38,
#   9,
#   1,
#   1491,
#   1,
#   1492,
#   704,
#   1493,
#   2,
#   170,
#   176,
#   765,
#   587,
#   3,
#   170,
#   36,
#   1494,
#   1495,
#   5,
#   705,
#   247,
#   18,
#   835,
#   706,
#   1496,
#   3,
#   173,
#   14,
#   35,
#   1497,
#   21,
#   367,
#   898,
#   36,
#   657,
#   45,
#   899,
#   1498,
#   1,
#   441,
#   2,
#   193,
#   706,
#   5,
#   1,
#   704,
#   5,
#   705,
#   247,
#   35,
#   1499,
#   173,
#   218,
#   1500,
#   9,
#   1,
#   99,
#   176,
#   110,
#   35,
#   903,
#   3,
#   707,
#   15,
#   25,
#   218,
#   1501,
#   337,
#   1,
#   1502,
#   88,
#   1,
#   139,
#   345,
#   292,
#   353,
#   295,
#   1,
#   543,
#   443,
#   1503,
#   31,
#   707,
#   3,
#   1504,
#   11,
#   1,
#   176,
#   14,
#   250,
#   99,
#   10,
#   1,
#   1505,
#   3,
#   681,
#   110,
#   2,
#   78,
#   218,
#   3,
#   173,
#   14,
#   35,
#   781,
#   12,
#   66,
#   212,
#   1,
#   517,
#   2,
#   1,
#   447,
#   176,
#   428,
#   848,
#   11,
#   1,
#   292,
#   1506],
#  [537,
#   14,
#   465,
#   9,
#   860,
#   211,
#   300,
#   198,
#   148,
#   5,
#   1507,
#   691,
#   918,
#   181,
#   1508,
#   109,
#   8,
#   1509,
#   1510,
#   11,
#   519,
#   1511,
#   291,
#   115,
#   692,
#   18,
#   1512,
#   11,
#   600,
#   5,
#   896,
#   1513,
#   1514,
#   295,
#   21,
#   37,
#   199,
#   5,
#   101,
#   4,
#   84,
#   1,
#   299,
#   1515,
#   211,
#   300,
#   198,
#   52,
#   13,
#   507,
#   10,
#   306,
#   199,
#   5,
#   1,
#   448,
#   1516,
#   3,
#   912,
#   1517,
#   266,
#   15,
#   1518,
#   61,
#   1519,
#   1520,
#   1521,
#   8,
#   1522,
#   1523,
#   5,
#   1524,
#   24,
#   723,
#   10,
#   1,
#   153,
#   2,
#   756,
#   465,
#   17,
#   13,
#   1525,
#   1526,
#   211,
#   300,
#   198,
#   148,
#   15,
#   916,
#   1,
#   306,
#   1527,
#   195,
#   831,
#   9,
#   300,
#   198,
#   23,
#   10,
#   1528,
#   29,
#   49,
#   3,
#   468,
#   1,
#   873,
#   1529,
#   1530,
#   159,
#   57,
#   32,
#   104,
#   1,
#   33,
#   48,
#   152,
#   6,
#   708,
#   17,
#   13,
#   1531,
#   199,
#   23,
#   10,
#   1532,
#   4,
#   1533,
#   342,
#   1534,
#   24,
#   305,
#   1,
#   33,
#   48,
#   15,
#   585,
#   22,
#   6,
#   1535,
#   305,
#   9,
#   512,
#   1536,
#   3,
#   241,
#   412,
#   160,
#   107,
#   69,
#   2,
#   709,
#   429,
#   4,
#   448,
#   710,
#   3,
#   120,
#   107,
#   211,
#   711,
#   148,
#   11,
#   1,
#   712,
#   149,
#   24,
#   162,
#   13,
#   1,
#   708,
#   17,
#   1537,
#   1538,
#   309,
#   107,
#   69,
#   2,
#   709,
#   429,
#   4,
#   448,
#   710,
#   15,
#   1539,
#   590,
#   3,
#   309,
#   711,
#   148,
#   15,
#   1540,
#   413,
#   5,
#   407,
#   2,
#   1541,
#   123,
#   380,
#   1542,
#   574,
#   4,
#   6,
#   299,
#   1543,
#   2,
#   1544,
#   1545,
#   449,
#   10,
#   1546,
#   1547,
#   88,
#   1548,
#   1549,
#   413,
#   662],
#  [177,
#   219,
#   196,
#   25,
#   1,
#   127,
#   19,
#   7,
#   12,
#   60,
#   703,
#   1,
#   396,
#   2,
#   127,
#   19,
#   7,
#   9,
#   196,
#   177,
#   219,
#   2,
#   1,
#   199,
#   5,
#   1,
#   1550,
#   378,
#   2,
#   1,
#   1551,
#   1552,
#   1553,
#   1554,
#   1555,
#   940,
#   1556,
#   49,
#   1557,
#   177,
#   1558,
#   3,
#   69,
#   2,
#   199,
#   18,
#   1,
#   75,
#   2,
#   1,
#   7,
#   13,
#   8,
#   905,
#   98,
#   11,
#   202,
#   14,
#   1,
#   66,
#   2,
#   1,
#   196,
#   8,
#   1,
#   177,
#   219,
#   1,
#   7,
#   39,
#   5,
#   12,
#   38,
#   8,
#   6,
#   50,
#   186,
#   381,
#   7,
#   3,
#   1,
#   32,
#   59,
#   8,
#   1,
#   385,
#   12,
#   7,
#   8,
#   98,
#   4,
#   30,
#   1559,
#   4,
#   840,
#   177,
#   219,
#   900,
#   9,
#   177,
#   219,
#   196,
#   2,
#   1,
#   1560,
#   449,
#   1561,
#   1562,
#   1,
#   66,
#   21,
#   127,
#   19,
#   7,
#   212,
#   61,
#   97,
#   15,
#   658,
#   1,
#   713,
#   2,
#   138,
#   88,
#   368,
#   830,
#   144,
#   1,
#   66,
#   21,
#   1563,
#   843,
#   107,
#   91,
#   41,
#   1,
#   713,
#   2,
#   138,
#   88,
#   170,
#   1564,
#   1565,
#   449],
#  [195,
#   65,
#   122,
#   878,
#   5,
#   137,
#   150,
#   86,
#   25,
#   288,
#   32,
#   19,
#   26,
#   12,
#   85,
#   33,
#   22,
#   52,
#   9,
#   195,
#   65,
#   122,
#   422,
#   5,
#   6,
#   137,
#   150,
#   87,
#   423,
#   6,
#   288,
#   32,
#   19,
#   7,
#   879,
#   31,
#   53,
#   5,
#   1,
#   126,
#   48,
#   1,
#   653,
#   2,
#   19,
#   7,
#   35,
#   654,
#   2,
#   1,
#   311,
#   2,
#   1,
#   655,
#   880,
#   1,
#   311,
#   2,
#   1,
#   422,
#   3,
#   1,
#   580,
#   881,
#   882,
#   883,
#   2,
#   137,
#   150,
#   86,
#   9,
#   45,
#   230,
#   2,
#   19,
#   194,
#   34,
#   54,
#   4,
#   160,
#   884,
#   1,
#   183,
#   31,
#   122,
#   3,
#   656,
#   342,
#   1,
#   183,
#   31,
#   65,
#   122,
#   24,
#   358,
#   885,
#   1,
#   423,
#   13,
#   41,
#   6,
#   244,
#   130,
#   255,
#   3,
#   886,
#   1,
#   87,
#   362,
#   4,
#   424,
#   887,
#   172,
#   888,
#   291,
#   172,
#   31,
#   340,
#   21,
#   120,
#   4,
#   170,
#   3,
#   424,
#   31,
#   340,
#   21,
#   172,
#   4,
#   172,
#   120,
#   103,
#   1,
#   198,
#   415,
#   889,
#   28,
#   31,
#   206,
#   9,
#   112,
#   19,
#   26,
#   1,
#   66,
#   2,
#   12,
#   60,
#   425,
#   1,
#   97,
#   2,
#   19,
#   26,
#   13,
#   890,
#   65,
#   122,
#   183],
#  [65,
#   301,
#   161,
#   14,
#   450,
#   10,
#   451,
#   276,
#   277,
#   26,
#   225,
#   155,
#   5,
#   451,
#   276,
#   277,
#   26,
#   8,
#   562,
#   248,
#   4,
#   106,
#   244,
#   641,
#   114,
#   1566,
#   327,
#   3,
#   204,
#   451,
#   1567,
#   226,
#   3,
#   185,
#   5,
#   542,
#   1568,
#   354,
#   482,
#   22,
#   1569,
#   1570,
#   3,
#   225,
#   155,
#   145,
#   24,
#   182,
#   6,
#   65,
#   301,
#   161,
#   225,
#   155,
#   145,
#   13,
#   41,
#   22,
#   203,
#   14,
#   714,
#   289,
#   3,
#   22,
#   203,
#   155,
#   74,
#   1,
#   714,
#   117,
#   289,
#   28,
#   8,
#   6,
#   893,
#   671,
#   28,
#   13,
#   1571,
#   6,
#   117,
#   4,
#   603,
#   13,
#   34,
#   1572,
#   4,
#   6,
#   1573,
#   2,
#   505,
#   1574,
#   54,
#   70,
#   90,
#   1,
#   28,
#   8,
#   6,
#   647,
#   2,
#   739,
#   23,
#   28,
#   3,
#   165,
#   23,
#   419,
#   319,
#   1575,
#   1,
#   28,
#   524,
#   90,
#   1576,
#   467,
#   301,
#   161,
#   141,
#   34,
#   16,
#   474,
#   1577,
#   6,
#   446,
#   1578,
#   103,
#   1,
#   28,
#   16,
#   1579,
#   1580,
#   14,
#   63,
#   245,
#   712,
#   104,
#   13,
#   482,
#   143,
#   1581,
#   715,
#   9,
#   478,
#   14,
#   24,
#   76,
#   182,
#   6,
#   37,
#   155,
#   1582,
#   319,
#   1583,
#   716,
#   417,
#   2,
#   6,
#   155,
#   498,
#   6,
#   1584,
#   1585,
#   74,
#   3,
#   6,
#   715,
#   74,
#   1,
#   33,
#   145,
#   1586,
#   140,
#   467,
#   301,
#   161,
#   3,
#   212,
#   225,
#   3,
#   203,
#   14,
#   450,
#   1,
#   29,
#   8,
#   377,
#   11,
#   6,
#   1587,
#   7,
#   624,
#   1588,
#   512,
#   586,
#   47,
#   124,
#   13,
#   716,
#   11,
#   1589,
#   801,
#   64,
#   315,
#   1590,
#   5,
#   407,
#   2,
#   1591,
#   1592,
#   3,
#   14,
#   450,
#   1593]]

# %%
maxlen_train = len(max(x_indx, key=len))
maxlen_test = len(max(x_indx_test, key=len))
maxlen_val = len(max(x_indx_val, key=len))
maxlen = max([maxlen_train,maxlen_test,maxlen_val])
maxlen
# Out:
# 430

# %%
len(t.word_index)
# Out:
# 2491

# %%
for i, x in enumerate(x_indx_test):
    if len(x) < maxlen:
        x_indx_test[i] = np.hstack((x, np.zeros(maxlen-len(x))))
x_test_index = np.array(x_indx_test)

# %%
x_test_index.shape
# Out:
# (15, 430)

# %%
for i, x in enumerate(x_indx):
    if len(x) < maxlen:
        x_indx[i] = np.hstack((x, np.zeros(maxlen-len(x))))
x_train_index = np.array(x_indx)

# %%
x_train_index.shape
# Out:
# (35, 430)

# %%
for i, x in enumerate(x_indx_val):
    if len(x) < maxlen:
        x_indx_val[i] = np.hstack((x, np.zeros(maxlen-len(x))))
x_val_index = np.array(x_indx_val)

# %%
len(x_train_index[0])
# Out:
# 430

# %%
total_word = len(t.word_index) +1

# %%
total_word
# Out:
# 2492

# %%
t.word_index
# Out:
# {'the': 1,
#  'of': 2,
#  'and': 3,
#  'to': 4,
#  'in': 5,
#  'a': 6,
#  'network': 7,
#  'is': 8,
#  'for': 9,
#  'on': 10,
#  'with': 11,
#  'this': 12,
#  'that': 13,
#  'data': 14,
#  'by': 15,
#  'can': 16,
#  'model': 17,
#  'are': 18,
#  'neural': 19,
#  'as': 20,
#  'from': 21,
#  'an': 22,
#  'based': 23,
#  'we': 24,
#  'using': 25,
#  'networks': 26,
#  'system': 27,
#  'algorithm': 28,
#  'performance': 29,
#  'be': 30,
#  'was': 31,
#  'learning': 32,
#  'proposed': 33,
#  'it': 34,
#  'were': 35,
#  'thai': 36,
#  'new': 37,
#  'study': 38,
#  'used': 39,
#  'models': 40,
#  'has': 41,
#  'word': 42,
#  'which': 43,
#  'different': 44,
#  'each': 45,
#  'time': 46,
#  'results': 47,
#  'method': 48,
#  ',': 49,
#  'two': 50,
#  'language': 51,
#  'approach': 52,
#  'applied': 53,
#  'set': 54,
#  'between': 55,
#  'our': 56,
#  'machine': 57,
#  'one': 58,
#  'process': 59,
#  'research': 60,
#  'more': 61,
#  'when': 62,
#  'than': 63,
#  'other': 64,
#  'non': 65,
#  'result': 66,
#  'lstm': 67,
#  'information': 68,
#  'number': 69,
#  'or': 70,
#  'domain': 71,
#  'have': 72,
#  'many': 73,
#  'mechanism': 74,
#  'input': 75,
#  'also': 76,
#  'function': 77,
#  'both': 78,
#  'text': 79,
#  'control': 80,
#  'audit': 81,
#  'processing': 82,
#  'however,': 83,
#  'improve': 84,
#  'thesis': 85,
#  'problems': 86,
#  'problem': 87,
#  'at': 88,
#  'deep': 89,
#  'not': 90,
#  'technique': 91,
#  'classification': 92,
#  'traffic': 93,
#  'design': 94,
#  'quantum': 95,
#  'firms': 96,
#  'accuracy': 97,
#  'trained': 98,
#  'analysis': 99,
#  'such': 100,
#  'order': 101,
#  'search': 102,
#  'moreover,': 103,
#  'algorithms': 104,
#  'compared': 105,
#  'its': 106,
#  'average': 107,
#  'been': 108,
#  'market': 109,
#  'features': 110,
#  'residual': 111,
#  'training': 112,
#  'over': 113,
#  'including': 114,
#  'most': 115,
#  'best': 116,
#  'node': 117,
#  'detection': 118,
#  'routing': 119,
#  '2': 120,
#  'strategy': 121,
#  'binding': 122,
#  'these': 123,
#  'show': 124,
#  'level': 125,
#  'prediction': 126,
#  'artificial': 127,
#  'dataset': 128,
#  'use': 129,
#  'optimal': 130,
#  'transactions': 131,
#  'natural': 132,
#  'important': 133,
#  'speech': 134,
#  'well': 135,
#  'techniques': 136,
#  'linear': 137,
#  'error': 138,
#  'same': 139,
#  'without': 140,
#  'therefore,': 141,
#  'tuning': 142,
#  'high': 143,
#  'while': 144,
#  'protocol': 145,
#  '19': 146,
#  'policy': 147,
#  'rate': 148,
#  'case': 149,
#  'programming': 150,
#  'stock': 151,
#  'returns': 152,
#  'development': 153,
#  'term': 154,
#  'broadcasting': 155,
#  'large': 156,
#  'first': 157,
#  'random': 158,
#  'several': 159,
#  '1': 160,
#  'knowledge': 161,
#  'find': 162,
#  'long': 163,
#  'sdn': 164,
#  'topology': 165,
#  'sensor': 166,
#  'behavior': 167,
#  'work': 168,
#  'memory': 169,
#  '4': 170,
#  'deadlock': 171,
#  'n': 172,
#  'audio': 173,
#  'tokenization': 174,
#  'attention': 175,
#  'facial': 176,
#  'water': 177,
#  'build': 178,
#  'tasks': 179,
#  'methods': 180,
#  'real': 181,
#  'propose': 182,
#  'constraint': 183,
#  'sets': 184,
#  'services': 185,
#  'layer': 186,
#  'predict': 187,
#  'better': 188,
#  'genetic': 189,
#  'evaluate': 190,
#  'loss': 191,
#  'into': 192,
#  'all': 193,
#  'network,': 194,
#  'identifying': 195,
#  'forecasting': 196,
#  'covid': 197,
#  'back': 198,
#  'customers': 199,
#  'attack': 200,
#  'world': 201,
#  'historical': 202,
#  'efficient': 203,
#  'various': 204,
#  'datasets': 205,
#  'selected': 206,
#  'three': 207,
#  'under': 208,
#  'service': 209,
#  'controller': 210,
#  'customer': 211,
#  'provides': 212,
#  'short': 213,
#  'hyperparameters': 214,
#  'chatbot': 215,
#  'russia': 216,
#  'logs': 217,
#  'visual': 218,
#  'demand': 219,
#  'languages': 220,
#  'their': 221,
#  'against': 222,
#  'alice': 223,
#  'nodes': 224,
#  'reliable': 225,
#  'applications': 226,
#  'only': 227,
#  'some': 228,
#  'consider': 229,
#  'target': 230,
#  'score': 231,
#  'conventional': 232,
#  'ability': 233,
#  'measurement': 234,
#  'errors': 235,
#  'parameters': 236,
#  'coreference': 237,
#  'legal': 238,
#  'log': 239,
#  'main': 240,
#  'then': 241,
#  'end': 242,
#  'tested': 243,
#  'unique': 244,
#  'position': 245,
#  'up': 246,
#  'there': 247,
#  'due': 248,
#  'especially': 249,
#  'computational': 250,
#  'impairment': 251,
#  'hidden': 252,
#  'works': 253,
#  'studies': 254,
#  'solution': 255,
#  'augmentation': 256,
#  'sinkhole': 257,
#  'protection': 258,
#  'ai': 259,
#  'computer': 260,
#  'thesis,': 261,
#  'dissertation': 262,
#  'how': 263,
#  'evaluation': 264,
#  'computing': 265,
#  'them': 266,
#  'experiment': 267,
#  'multi': 268,
#  'actual': 269,
#  'optimization': 270,
#  'meaning': 271,
#  'amr': 272,
#  'step': 273,
#  'could': 274,
#  'testbed': 275,
#  'ad': 276,
#  'hoc': 277,
#  'topic': 278,
#  'path': 279,
#  'caching': 280,
#  'content': 281,
#  'visibility': 282,
#  'types': 283,
#  'modelling': 284,
#  'cluster': 285,
#  'circuit': 286,
#  'risk': 287,
#  'supervised': 288,
#  'selection': 289,
#  'monitoring': 290,
#  'where': 291,
#  'acoustic': 292,
#  'hissing': 293,
#  'character': 294,
#  'particularly': 295,
#  'differential': 296,
#  'equation': 297,
#  'block': 298,
#  'revenue': 299,
#  'win': 300,
#  'geographical': 301,
#  'allows': 302,
#  'develop': 303,
#  'i': 304,
#  'test': 305,
#  'current': 306,
#  'estimation': 307,
#  'difficult': 308,
#  'increase': 309,
#  'metrics': 310,
#  'coefficients': 311,
#  'defined': 312,
#  'synthetic': 313,
#  'because': 314,
#  'existing': 315,
#  'correlations': 316,
#  'provide': 317,
#  'ga': 318,
#  'called': 319,
#  'point': 320,
#  'experiments': 321,
#  'shows': 322,
#  'packet': 323,
#  'flps': 324,
#  'anomaly': 325,
#  'series': 326,
#  'connectivity': 327,
#  'popular': 328,
#  'link': 329,
#  'others': 330,
#  'virtual': 331,
#  'framework': 332,
#  'lda': 333,
#  'cognitive': 334,
#  'capacity': 335,
#  'reinforcement': 336,
#  'through': 337,
#  'idiosyncratic': 338,
#  'missing': 339,
#  'varied': 340,
#  'resilient': 341,
#  'if': 342,
#  'articulatory': 343,
#  'evitar': 344,
#  'time,': 345,
#  'technologies': 346,
#  'textual': 347,
#  'human': 348,
#  'out': 349,
#  'texts': 350,
#  'novel': 351,
#  'multiple': 352,
#  'data,': 353,
#  'systems': 354,
#  'estimate': 355,
#  'make': 356,
#  'developing': 357,
#  'considered': 358,
#  'class': 359,
#  'classes': 360,
#  'neuron': 361,
#  'size': 362,
#  'minority': 363,
#  'oversampling': 364,
#  'output': 365,
#  'chosen': 366,
#  '10': 367,
#  '0': 368,
#  'parameter': 369,
#  'gradient': 370,
#  'cost': 371,
#  'grid': 372,
#  'corpus': 373,
#  'related': 374,
#  'representation': 375,
#  'conducted': 376,
#  'evaluated': 377,
#  'area': 378,
#  'applying': 379,
#  'significant': 380,
#  'feedforward': 381,
#  'identification,': 382,
#  'approximation,': 383,
#  'advanced': 384,
#  'backpropagation': 385,
#  'plant': 386,
#  'learn': 387,
#  'dynamics': 388,
#  'seen': 389,
#  'maximum': 390,
#  'reactor': 391,
#  'gmc': 392,
#  'temperature': 393,
#  'condition': 394,
#  'inverse': 395,
#  'application': 396,
#  'delay': 397,
#  'first,': 398,
#  'analyzed': 399,
#  'mechanisms': 400,
#  'centralized': 401,
#  'openflow': 402,
#  'those': 403,
#  'individual': 404,
#  'global': 405,
#  'mininet': 406,
#  'terms': 407,
#  'power': 408,
#  'us': 409,
#  'feature': 410,
#  'embedding': 411,
#  'compare': 412,
#  '5': 413,
#  'asset': 414,
#  'propagation': 415,
#  'incomplete': 416,
#  'consists': 417,
#  'values': 418,
#  'algorithm,': 419,
#  'summarization': 420,
#  'news': 421,
#  'constraints': 422,
#  'lp': 423,
#  'm': 424,
#  'showed': 425,
#  'convolutional': 426,
#  'effectiveness': 427,
#  'movement': 428,
#  'cases': 429,
#  'smart': 430,
#  'comparison': 431,
#  'tabu': 432,
#  'documents': 433,
#  'messages': 434,
#  'f1': 435,
#  'created': 436,
#  'bee': 437,
#  'hyperparameter': 438,
#  'abc': 439,
#  'partial': 440,
#  'sentence': 441,
#  'paper': 442,
#  'frequency': 443,
#  'tf': 444,
#  'idf': 445,
#  'privacy': 446,
#  'expressive': 447,
#  'sales': 448,
#  'year': 449,
#  'dissemination': 450,
#  'vehicular': 451,
#  'amount': 452,
#  'nlp': 453,
#  'perform': 454,
#  'robustness': 455,
#  'furthermore,': 456,
#  'original': 457,
#  'examples': 458,
#  'resource': 459,
#  'uses': 460,
#  'research,': 461,
#  'researchers': 462,
#  'organization': 463,
#  'software': 464,
#  'analytics': 465,
#  'create': 466,
#  'any': 467,
#  'testing': 468,
#  'may': 469,
#  'distribution': 470,
#  'adjust': 471,
#  'center': 472,
#  'task': 473,
#  'avoid': 474,
#  'reduce': 475,
#  'appropriate': 476,
#  'given': 477,
#  'accurate': 478,
#  'conditions': 479,
#  '7': 480,
#  'hyper': 481,
#  'need': 482,
#  'implemented': 483,
#  'addition,': 484,
#  'resolution': 485,
#  'bidirectional': 486,
#  'five': 487,
#  'tool': 488,
#  'according': 489,
#  'potential': 490,
#  'multilayer': 491,
#  'good': 492,
#  'obtained': 493,
#  'derived': 494,
#  'designing': 495,
#  'effects': 496,
#  'cooperative': 497,
#  'mechanism,': 498,
#  'survivable': 499,
#  'backbone': 500,
#  'wireless': 501,
#  'designed': 502,
#  'emulated': 503,
#  'low': 504,
#  'connected': 505,
#  'failed': 506,
#  'focuses': 507,
#  'response': 508,
#  'gain': 509,
#  'model,': 510,
#  'mild': 511,
#  '3': 512,
#  'since': 513,
#  'second,': 514,
#  'operation': 515,
#  'trading': 516,
#  'relation': 517,
#  'shock': 518,
#  'negative': 519,
#  'seven': 520,
#  'social': 521,
#  'collected': 522,
#  'traditional': 523,
#  'does': 524,
#  'pre': 525,
#  'heat': 526,
#  'energy': 527,
#  'unit': 528,
#  'vowel': 529,
#  'recurrent': 530,
#  'dropout': 531,
#  'single': 532,
#  'indicators': 533,
#  'gas': 534,
#  'analysis,': 535,
#  'rpl': 536,
#  'big': 537,
#  'pandemic': 538,
#  'copyright': 539,
#  'author': 540,
#  'robust': 541,
#  'intelligent': 542,
#  'fundamental': 543,
#  'fail': 544,
#  'must': 545,
#  'malformed': 546,
#  'setting': 547,
#  'proposes': 548,
#  'alternative': 549,
#  'schemes': 550,
#  'they': 551,
#  'resources': 552,
#  'cern': 553,
#  'installed': 554,
#  'transfer': 555,
#  'working': 556,
#  'generalization': 557,
#  'rbf': 558,
#  'correctness': 559,
#  'experimental': 560,
#  'significantly': 561,
#  'challenging': 562,
#  'solutions': 563,
#  'namely': 564,
#  'samples': 565,
#  'probability': 566,
#  'generated': 567,
#  'aims': 568,
#  'noise': 569,
#  'flow': 570,
#  'pressure': 571,
#  'outputs': 572,
#  'second': 573,
#  'lead': 574,
#  'requires': 575,
#  'optimization,': 576,
#  'four': 577,
#  'understanding': 578,
#  'reduction': 579,
#  'right': 580,
#  'further': 581,
#  'design,': 582,
#  'collect': 583,
#  'e': 584,
#  'running': 585,
#  'simulation': 586,
#  's': 587,
#  'studied': 588,
#  'relative': 589,
#  '8': 590,
#  'cstr': 591,
#  'disturbance': 592,
#  'rejection': 593,
#  'tracking': 594,
#  'nimc': 595,
#  'offsets': 596,
#  'flight': 597,
#  'communication': 598,
#  'space': 599,
#  'challenges': 600,
#  'aanet': 601,
#  'dimensional': 602,
#  'know': 603,
#  'improved': 604,
#  'ratio': 605,
#  'policies': 606,
#  'support': 607,
#  'ratio,': 608,
#  'performs': 609,
#  'wifi': 610,
#  'iot': 611,
#  'work,': 612,
#  'paths': 613,
#  'establish': 614,
#  'connection': 615,
#  'increasing': 616,
#  'wide': 617,
#  'factors': 618,
#  'clustering': 619,
#  'among': 620,
#  'included': 621,
#  'walk': 622,
#  'sizes': 623,
#  'simulator': 624,
#  'lower': 625,
#  'presented': 626,
#  'return': 627,
#  'management': 628,
#  'previous': 629,
#  'combined': 630,
#  'sharpe': 631,
#  'revealed': 632,
#  'pricing': 633,
#  'structure': 634,
#  'finding': 635,
#  'makes': 636,
#  'measures': 637,
#  'centrality': 638,
#  'essential': 639,
#  'about': 640,
#  'characteristics': 641,
#  'pattern': 642,
#  'like': 643,
#  'way': 644,
#  'condition,': 645,
#  'ensemble': 646,
#  'combination': 647,
#  'subsequence': 648,
#  'complete': 649,
#  'user': 650,
#  'very': 651,
#  'exchanger': 652,
#  'inputs': 653,
#  'composed': 654,
#  'objective': 655,
#  'o': 656,
#  'speakers': 657,
#  'having': 658,
#  'recorded': 659,
#  'contract': 660,
#  'ethereum': 661,
#  'million': 662,
#  'sending': 663,
#  'logistic': 664,
#  'known': 665,
#  'lossy': 666,
#  'dual': 667,
#  'parent': 668,
#  'apis': 669,
#  'mel': 670,
#  'decision': 671,
#  'minimum': 672,
#  'baseline': 673,
#  'batch': 674,
#  'emerging': 675,
#  'automated': 676,
#  'colony': 677,
#  'sequentially': 678,
#  'suggested': 679,
#  'automatically': 680,
#  'dynamic': 681,
#  'mechanics': 682,
#  'mathematical': 683,
#  'position,': 684,
#  'formulation': 685,
#  'architecture': 686,
#  'segmentation': 687,
#  'answer': 688,
#  'advisory': 689,
#  'but': 690,
#  'segment': 691,
#  'developers': 692,
#  'anomalous': 693,
#  'cnn': 694,
#  'scale': 695,
#  'optical': 696,
#  'aggregation': 697,
#  'requirement': 698,
#  'spare': 699,
#  'ilp': 700,
#  'shared': 701,
#  'tokenizations': 702,
#  'presents': 703,
#  'stimuli': 704,
#  'total,': 705,
#  'combinations': 706,
#  'tracked': 707,
#  'propensity': 708,
#  'refer': 709,
#  'department': 710,
#  'referral': 711,
#  'base': 712,
#  'percentages': 713,
#  'forwarder': 714,
#  'beaconing': 715,
#  'nog': 716,
#  'becomes': 717,
#  'across': 718,
#  'segmentation,': 719,
#  'issues': 720,
#  'goal': 721,
#  'handle': 722,
#  'focus': 723,
#  'strategies': 724,
#  'adversarial': 725,
#  'o2': 726,
#  'will': 727,
#  'logstash': 728,
#  'clusters': 729,
#  'hard': 730,
#  'get': 731,
#  'machines': 732,
#  'measured': 733,
#  'mean': 734,
#  'radial': 735,
#  'basis': 736,
#  'concern': 737,
#  'possible': 738,
#  'density': 739,
#  'imbalanced': 740,
#  'identify': 741,
#  'cause': 742,
#  'overlapping': 743,
#  'then,': 744,
#  'benchmark': 745,
#  'empirical': 746,
#  'multiphase': 747,
#  'levels': 748,
#  'after': 749,
#  'correlation': 750,
#  'less': 751,
#  '23': 752,
#  'coded': 753,
#  'predicted': 754,
#  'automatic': 755,
#  'predictive': 756,
#  'become': 757,
#  'widely': 758,
#  'utilizing': 759,
#  'gbm': 760,
#  'background': 761,
#  'complex': 762,
#  'variation': 763,
#  'legislative': 764,
#  'expression': 765,
#  'activities': 766,
#  'addresses': 767,
#  'integrated': 768,
#  'transformer': 769,
#  'spanbert': 770,
#  'complexity': 771,
#  'convention': 772,
#  'child': 773,
#  'status': 774,
#  '78': 775,
#  'allocation': 776,
#  'sent': 777,
#  'filtered': 778,
#  'help': 779,
#  'result,': 780,
#  'performed': 781,
#  'utilization': 782,
#  'employed': 783,
#  'simulated': 784,
#  'consequently,': 785,
#  'added': 786,
#  'links': 787,
#  'targets': 788,
#  'present': 789,
#  'characteristic': 790,
#  'value': 791,
#  'expected': 792,
#  'within': 793,
#  'key': 794,
#  'implementation': 795,
#  'server': 796,
#  'utilized': 797,
#  'emulation': 798,
#  'also,': 799,
#  'simple,': 800,
#  'outperforms': 801,
#  'utilizes': 802,
#  'gives': 803,
#  'hybrid': 804,
#  'gns3': 805,
#  'form': 806,
#  'ovs': 807,
#  'ryu': 808,
#  'developed': 809,
#  'measure': 810,
#  'necessary': 811,
#  'aware': 812,
#  'another': 813,
#  'easily': 814,
#  'hypertext': 815,
#  'campus': 816,
#  'internet': 817,
#  'rate,': 818,
#  'recent': 819,
#  'dwt': 820,
#  'english': 821,
#  'hiv': 822,
#  'plwh': 823,
#  'determine': 824,
#  'assessment': 825,
#  'who': 826,
#  'means': 827,
#  'years,': 828,
#  'marked': 829,
#  '18': 830,
#  'significance': 831,
#  'wall': 832,
#  'operators': 833,
#  'type': 834,
#  '16': 835,
#  'sensitive': 836,
#  'financial': 837,
#  'adopted': 838,
#  'researches': 839,
#  'forecast': 840,
#  'regime': 841,
#  'signals': 842,
#  'moving': 843,
#  '21': 844,
#  'economic': 845,
#  'even': 846,
#  'explain': 847,
#  'together': 848,
#  'cannot': 849,
#  'systematic': 850,
#  'cross': 851,
#  'cycle': 852,
#  'effective': 853,
#  'code': 854,
#  '2009': 855,
#  'lock': 856,
#  'fill': 857,
#  'demonstrates': 858,
#  'steps': 859,
#  'improving': 860,
#  'imputation': 861,
#  'similar': 862,
#  'operator': 863,
#  'easy': 864,
#  'change': 865,
#  'optimize': 866,
#  'describe': 867,
#  'matter': 868,
#  'approaches': 869,
#  'abstractive': 870,
#  'specific': 871,
#  'example': 872,
#  'resulting': 873,
#  'recovery': 874,
#  'variations': 875,
#  'load': 876,
#  'resiliency': 877,
#  'constrints': 878,
#  '9nn': 879,
#  'function,': 880,
#  'hand': 881,
#  'side': 882,
#  'constants': 883,
#  'fif': 884,
#  'specifically': 885,
#  'fixed': 886,
#  'x': 887,
#  'dimensions': 888,
#  'bp': 889,
#  'identified': 890,
#  'inversion': 891,
#  'production': 892,
#  'self': 893,
#  'underlying': 894,
#  'predefined': 895,
#  'generating': 896,
#  '50': 897,
#  'native': 898,
#  'speaker': 899,
#  'accurately': 900,
#  'analyze': 901,
#  'vectors': 902,
#  'extracted': 903,
#  'medicare': 904,
#  'properly': 905,
#  'users': 906,
#  'runtime': 907,
#  'analyzes': 908,
#  'default': 909,
#  '32': 910,
#  'full': 911,
#  're': 912,
#  'vehicle': 913,
#  'windows': 914,
#  'company': 915,
#  'exploring': 916,
#  'grow': 917,
#  'thailand’s': 918,
#  'component': 919,
#  'indicated': 920,
#  'lln': 921,
#  'devices': 922,
#  'physical': 923,
#  'damage': 924,
#  'impact': 925,
#  'defense': 926,
#  'formation': 927,
#  'finally,': 928,
#  'sentiment': 929,
#  'situation': 930,
#  '2020': 931,
#  'accuracy,': 932,
#  'score,': 933,
#  'precision,': 934,
#  'recall,': 935,
#  'intelligence': 936,
#  'law': 937,
#  'notion': 938,
#  'write': 939,
#  'product': 940,
#  'ordinary': 941,
#  'shown': 942,
#  'part': 943,
#  'named': 944,
#  'entity': 945,
#  'address': 946,
#  'architectures': 947,
#  'explores': 948,
#  'similarity': 949,
#  'parallel': 950,
#  'reveal': 951,
#  'weaknesses': 952,
#  'logging': 953,
#  'examine': 954,
#  'european': 955,
#  'nuclear': 956,
#  'logstash,': 957,
#  'kibana': 958,
#  'nodes,': 959,
#  'receive': 960,
#  'elasticsearch': 961,
#  'changes': 962,
#  'forest': 963,
#  'regression,': 964,
#  'perceptron': 965,
#  'absolute': 966,
#  'radius': 967,
#  'cover': 968,
#  'correct': 969,
#  'achieve': 970,
#  'statistical': 971,
#  'estimating': 972,
#  'correctly': 973,
#  'probabilistic': 974,
#  'symprod': 975,
#  'affects': 976,
#  'majority': 977,
#  'skewed': 978,
#  'do': 979,
#  'instances': 980,
#  'distribution,': 981,
#  'validated': 982,
#  '17': 983,
#  'compares': 984,
#  'eight': 985,
#  'vertical': 986,
#  'bottomhole': 987,
#  'computation': 988,
#  'scenario,': 989,
#  'yields': 990,
#  'difference': 991,
#  'boosting': 992,
#  'modeling': 993,
#  'fields': 994,
#  'consideration': 995,
#  'explored': 996,
#  'outperformed': 997,
#  'com': 998,
#  "entity's": 999,
#  'action': 1000,
#  ...}

# %%
import keras

# %%
model = keras.Sequential()

model.add(keras.layers.Embedding(total_word, 512, input_length=maxlen, name='Embedding'))
model.add(keras.layers.LSTM(512,activation = 'tanh', return_sequences=True))
model.add(keras.layers.LSTM(256))
model.add(keras.layers.Dense(topic_no, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy',optimizer='rmsprop' ,metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Embedding (Embedding)       (None, 430, 512)          1275904
#
#  lstm_2 (LSTM)               (None, 430, 512)          2099200
#
#  lstm_3 (LSTM)               (None, 256)               787456
#
#  dense_1 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 4,163,331
# Trainable params: 4,163,331
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train = np.array(y_train)
y_val = np.array(y_val)

# %%
y_train
# Out:
# array([2, 2, 2, 2, 1, 2, 1, 2, 0, 1, 0, 1, 0, 2, 2, 2, 1, 2, 1, 2, 2, 1,
#        0, 0, 2, 0, 2, 0, 0, 2, 2, 2, 1, 2, 1], dtype=int64)

# %%
y_val
# Out:
# array([0, 0, 2, 0, 2, 0, 2, 2, 1, 2, 1, 2, 2, 2, 1], dtype=int64)

# %%
len(y_train)
# Out:
# 35

# %%
x_test_index.shape
# Out:
# (15, 430)

# %%
x_val_index.shape
# Out:
# (15, 430)

# %%
x_train_index.shape
# Out:
# (35, 430)

# %%
his = model.fit(x_train_index, y_train, epochs=20, batch_size=64, validation_data = (x_val_index,y_val))
# Out:
# Epoch 1/20
# 1/1 [==============================] - 15s 15s/step - loss: 1.0975 - acc: 0.2571 - val_loss: 1.0584 - val_acc: 0.5333
# Epoch 2/20
# 1/1 [==============================] - 10s 10s/step - loss: 1.0610 - acc: 0.5143 - val_loss: 1.1008 - val_acc: 0.2667
# Epoch 3/20
# 1/1 [==============================] - 10s 10s/step - loss: 1.1010 - acc: 0.2571 - val_loss: 1.0426 - val_acc: 0.5333
# Epoch 4/20
# 1/1 [==============================] - 10s 10s/step - loss: 1.0425 - acc: 0.5143 - val_loss: 1.0119 - val_acc: 0.5333
# Epoch 5/20
# 1/1 [==============================] - 10s 10s/step - loss: 1.0183 - acc: 0.5143 - val_loss: 1.0193 - val_acc: 0.5333
# Epoch 6/20
# 1/1 [==============================] - 11s 11s/step - loss: 1.0177 - acc: 0.5429 - val_loss: 1.0104 - val_acc: 0.5333
# Epoch 7/20
# 1/1 [==============================] - 10s 10s/step - loss: 1.0184 - acc: 0.5429 - val_loss: 1.0364 - val_acc: 0.5333
# Epoch 8/20
# 1/1 [==============================] - 11s 11s/step - loss: 1.0259 - acc: 0.5429 - val_loss: 1.0169 - val_acc: 0.5333
# Epoch 9/20
# 1/1 [==============================] - 15s 15s/step - loss: 1.0306 - acc: 0.5429 - val_loss: 1.0511 - val_acc: 0.5333
# Epoch 10/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.0420 - acc: 0.5429 - val_loss: 1.0232 - val_acc: 0.5333
# Epoch 11/20
# 1/1 [==============================] - 13s 13s/step - loss: 1.0190 - acc: 0.5429 - val_loss: 1.0156 - val_acc: 0.5333
# Epoch 12/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.0157 - acc: 0.5429 - val_loss: 1.0139 - val_acc: 0.5333
# Epoch 13/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.0154 - acc: 0.5429 - val_loss: 1.0197 - val_acc: 0.5333
# Epoch 14/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.0157 - acc: 0.5429 - val_loss: 1.0193 - val_acc: 0.5333
# Epoch 15/20
# 1/1 [==============================] - 13s 13s/step - loss: 1.0199 - acc: 0.5429 - val_loss: 1.0218 - val_acc: 0.5333
# Epoch 16/20
# 1/1 [==============================] - 14s 14s/step - loss: 1.0125 - acc: 0.5429 - val_loss: 1.0189 - val_acc: 0.5333
# Epoch 17/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.0122 - acc: 0.5429 - val_loss: 1.0160 - val_acc: 0.5333
# Epoch 18/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.0040 - acc: 0.5429 - val_loss: 1.2267 - val_acc: 0.2000
# Epoch 19/20
# 1/1 [==============================] - 12s 12s/step - loss: 1.1673 - acc: 0.2571 - val_loss: 1.0255 - val_acc: 0.5333
# Epoch 20/20
# 1/1 [==============================] - 10s 10s/step - loss: 1.0283 - acc: 0.5429 - val_loss: 1.0225 - val_acc: 0.5333

# %%
his.history
# Out:
# {'loss': [1.0975444316864014,
#   1.0610498189926147,
#   1.1009587049484253,
#   1.0425069332122803,
#   1.0183289051055908,
#   1.0177491903305054,
#   1.0183881521224976,
#   1.025896430015564,
#   1.030562400817871,
#   1.0419948101043701,
#   1.019044041633606,
#   1.0157088041305542,
#   1.0154352188110352,
#   1.0156675577163696,
#   1.019930362701416,
#   1.012472152709961,
#   1.0122281312942505,
#   1.0039782524108887,
#   1.1672712564468384,
#   1.0282751321792603],
#  'acc': [0.2571428716182709,
#   0.5142857432365417,
#   0.2571428716182709,
#   0.5142857432365417,
#   0.5142857432365417,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.5428571701049805,
#   0.2571428716182709,
#   0.5428571701049805],
#  'val_loss': [1.058449625968933,
#   1.100841999053955,
#   1.042617678642273,
#   1.0119059085845947,
#   1.0192691087722778,
#   1.0103639364242554,
#   1.0363601446151733,
#   1.0168862342834473,
#   1.051148772239685,
#   1.0231831073760986,
#   1.0155856609344482,
#   1.013940691947937,
#   1.0197306871414185,
#   1.0193077325820923,
#   1.0217574834823608,
#   1.0188579559326172,
#   1.0160095691680908,
#   1.226730227470398,
#   1.0254875421524048,
#   1.02254056930542],
#  'val_acc': [0.5333333611488342,
#   0.2666666805744171,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.5333333611488342,
#   0.20000000298023224,
#   0.5333333611488342,
#   0.5333333611488342]}

# %%
import matplotlib.pyplot as plt

# %%
# define a function to plot the result from training step
def show_result(history):

    # Print the result from the last epoch
    print('Last train accuracy: %s' % history.history['acc'][-1])
    print('Last validation accuracy: %s' % history.history['val_acc'][-1])

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    acc = history.history['acc']
    val_acc = history.history['val_acc']

    epochs = range(1, len(loss) + 1)

    # Define a subplot
    fig, axs = plt.subplots(1, 2, figsize=(15, 4))

    # Plot loss
    loss_plot = axs[0]

    loss_plot.plot(epochs, loss, 'c--', label='Training loss')
    loss_plot.plot(epochs, val_loss, 'b', label='Validation loss')
    loss_plot.set_title('Training and validation loss')
    loss_plot.set_xlabel('Epochs')
    loss_plot.set_ylabel('Loss')
    loss_plot.legend()

    # Plot accuracy
    acc_plot = axs[1]

    acc_plot.plot(epochs, acc, 'c--', label='Training acc')
    acc_plot.plot(epochs, val_acc, 'b', label='Validation acc')
    acc_plot.set_title('Training and validation accuracy')
    acc_plot.set_xlabel('Epochs')
    acc_plot.set_ylabel('Accuracy')
    acc_plot.legend()

# %%
show_result(his)
# Out:
# Last train accuracy: 0.5428571701049805
# Last validation accuracy: 0.5333333611488342

# %%
model.evaluate(x_test_index,y_test)
# Out:
# 1/1 [==============================] - 1s 832ms/step - loss: 1.0225 - acc: 0.5333
# [1.02254056930542, 0.5333333611488342]

# %%
model.predict(x_test_index).argmax(axis=1)
# Out:
# 1/1 [==============================] - 2s 2s/step
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 2, 0, 2, 0, 2, 2, 1, 2, 1, 2, 2, 2, 1], dtype=int64)

# %%
model.predict(x_train_index).argmax(axis=1)
# Out:
# 2/2 [==============================] - 3s 547ms/step
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)

# %%
y_train
# Out:
# array([2, 2, 2, 2, 1, 2, 1, 2, 0, 1, 0, 1, 0, 2, 2, 2, 1, 2, 1, 2, 2, 1,
#        0, 0, 2, 0, 2, 0, 0, 2, 2, 2, 1, 2, 1], dtype=int64)
